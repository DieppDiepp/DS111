# %% [markdown]
# # Đọc data

# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
from IPython.display import display

# %%
# pd.set_option('display.max_columns', 50)
# pd.set_option('display.max_rows', 50)
pd.set_option('display.max_colwidth', 200)

# %%
# import data_goc
data_original = pd.read_json(r'D:\Python_code\DS111_Final_Term_Project\DS111\analysis-job-trend\data\1- job-list\job_list.json')
data_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3458 entries, 0 to 3457
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_title            3458 non-null   object
#  1   salary               3458 non-null   object
#  2   province             3458 non-null   object
#  3   experience_years     3458 non-null   object
#  4   deadline             3458 non-null   object
#  5   job_description      3458 non-null   object
#  6   job_requirements     3458 non-null   object
#  7   job_benefits         3458 non-null   object
#  8   job_location_detail  3458 non-null   object
#  9   working_time         3458 non-null   object
#  10  company_name         3458 non-null   object
#  11  company_scale        3458 non-null   object
#  12  company_industry     3458 non-null   object
#  13  company_address      3458 non-null   object
#  14  job_level            3458 non-null   object
#  15  academic_level       3458 non-null   object
#  16  job_type             3458 non-null   object
#  17  quantity             3458 non-null   object
#  18  tags_role            3458 non-null   object
#  19  tags_skill           3458 non-null   object
#  20  tags_location        3458 non-null   object
#  21  company_url          3458 non-null   object
#  22  url                  3458 non-null   object
#  23  date_crawl           3458 non-null   object
#  24  layout_type          3458 non-null   object
#  25  csv_id               3458 non-null   int64
# dtypes: int64(1), object(25)
# memory usage: 702.5+ KB

# %%
data_original
# Out:
#                                                                                                          job_title  \
# 0                                           Kỹ Sư Triển Khai Dự Án Hệ Thống (Postsale System) - Thu Nhập Upto 40tr
# 1                                         Nhân Viên Tư Vấn Phát Triển Phần Mềm (HCM - Thu Nhập Lên Đến 25Tr/Tháng)
# 2                         Nhân Viên Kinh Doanh/Sale/Tư Vấn Bán Hàng(Máy In)Lương Cứng 12tr+Hoa Hồng-Nhận Việc Ngay
# 3                                         Business Analyst | Từ 3 Năm Kinh Nghiệm | Thu Nhập Upto 30M | Tại Hà Nội
# 4           Nhân Viên Kinh Doanh Phần Mềm ERP/ Sales ERP Thu Nhập Cao Upto 30-60 Triệu - Nhận Việc Ngay Tại Quận 7
# ...                                                                                                            ...
# 3453                                                                Chuyên Viên Kinh Doanh - Sales (Mảng Phần Mềm)
# 3454                                                                         Chuyên Viên Kiểm Thử Phần Mềm/ Tester
# 3455  Frontend Developer (ReactJS) - Mid/Senior Level - Không Yêu Cầu Tiếng Anh (Thu Nhập Từ 20 - 35 Triệu VNĐ+++)
# 3456                                                                                  Experienced Business Analyst
# 3457                                                      Senior Devops - Thu Nhập Hấp Dẫn - Làm Việc Tại Tân Bình
#
#              salary             province experience_years    deadline  \
# 0     20 - 40 triệu  Hà Nội, Hồ Chí Minh            2 năm  31/01/2026
# 1     10 - 25 triệu          Hồ Chí Minh    Không yêu cầu  02/01/2026
# 2        Thoả thuận          Hồ Chí Minh       Dưới 1 năm  02/01/2026
# 3     25 - 30 triệu               Hà Nội            3 năm  27/12/2025
# 4     30 - 60 triệu          Hồ Chí Minh            3 năm  01/01/2026
# ...             ...                  ...              ...         ...
# 3453  25 - 35 triệu               Hà Nội            1 năm  09/01/2026
# 3454  15 - 25 triệu          Hồ Chí Minh            2 năm  10/12/2025
# 3455  20 - 35 triệu               Hà Nội            3 năm  10/12/2025
# 3456   Tới 30 triệu               Hà Nội            2 năm  31/12/2025
# 3457     Thoả thuận          Hồ Chí Minh            4 năm  10/12/2025
#
#                                                                                                                                                                                               job_description  \
# 0     Triển khai và giám sát thi công các dự án công nghệ thông tin:\nTriển khai Hệ thống ảo hóa: VMware, Citrix, Hyper-V.\nTriển khai Hệ thống máy chủ: HPE, IBM, DellEMC...\nTriển khai các hệ thống cun...
# 1     Tư vấn khách hàng doanh nghiệp triển khai các kênh marketing onl website, phần mềm bán hàng.\nThực hiện các thủ tục ký kết hợp đồng với khách hàng.\nXây dựng, duy trì mối quan hệ tốt với khách hàn...
# 2     - Duy trì những mối quan hệ Kinh doanh hiện có, bao gồm khách hàng doanh nghiệp và đối tác.\n- Tìm kiếm mở rộng, tiếp xúc và khai thác các mối quan hệ mục tiêu, chăm sóc bồi dưỡng thành các mối qu...
# 3     ĐỐI TÁC\nĐối tác hoạt động chuyên sâu trong lĩnh vực An toàn thông tin/Cyber Security, cung cấp giải pháp bảo mật cho các hệ thống lớn trong và ngoài nước. Văn hoá làm việc đề cao tính kỷ luật, ti...
# 4     Actively seek and develop potential clients (in a B2B model), build and maintain client relationships through various methods, and achieve company-set sales targets.\nDeeply understand clients' bu...
# ...                                                                                                                                                                                                       ...
# 3453  Tìm hiểu về sản phẩm: Salekit - Phần mềm quản lý bán hàng đa kênh\nData từ 02 nguồn: data từ BP marketing cung cấp & data do sale chủ động tìm kiếm\nLiên hệ khách hàng để tư vấn => demo => đàm phá...
# 3454  • Phát triển & Bảo trì: Tham gia vào quy trình phát triển dự án, đảm bảo chất lượng dự án.\n• Thiết kế hệ thống: Đọc hiểu, phân tích tài liệu đặc tả, yêu cầu từ phía khách hàng, tài liệu của hệ th...
# 3455  Phát triển và tối ưu giao diện người dùng (UI) cho web/app sử dụng ReactJS (hoặc NextJS).\nPhối hợp chặt chẽ với Backend team, UI/UX Designer, BA để đảm bảo sản phẩm đáp ứng yêu cầu kỹ thuật và ng...
# 3456  Experienced Business Analyst with 2+ years of experience in business analysis on software development projects, advanced English level, and experience in the e-Commerce domain to join our team.\nW...
# 3457  - Thiết kế, xây dựng và duy trì CI/CD pipelines (Jenkins, GitHub Actions, ArgoCD,..) ;\n- Quản lý, vận hành hạ tầng Cloud/On-premise;\n- Triển khai và tối ưu hóa Kubernetes clusters;\n- Xây dựng h...
#
#                                                                                                                                                                                              job_requirements  \
# 0     Tốt nghiệp Cao Đẳng /Đại Học chuyên ngành CNTT hoặc tương đương\nCó từ 2 năm kinh nghiệm(có kinh nghiệm ở các vị trí tương đương).\nƯu tiên có chứng chỉ: VMware Certified Associate (VCA),, MCSA......
# 1     Tuổi từ 20 trở lên, yêu cầu bằng cấp từ tốt nghiệp trung cấp\nGiọng nói dễ nghe, tự tin\nKỹ năng giao tiếp tốt.\nNhiệt tình, vui vẻ hỗ trợ khách hàng\nCó công cụ làm việc : Xe máyy, smartphone\nCh...
# 2     Trình độ học vấn Cao đẳng, Đại học- nếu đã có kinh nghiệm không cần bằng.\nTrình độ chuyên môn Một trong các chuyên ngành: Quản trị kinh doanh, kinh tế, marketing hoặc chứng chỉ tương ứng\nKinh ng...
# 3     Tốt nghiệp Đại học chuyên ngành CNTT, Khoa học máy tính, Toán – Tin, An toàn thông tin hoặc liên quan.\nTừ 3 năm kinh nghiệm ở vị trí Business Analyst hoặc tương đương.\nHiểu biết về Agile, UX/UI,...
# 4     Bachelor's degree or above (or equivalent).3 years of B2B software sales experience; experience selling enterprise applications like ERP or CRM is a strong plus.\nClear understanding and knowledge...
# ...                                                                                                                                                                                                       ...
# 3453  Kinh nghiệm 1 năm ở vị trí tương đương, ưu tiên ứng viên có kinh nghiệm trong mảng phần mềm (khả năng lên leader cao)\nKhả năng tư vấn, đàm phán tốt\nCó mong muốn phát triển & thăng tiến\nCó lapto...
# 3454  Kỹ năng & Kinh nghiệm chính:\n• Có ít nhất 2 năm kinh nghiệm làm việc thực tế với vị trí Software Testing\n• Có kinh nghiệm test web/mobile/desktop.\n• Có kinh nghiệm làm việc với API, Database.\n...
# 3455  Tối thiểu 3-4 năm kinh nghiệm lập trình Frontend, trong đó ReactJS là công nghệ chính.\nThành thạo HTML5, CSS3, JavaScript (ES6+), TypeScript.\nCó kinh nghiệm làm việc với các dự án AI là một lợi ...
# 3456  At least 2 years’ relevant experience as a Business Analyst (or similar capacity) with a proven track record of successful project delivery. eCommerce experience is not compulsory, but will be hig...
# 3457  1. Kiến thức chuyên môn:\n- Trình độ học vấn: Tốt nghiệp Cao học/Đại học chính quy;\n- Có thể đọc hiểu và research tốt bằng tiếng Anh;\n- Tối thiểu 4-5 năm kinh nghiệm làm việc trong lĩnh vực DevO...
#
#                                                                                                                                                                                                  job_benefits  \
# 0     Chế độ lương thưởng hấp dẫn;\nChế độ BHYT, BHXH, BHTN theo quy định;\nBảo hiểm sức khỏe cho Nhân viên chính thức;\nBếp ăn cho Nhân viên (công ty hỗ trợ chi phí);\nThưởng định kỳ các ngày lễ 30/4, ...
# 1     Thu nhập cao 10 - 25tr và thưởng hoa hồng lên đến 35%\nĐược hưởng các chế độ, phúc lợi theo quy định của Luật lao động\nĐược hỗ trợ, đào tạo kỹ năng công việc\nXét tăng tiến khi có thành tích tốt\...
# 2     Lương cố định: (từ 8 - đến 12 triệu)\nHoa hồng bán hàng phụ thuộc vào %/dự án/sản phẩm.\nThưởng đạt chỉ tiêu về doanh số.\nNâng lương theo quy định.\nSau thử việc ký Hợp đồng lao động, tham gia BH...
# 3     Sign-on Bonus 1 tháng lương nếu đạt level đánh giá và bắt đầu làm việc trước 01/01/2026.\nThu nhập cạnh tranh 300 - 350M Gross/năm, review lương định kỳ tháng 3 hàng năm.\nBảo hiểm sức khỏe MIC (h...
# 4     Competitive salary with attractive commission and performance bonuses, offering unlimited income potential.\nQuarterly and annual performance-based incentives for outstanding achievements.\nTransp...
# ...                                                                                                                                                                                                       ...
# 3453  Mức lương khởi điểm & phụ cấp: 7.000.000đ - 10.000.000đ/ tháng + thưởng 20% cạnh tranh nhất thị trường (thu nhập cạnh tranh), cơ hội thăng tiến lên leader cao\nĂn trưa miễn phí tại canteen công ty...
# 3454  • Mức lương: 15,000,000-25,000,000 VNĐ/tháng (có thể thương lượng cao hơn tùy theo năng lực và kinh nghiệm).\n• Thưởng hấp dẫn:\no Thưởng chuyên cần: 1,000,000 VNĐ/tháng.\no Thưởng hiệu quả dự án ...
# 3455  Thu nhập từ 20 - 35 triệu VNĐ/tháng (tùy năng lực)\nHỗ trợ chi phí đi lại cho nhân sự onsite tại Hà Nội.\nCơ hội làm việc với Khách hàng cuối là Tập đoàn đa ngành top đầu tại Việt Nam\nCơ hội tham...
# 3456  Salary range: up to 30M. OKR/KPI bonus. Performance review twice a year;\n13th-month salary based on the business performance. Seniority Allowance;\nOpportunity to experience your expertise in a y...
# 3457  1. Quyền lợi:\n- Lương chính: Lương thỏa thuận theo năng lực và kinh nghiệm thực tế của ứng viên;\n- Thưởng:\n+ Thưởng định kỳ theo kết quả kinh doanh chung của Công ty theo năm;\n+ Thưởng đột xuấ...
#
#                                                                                                                                                                       job_location_detail  \
# 0     - Hà Nội: Tòa nhà 319 Bộ Quốc phòng, 63 Lê Văn Lương, Cầu Giấy, Phường Cầu Giấy\n- Hồ Chí Minh: ầng 10, Toà The six8 , 24-26 Phan Đình Giót, Phường Tân Sơn Hoà, Phường Tân Sơn Hòa
# 1                                                                                      - Hồ Chí Minh: Lầu 1 Tòa nhà Saigon ICT, Lô 46 Công viên phần mềm Quang Trung, Phường Trung Mỹ Tây
# 2                                                                                                                                                         - Hồ Chí Minh: Phường Long Bình
# 3                                                                                                                  - Hà Nội: Landmark 72, Lô E6, Khu đô thị mới Cầu Giấy, Phường Cầu Giấy
# 4                                                                                                                                               - Hồ Chí Minh: COBI Tower, Phường Tân Phú
# ...                                                                                                                                                                                   ...
# 3453                                                                                                                                              - Hà Nội: 247 Cầu Giấy, Phường Cầu Giấy
# 3454                                                                                                                                - Hồ Chí Minh: 25 Đường 53C, Phường Tân Tạo, Bình Tân
# 3455                                                                                                                                                                             - Hà Nội
# 3456                                                                                                                          - Hà Nội: Toà Viwaseen, 48 Tố Hữu, Nam Từ Liêm, Nam Từ Liêm
# 3457                                                                                                                      - Hồ Chí Minh: Tòa WASECO, Số 10, Phổ Quang, Phường Tân Sơn Hòa
#
#                                                         working_time  \
# 0                                 Thứ 2 - Thứ 6 (từ 08:00 đến 17:00)
# 1     Thứ 2 - Thứ 6 (từ 08:00 đến 17:00)\nThứ 7 (từ 08:00 đến 12:00)
# 2                                                               Null
# 3                                 Thứ 2 - Thứ 6 (từ 08:00 đến 18:00)
# 4                                 Thứ 2 - Thứ 6 (từ 08:30 đến 17:30)
# ...                                                              ...
# 3453                                                            Null
# 3454                                                            Null
# 3455                                                            Null
# 3456                              Thứ 2 - Thứ 6 (từ 09:00 đến 18:15)
# 3457                              Thứ 2 - Thứ 7 (từ 08:00 đến 17:30)
#
#                                                      company_name  \
# 0                          Công ty Cổ phần Hệ thống Công nghệ ETC
# 1                          CÔNG TY TNHH CÔNG NGHỆ PHẦN MỀM NASANI
# 2                      CÔNG TY CP THIẾT BỊ CÔNG NGHIỆP HUỲNH LONG
# 3                         CÔNG TY CỔ PHẦN CÔNG NGHỆ THÔNG MINH GX
# 4     CÔNG TY TNHH KINGDEE INTERNATIONAL SOFTWARE GROUP (VIETNAM)
# ...                                                           ...
# 3453                                     Công ty Cổ Phần Salemall
# 3454                CÔNG TY TNHH KHOA HỌC VÀ CÔNG NGHỆ MINDORIGIN
# 3455                                              DATAX POWER LTD
# 3456                                                    BSS Group
# 3457                         VPĐD Công ty Cổ phần Trực tuyến GOSU
#
#            company_scale   company_industry  \
# 0     500-1000 nhân viên      IT - Phần mềm
# 1        1000+ nhân viên  Internet / Online
# 2        25-99 nhân viên             Cơ khí
# 3        25-99 nhân viên      IT - Phần mềm
# 4        25-99 nhân viên      IT - Phần mềm
# ...                  ...                ...
# 3453     10-24 nhân viên      IT - Phần mềm
# 3454     25-99 nhân viên      IT - Phần mềm
# 3455     10-24 nhân viên      IT - Phần mềm
# 3456   100-499 nhân viên      IT - Phần mềm
# 3457   100-499 nhân viên  Internet / Online
#
#                                                                                                       company_address  \
# 0                                              Tòa 319 Bộ Quốc Phòng, Số 63 Lê Văn Lương, Trung Hòa, Cầu Giấy, Hà Nội
# 1                                          Lầu 1, Tòa nhà SaigonTel, Lô 46, CVPM Quang Trung, P. Trung Mỹ Tây, TP HCM
# 2     Lô J35, KDC Phú Nhuận, 659 Đỗ Xuân Hợp, Phường Phước Long B, Thành phố Thủ Đức, Thành phố Hồ Chí Minh, Việt Nam
# 3                                                                        HH2 Bắc Hà, số 15 Tố Hữu, Thanh Xuân, Hà Nội
# 4                     4th Floor, Cobi Tower II Building, No. 2-4 Street No. 8, Tan My Ward, Ho Chi Minh City, Vietnam
# ...                                                                                                               ...
# 3453                Toà nhà iNET, số 247, đường Cầu Giấy, Phường Dịch Vọng, Quận Cầu Giấy, Thành phố Hà Nội, Việt Nam
# 3454                                                           25 Đường 53C, Phường Tân Tạo, TP Hồ Chí Minh, Việt Nam
# 3455                                  ML6-40 Vinhomes Green Bay, Lương Thế Vinh, Mễ Trì, Nam Từ Liêm, Hà Nội, Vietnam
# 3456                                                  Headquarters: Viwaseen Tower, Nam Tu Liem Dist., Hanoi, Vietnam
# 3457                                                                            10 Phổ Quang, Phường 2, Quận Tân Bình
#
#       job_level     academic_level        job_type  quantity  \
# 0     Nhân viên   Cao Đẳng trở lên  Toàn thời gian  10 người
# 1     Nhân viên  Trung cấp trở lên  Toàn thời gian   8 người
# 2     Nhân viên  Trung cấp trở lên  Toàn thời gian   2 người
# 3     Nhân viên    Đại Học trở lên  Toàn thời gian   1 người
# 4     Nhân viên   Cao Đẳng trở lên  Toàn thời gian   1 người
# ...         ...                ...             ...       ...
# 3453  Nhân viên   Cao Đẳng trở lên  Toàn thời gian   2 người
# 3454  Nhân viên   Cao Đẳng trở lên  Toàn thời gian   4 người
# 3455  Nhân viên   Cao Đẳng trở lên  Toàn thời gian   2 người
# 3456  Nhân viên    Đại Học trở lên  Toàn thời gian   1 người
# 3457  Nhân viên   Cao Đẳng trở lên  Toàn thời gian   2 người
#
#                                                                                                                                        tags_role  \
# 0                                                            Công nghệ Thông tin, IT Infrastructure and Operations, System Engineer, Việc làm IT
# 1     Kinh doanh/Bán hàng, Marketing/PR/Quảng cáo, Marketing/PR/Quảng cáo, Sales dịch vụ Quảng cáo/Triển lãm/Sự kiện, Marketing, Sales Marketing
# 2         Kinh doanh/Bán hàng, Công nghệ Thông tin, Sales Kỹ thuật (Sales Engineer), Công nghệ thông tin khác, Bán hàng kỹ thuật IT, Việc làm IT
# 3                                                   Công nghệ Thông tin, Product Management, Business Analyst (Phân tích nghiệp vụ), Việc làm IT
# 4                                                  Kinh doanh/Bán hàng, Công nghệ Thông tin, Sales IT Phần mềm, Kinh doanh phần mềm, Việc làm IT
# ...                                                                                                                                          ...
# 3453                                               Kinh doanh/Bán hàng, Công nghệ Thông tin, Sales IT Phần mềm, Kinh doanh phần mềm, Việc làm IT
# 3454                                                   Công nghệ Thông tin, Software Testing, Software Tester (Automation & Manual), Việc làm IT
# 3455                                                                  Công nghệ Thông tin, Software Engineering, Frontend Developer, Việc làm IT
# 3456                                                Công nghệ Thông tin, Product Management, Business Analyst (Phân tích nghiệp vụ), Việc làm IT
# 3457                                                         Công nghệ Thông tin, IT Infrastructure and Operations, DevOps Engineer, Việc làm IT
#
#                                                                                                                                                                                                    tags_skill  \
# 0                                                                   Kỹ năng giao tiếp, Kỹ năng giải quyết vấn đề, Kỹ Năng Quản Lý Dự Án, Kỹ Năng Triển Khai Phần Mềm, Kiến Thức Về Hệ Thống (ví Dụ: Crm, Erp)
# 1     Công Nghệ Thông Tin, Kinh Doanh Phần Mềm, Quản Lý Website, Có kiến thức về công nghệ thông tin, sử dụng hiệu quả các phần mềm văn phòng, phần mềm quản lý tài liệu, hệ thống email và mạng lưới, Hiể...
# 2                                                                                                                                                                                                        Null
# 3                                                                                                          Phân Tích Nghiệp Vụ, Phân tích dữ liệu, Giải quyết vấn đề, Giao tiếp, Làm việc nhóm, Viết tài liệu
# 4                                                                                                                                                        Xây dựng mối quan hệ, Giao tiếp, Phân Tích Nghiệp Vụ
# ...                                                                                                                                                                                                       ...
# 3453                                                                                                                                                                                                     Null
# 3454                                                                                                                                                                                                     Null
# 3455                                                                                                                                                                                                     Null
# 3456                                                                              Business Analyst, Phân tích dữ liệu, Phân Tích Nghiệp Vụ, Thu Thập Yêu Cầu, Mô Hình Hóa Quy Trình, Requirements Elicitation
# 3457                                                                                                                                                                                                     Null
#
#                                                                         tags_location  \
# 0     Hà Nội, Phường Cầu Giấy - Hà Nội, Hồ Chí Minh, Phường Tân Sơn Hòa - Hồ Chí Minh
# 1                                      Hồ Chí Minh, Phường Trung Mỹ Tây - Hồ Chí Minh
# 2                                         Hồ Chí Minh, Phường Long Bình - Hồ Chí Minh
# 3                                                    Hà Nội, Phường Cầu Giấy - Hà Nội
# 4                                           Hồ Chí Minh, Phường Tân Phú - Hồ Chí Minh
# ...                                                                               ...
# 3453                                                 Hà Nội, Phường Cầu Giấy - Hà Nội
# 3454                                                   Hồ Chí Minh, Bình Tân - TP HCM
# 3455                                                                           Hà Nội
# 3456                                                     Hà Nội, Nam Từ Liêm - Hà Nội
# 3457                                    Hồ Chí Minh, Phường Tân Sơn Hòa - Hồ Chí Minh
#
#                                                                                              company_url  \
# 0                        https://www.topcv.vn/cong-ty/cong-ty-co-phan-he-thong-cong-nghe-etc/200939.html
# 1                        https://www.topcv.vn/cong-ty/cong-ty-tnhh-cong-nghe-phan-mem-nasani/233549.html
# 2                    https://www.topcv.vn/cong-ty/cong-ty-cp-thiet-bi-cong-nghiep-huynh-long/105523.html
# 3                       https://www.topcv.vn/cong-ty/cong-ty-co-phan-cong-nghe-thong-minh-gx/243568.html
# 4     https://www.topcv.vn/cong-ty/cong-ty-tnhh-kingdee-international-software-group-vietnam/237459.html
# ...                                                                                                  ...
# 3453                                    https://www.topcv.vn/cong-ty/cong-ty-co-phan-salemall/10238.html
# 3454              https://www.topcv.vn/cong-ty/cong-ty-tnhh-khoa-hoc-va-cong-nghe-mindorigin/236893.html
# 3455                                            https://www.topcv.vn/cong-ty/datax-power-ltd/208389.html
# 3456                                                     https://www.topcv.vn/cong-ty/bss-group/405.html
# 3457                        https://www.topcv.vn/cong-ty/vpdd-cong-ty-co-phan-truc-tuyen-gosu/21410.html
#
#                                                                                                                                                                                                           url  \
# 0     https://www.topcv.vn/viec-lam/ky-su-trien-khai-du-an-he-thong-postsale-system-thu-nhap-upto-40tr/1949543.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_17...
# 1     https://www.topcv.vn/viec-lam/nhan-vien-tu-van-phat-trien-phan-mem-hcm-thu-nhap-len-den-25tr-thang/1971777.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_...
# 2     https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-sale-tu-van-ban-hangmay-inluong-cung-12tr-hoa-hong-nhan-viec-ngay/1971328.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4V...
# 3     https://www.topcv.vn/viec-lam/business-analyst-tu-3-nam-kinh-nghiem-thu-nhap-upto-30m-tai-ha-noi/1966948.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_17...
# 4     https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-phan-mem-erp-sales-erp-thu-nhap-cao-upto-30-60-trieu-nhan-viec-ngay-tai-quan-7/1891406.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4Gqa...
# ...                                                                                                                                                                                                       ...
# 3453                     https://www.topcv.vn/viec-lam/chuyen-vien-kinh-doanh-sales-mang-phan-mem/1944199.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096264
# 3454                           https://www.topcv.vn/viec-lam/chuyen-vien-kiem-thu-phan-mem-tester/1945294.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096431
# 3455  https://www.topcv.vn/viec-lam/frontend-developer-reactjs-mid-senior-level-khong-yeu-cau-tieng-anh-thu-nhap-tu-20-35-trieu-vnd/1945977.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKy...
# 3456                                   https://www.topcv.vn/viec-lam/experienced-business-analyst/1891659.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096431
# 3457           https://www.topcv.vn/viec-lam/senior-devops-thu-nhap-hap-dan-lam-viec-tai-tan-binh/1946011.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096431
#
#                date_crawl layout_type  csv_id
# 0     09/12/2025 13:13:17    standard       1
# 1     09/12/2025 13:13:28    standard       2
# 2     09/12/2025 13:13:41    standard       3
# 3     09/12/2025 13:13:50    standard       4
# 4     09/12/2025 13:14:03    standard       5
# ...                   ...         ...     ...
# 3453  10/12/2025 06:48:47    standard    2064
# 3454  10/12/2025 07:02:07    standard    2815
# 3455  10/12/2025 07:02:26    standard    2816
# 3456  10/12/2025 07:02:46    standard    2817
# 3457  10/12/2025 07:03:05    standard    2818
#
# [3458 rows x 26 columns]

# %%
# import data đã được xử lí bằng API
data_API = pd.read_parquet(r'D:\Python_code\DS111_Final_Term_Project\DS111\analysis-job-trend\data\2-API-processing\API_data_raw.parquet')
data_API.head(5)
# Out:
#                                             Job_Title  \
# 0   Kỹ Sư Triển Khai Dự Án Hệ Thống (Postsale System)
# 1                Nhân Viên Tư Vấn Phát Triển Phần Mềm
# 2  Nhân Viên Kinh Doanh/Sale/Tư Vấn Bán Hàng (Máy In)
# 3                                    Business Analyst
# 4        Nhân Viên Kinh Doanh Phần Mềm Erp/ Sales Erp
#
#                                                                                                                                       Roles  \
# 0                                                     [CÔNG NGHỆ THÔNG TIN, IT INFRASTRUCTURE AND OPERATIONS, SYSTEM ENGINEER, VIỆC LÀM IT]
# 1                      [KINH DOANH/BÁN HÀNG, MARKETING/PR/QUẢNG CÁO, SALES DỊCH VỤ QUẢNG CÁO/TRIỂN LÃM/SỰ KIỆN, MARKETING, SALES MARKETING]
# 2  [KINH DOANH/BÁN HÀNG, CÔNG NGHỆ THÔNG TIN, SALES KỸ THUẬT (SALES ENGINEER), CÔNG NGHỆ THÔNG TIN KHÁC, BÁN HÀNG KỸ THUẬT IT, VIỆC LÀM IT]
# 3                                            [CÔNG NGHỆ THÔNG TIN, PRODUCT MANAGEMENT, BUSINESS ANALYST (PHÂN TÍCH NGHIỆP VỤ), VIỆC LÀM IT]
# 4                                           [KINH DOANH/BÁN HÀNG, CÔNG NGHỆ THÔNG TIN, SALES IT PHẦN MỀM, KINH DOANH PHẦN MỀM, VIỆC LÀM IT]
#
#    Recruitment_Count               Province Company_Location  \
# 0                 10  [HÀ NỘI, HỒ CHÍ MINH]         [HÀ NỘI]
# 1                  8          [HỒ CHÍ MINH]    [HỒ CHÍ MINH]
# 2                  2          [HỒ CHÍ MINH]    [HỒ CHÍ MINH]
# 3                  1               [HÀ NỘI]         [HÀ NỘI]
# 4                  1          [HỒ CHÍ MINH]    [HỒ CHÍ MINH]
#
#    Current_Employee_Min  Current_Employee_Max  \
# 0                 500.0                1000.0
# 1                1000.0                   NaN
# 2                  25.0                  99.0
# 3                  25.0                  99.0
# 4                  25.0                  99.0
#
#                                Language  \
# 0               [TIẾNG VIỆT, TIẾNG ANH]
# 1                          [TIẾNG VIỆT]
# 2                          [TIẾNG VIỆT]
# 3               [TIẾNG VIỆT, TIẾNG ANH]
# 4  [TIẾNG VIỆT, TIẾNG TRUNG, TIẾNG ANH]
#
#                                                                                                                                                                                                 Tech_Stack  \
# 0  [VMWARE, CITRIX, HYPER-V, HPE, IBM, DELL EMC, ACTIVE DIRECTORY, DNS, MAIL SERVER, PROXY, SAN, NAS, NETAPP, HP, FUJITSU, EMC, CLOUD, ORACLE, VMWARE CERTIFIED ASSOCIATE (VCA), MCSA, NETWORKING, WIND...
# 1                                                                                  [WEBSITE, PHẦN MỀM BÁN HÀNG, PHẦN MỀM VĂN PHÒNG, PHẦN MỀM QUẢN LÝ TÀI LIỆU, HỆ THỐNG EMAIL, MẠNG LƯỚI, QUẢN LÝ WEBSITE]
# 2                                                                                                                                                                                                  [EXCEL]
# 3                                                                                       [CYBER SECURITY, DATA MODELING, MOCKUPS, PROTOTYPES, AGILE, UX/UI, DESIGN THINKING, TOÁN - TIN, KHOA HỌC MÁY TÍNH]
# 4                                                                                                                                                                                               [ERP, CRM]
#
#   Programming_Language  \
# 0                [SQL]
# 1                 None
# 2                 None
# 3                 None
# 4                 None
#
#                                                                                                                                                                                                     Skills  \
# 0  [GIÁM SÁT THI CÔNG, QUẢN LÝ DỰ ÁN, VIẾT TÀI LIỆU KỸ THUẬT, TƯ VẤN GIẢI PHÁP, XỬ LÝ SỰ CỐ, QUẢN TRỊ HỆ THỐNG, BẢO TRÌ HỆ THỐNG, NGHIÊN CỨU SẢN PHẨM, ĐỌC HIỂU TÀI LIỆU KỸ THUẬT, GIAO TIẾP, GIẢI QUYẾ...
# 1  [TƯ VẤN KHÁCH HÀNG, KÝ KẾT HỢP ĐỒNG, XÂY DỰNG MỐI QUAN HỆ, CHĂM SÓC KHÁCH HÀNG, GIAO TIẾP, KINH DOANH PHẦN MỀM, KIẾN THỨC VỀ CÔNG NGHỆ THÔNG TIN, HIỂU BIẾT VỀ THỊ TRƯỜDNG CÔNG NGHỆ THÔNG TIN, AM H...
# 2                                                                                                                               [KỸ NĂNG GIAO TIẾP, KỸ NĂNG LÀM VIỆC NHÓM, QUẢN TRỊ KINH DOANH, MARKETING]
# 3  [PHÂN TÍCH NGHIỆP VỤ, PHÂN TÍCH DỮ LIỆU, TƯ DUY LOGIC, KỸ NĂNG VIẾT, KỸ NĂNG TRÌNH BÀY, PHÂN TÍCH TRẢI NGHIỆM KHÁCH HÀNG, THIẾT KẾ HỆ THỐNG, GIAO TIẾP, PHỐI HỢP ĐA PHÒNG BAN, LÀM VIỆC NHÓM, CHỊU Đ...
# 4                                                                      [XÂY DỰNG MỐI QUAN HỆ, GIAO TIẾP, PHÂN TÍCH NGHIỆP VỤ, THUYẾT TRÌNH, ĐÀM PHÁN KINH DOANH, CHỊU ĐƯỢC ÁP LỰC, KHẢ NĂNG HỌC HỎI NHANH]
#
#    Total_Work_Hour  Salary_Min  Salary_Max  First_Working_Day_Of_Week  \
# 0             45.0  20000000.0  40000000.0                          2
# 1             49.0  10000000.0  25000000.0                          2
# 2              NaN   8000000.0  12000000.0                       <NA>
# 3             50.0  25000000.0  30000000.0                          2
# 4             45.0  30000000.0  60000000.0                          2
#
#    Last_Working_Day_Of_Week  Work_On_Saturday  Work_On_Sunday  \
# 0                         6               0.0             0.0
# 1                         6               1.0             0.0
# 2                      <NA>               0.0             0.0
# 3                         6               0.0             0.0
# 4                         6               0.0             0.0
#
#   Experience_Years    Deadline  \
# 0            2 năm  31/01/2026
# 1    Không yêu cầu  02/01/2026
# 2       Dưới 1 năm  02/01/2026
# 3            3 năm  27/12/2025
# 4            3 năm  01/01/2026
#
#                                                   Company_Name  \
# 0                       Công ty Cổ phần Hệ thống Công nghệ ETC
# 1                       CÔNG TY TNHH CÔNG NGHỆ PHẦN MỀM NASANI
# 2                   CÔNG TY CP THIẾT BỊ CÔNG NGHIỆP HUỲNH LONG
# 3                      CÔNG TY CỔ PHẦN CÔNG NGHỆ THÔNG MINH GX
# 4  CÔNG TY TNHH KINGDEE INTERNATIONAL SOFTWARE GROUP (VIETNAM)
#
#     Company_Industry  Job_Level     Academic_Level        Job_Type  \
# 0      IT - Phần mềm  Nhân viên   Cao Đẳng trở lên  Toàn thời gian
# 1  Internet / Online  Nhân viên  Trung cấp trở lên  Toàn thời gian
# 2             Cơ khí  Nhân viên  Trung cấp trở lên  Toàn thời gian
# 3      IT - Phần mềm  Nhân viên    Đại Học trở lên  Toàn thời gian
# 4      IT - Phần mềm  Nhân viên   Cao Đẳng trở lên  Toàn thời gian
#
#                                                                                           Company_URL  \
# 0                     https://www.topcv.vn/cong-ty/cong-ty-co-phan-he-thong-cong-nghe-etc/200939.html
# 1                     https://www.topcv.vn/cong-ty/cong-ty-tnhh-cong-nghe-phan-mem-nasani/233549.html
# 2                 https://www.topcv.vn/cong-ty/cong-ty-cp-thiet-bi-cong-nghiep-huynh-long/105523.html
# 3                    https://www.topcv.vn/cong-ty/cong-ty-co-phan-cong-nghe-thong-minh-gx/243568.html
# 4  https://www.topcv.vn/cong-ty/cong-ty-tnhh-kingdee-international-software-group-vietnam/237459.html
#
#                                                                                                                                                                                                    Job_URL  \
# 0  https://www.topcv.vn/viec-lam/ky-su-trien-khai-du-an-he-thong-postsale-system-thu-nhap-upto-40tr/1949543.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_17...
# 1  https://www.topcv.vn/viec-lam/nhan-vien-tu-van-phat-trien-phan-mem-hcm-thu-nhap-len-den-25tr-thang/1971777.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_...
# 2  https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-sale-tu-van-ban-hangmay-inluong-cung-12tr-hoa-hong-nhan-viec-ngay/1971328.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4V...
# 3  https://www.topcv.vn/viec-lam/business-analyst-tu-3-nam-kinh-nghiem-thu-nhap-upto-30m-tai-ha-noi/1966948.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_17...
# 4  https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-phan-mem-erp-sales-erp-thu-nhap-cao-upto-30-60-trieu-nhan-viec-ngay-tai-quan-7/1891406.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4Gqa...
#
#             Date_Crawl Layout_Type
# 0  09/12/2025 13:13:17    standard
# 1  09/12/2025 13:13:28    standard
# 2  09/12/2025 13:13:41    standard
# 3  09/12/2025 13:13:50    standard
# 4  09/12/2025 13:14:03    standard

# %% [markdown]
# # Xóa khoảng trắng thừa

# %%
cols_convert_to_list = ['Tech_Stack', 'Programming_Language', 'Province', 'Language', 'Roles', 'Company_Location']
#Chuyển đổi toàn bộ cột có kiểu dữ liệu np.ndarray sang list
for col in cols_convert_to_list:
    data_API[col] = data_API[col].apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x)

# %%
#Xóa khoảng trắng thừa ở đầu và cuối chuỗi
data_API = data_API.map(lambda x: x.strip() if isinstance(x, str) else x)
#Xóa khoảng trắng thừa ở đầu và cuối cho các cột có kiểu dữ liệu là list
for col in cols_convert_to_list:
    data_API[col] = data_API[col].apply(lambda x: [item.strip() for item in x] if isinstance(x, list) else x)

# %%
data_API.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3458 entries, 0 to 3457
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Job_Title                  3458 non-null   object
#  1   Roles                      3455 non-null   object
#  2   Recruitment_Count          3458 non-null   int64
#  3   Province                   3456 non-null   object
#  4   Company_Location           3456 non-null   object
#  5   Current_Employee_Min       3299 non-null   float64
#  6   Current_Employee_Max       2914 non-null   float64
#  7   Language                   3456 non-null   object
#  8   Tech_Stack                 3274 non-null   object
#  9   Programming_Language       1326 non-null   object
#  10  Skills                     3435 non-null   object
#  11  Total_Work_Hour            2948 non-null   float64
#  12  Salary_Min                 1829 non-null   float64
#  13  Salary_Max                 2092 non-null   float64
#  14  First_Working_Day_Of_Week  3187 non-null   float64
#  15  Last_Working_Day_Of_Week   3187 non-null   float64
#  16  Work_On_Saturday           3252 non-null   float64
#  17  Work_On_Sunday             3253 non-null   float64
#  18  Experience_Years           3458 non-null   object
#  19  Deadline                   3458 non-null   object
#  20  Company_Name               3458 non-null   object
#  21  Company_Industry           3458 non-null   object
#  22  Job_Level                  3458 non-null   object
#  23  Academic_Level             3458 non-null   object
#  24  Job_Type                   3458 non-null   object
#  25  Company_URL                3458 non-null   object
#  26  Job_URL                    3458 non-null   object
#  27  Date_Crawl                 3458 non-null   object
#  28  Layout_Type                3458 non-null   object
# dtypes: float64(9), int64(1), object(19)
# memory usage: 783.6+ KB

# %%
data_API_before = data_API.copy()

# %%
data_API.isnull().sum()
# Out:
# Job_Title                       0
# Roles                           3
# Recruitment_Count               0
# Province                        2
# Company_Location                2
# Current_Employee_Min          159
# Current_Employee_Max          544
# Language                        2
# Tech_Stack                    184
# Programming_Language         2132
# Skills                         23
# Total_Work_Hour               510
# Salary_Min                   1629
# Salary_Max                   1366
# First_Working_Day_Of_Week     271
# Last_Working_Day_Of_Week      271
# Work_On_Saturday              206
# Work_On_Sunday                205
# Experience_Years                0
# Deadline                        0
# Company_Name                    0
# Company_Industry                0
# Job_Level                       0
# Academic_Level                  0
# Job_Type                        0
# Company_URL                     0
# Job_URL                         0
# Date_Crawl                      0
# Layout_Type                     0
# dtype: int64

# %%
#Kiểm tra kiểu dữ liệu và đếm số lượng kiểu dữ liệu trong 1 cột
for col in data_API.columns:
    print(data_API[col].apply(type).value_counts())
# Out:
# Job_Title
# <class 'str'>    3458
# Name: count, dtype: int64
# Roles
# <class 'list'>        3455
# <class 'NoneType'>       3
# Name: count, dtype: int64
# Recruitment_Count
# <class 'int'>    3458
# Name: count, dtype: int64
# Province
# <class 'list'>        3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Company_Location
# <class 'list'>        3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Current_Employee_Min
# <class 'float'>    3458
# Name: count, dtype: int64
# Current_Employee_Max
# <class 'float'>    3458
# Name: count, dtype: int64
# Language
# <class 'list'>        3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Tech_Stack
# <class 'list'>        3274
# <class 'NoneType'>     184
# Name: count, dtype: int64
# Programming_Language
# <class 'NoneType'>    2132
# <class 'list'>        1326
# Name: count, dtype: int64
# Skills
# <class 'list'>        3435
# <class 'NoneType'>      23
# Name: count, dtype: int64
# Total_Work_Hour
# <class 'float'>    3458
# Name: count, dtype: int64
# Salary_Min
# <class 'float'>    3458
# Name: count, dtype: int64
# Salary_Max
# <class 'float'>    3458
# Name: count, dtype: int64
# First_Working_Day_Of_Week
# <class 'float'>    3458
# Name: count, dtype: int64
# Last_Working_Day_Of_Week
# <class 'float'>    3458
# Name: count, dtype: int64
# Work_On_Saturday
# <class 'float'>    3458
# Name: count, dtype: int64
# Work_On_Sunday
# <class 'float'>    3458
# Name: count, dtype: int64
# Experience_Years
# <class 'str'>    3458
# Name: count, dtype: int64
# Deadline
# <class 'str'>    3458
# Name: count, dtype: int64
# Company_Name
# <class 'str'>    3458
# Name: count, dtype: int64
# Company_Industry
# <class 'str'>    3458
# Name: count, dtype: int64
# Job_Level
# <class 'str'>    3458
# Name: count, dtype: int64
# Academic_Level
# <class 'str'>    3458
# Name: count, dtype: int64
# Job_Type
# <class 'str'>    3458
# Name: count, dtype: int64
# Company_URL
# <class 'str'>    3458
# Name: count, dtype: int64
# Job_URL
# <class 'str'>    3458
# Name: count, dtype: int64
# Date_Crawl
# <class 'str'>    3458
# Name: count, dtype: int64
# Layout_Type
# <class 'str'>    3458
# Name: count, dtype: int64

# %% [markdown]
# # Xem giá trị unique của các thuộc tính

# %%
# Tự động xác định các cột không phải là list và xem giá trị unique của chúng
for col in data_API.columns:
    # Lấy giá trị đầu tiên không rỗng trong cột để kiểm tra kiểu dữ liệu
    first_valid_item = data_API[col].dropna().iloc[0] if not data_API[col].dropna().empty else None
    
    # Nếu cột không chứa list, in ra các giá trị unique
    if not isinstance(first_valid_item, list):
        print(f"Unique values in {col}:")
        try:
            # Sử dụng unique() cho các kiểu dữ liệu thông thường
            unique_values = data_API[col].unique()
            print(unique_values)
        except TypeError:
            # Xử lý trường hợp cột chứa các kiểu dữ liệu không thể băm (unhashable)
            # Chuyển các giá trị sang chuỗi để lấy giá trị unique
            unique_values = data_API[col].astype(str).unique()
            print(unique_values)
        print("\n")
# Out:
# Unique values in Job_Title:
# ['Kỹ Sư Triển Khai Dự Án Hệ Thống (Postsale System)'
#  'Nhân Viên Tư Vấn Phát Triển Phần Mềm'
#  'Nhân Viên Kinh Doanh/Sale/Tư Vấn Bán Hàng (Máy In)' ...
#  'Chuyên Viên Kiểm Thử Phần Mềm/ Tester' 'Experienced Business Analyst'
#  'Senior Devops']
#
#
# Unique values in Recruitment_Count:
# [10  8  2  1  3  5  4  6 30 20 14  7 25 11 12 19 15 45 40 50 16  9]
#
#
# Unique values in Current_Employee_Min:
# [5.0e+02 1.0e+03 2.5e+01 1.0e+01 1.0e+02 1.0e+04 5.0e+03     nan 3.0e+03
#  1.0e+00]
#
#
# Unique values in Current_Employee_Max:
# [1000.   nan   99.   24.  499.    9.]
#
#
# Unique values in Total_Work_Hour:
# [45.    49.       nan 50.    54.    37.5   49.5   51.5   47.5   40.
#  46.25  45.83  48.    51.    48.75  56.    28.    44.    48.5   35.
#  49.17  45.5   46.75  60.    57.    42.5   47.75  51.75  42.    52.25
#  55.    48.125 46.5   50.25  56.5   49.75  53.5   46.    24.    50.5
#  51.25  47.    47.25  63.    44.17  93.5   32.5   52.    58.    38.5
#  20.    43.    53.    43.75  48.25  50.875 42.08  55.5   49.25  52.21
#  52.5   49.8   22.    46.67  36.    49.875  0.    53.625 57.5   15.
#  66.5   27.    41.25  43.5   39.25  41.   ]
#
#
# Unique values in Salary_Min:
# [2.0000000e+07 1.0000000e+07 8.0000000e+06 2.5000000e+07 3.0000000e+07
#            nan 4.5000000e+06 1.5000000e+07 7.4000000e+06 3.5000000e+07
#  6.0000000e+06 7.0000000e+06 1.8000000e+07 1.2000000e+07 3.5000000e+06
#  9.0000000e+06 5.0000000e+07 1.3000000e+07 1.4000000e+07 1.7000000e+07
#  5.3333333e+07 1.2500000e+07 3.0000000e+06 1.7500000e+07 2.0000000e+06
#  1.1000000e+07 5.0000000e+06 4.0000000e+06 9.5000000e+06 1.6000000e+07
#  1.0000000e+06 2.8000000e+07 5.0000000e+05 1.0000000e+08 4.0000000e+07
#  5.5000000e+06 3.7500000e+07 8.5000000e+06 2.5000000e+08 2.2000000e+07
#  2.1600000e+07 4.5000000e+07 2.3000000e+07 1.5000000e+06 2.1000000e+07
#  7.5000000e+06 4.2500000e+07 6.5000000e+06 2.3500000e+07 7.5000000e+07
#  3.0000000e+05 6.0000000e+07 6.5000000e+07 7.0000000e+07 1.4000000e+08
#  3.8100000e+07 1.5500000e+07 7.3000000e+06 2.7600000e+07 1.1300000e+07
#  6.9000000e+06 5.5000000e+07 3.5250000e+07 1.9000000e+07 1.8400000e+07
#  2.2500000e+07 1.7150000e+07 2.9000000e+06 4.7000000e+07 4.3200000e+07]
#
#
# Unique values in Salary_Max:
# [4.0000000e+07 2.5000000e+07 1.2000000e+07 3.0000000e+07 6.0000000e+07
#            nan 6.9000000e+06 8.0000000e+06 3.5000000e+07 2.0000000e+07
#  5.0000000e+07 1.5000000e+07 2.2000000e+07 1.0000000e+07 3.3000000e+07
#  1.6000000e+07 4.0000000e+06 3.7500000e+07 1.8000000e+07 1.0000000e+08
#  4.5000000e+07 2.7000000e+07 1.4000000e+07 1.3000000e+07 6.5000000e+07
#  5.5000000e+07 9.0000000e+06 7.0000000e+07 8.0000000e+07 6.2500000e+07
#  9.3333333e+07 1.7000000e+07 2.8000000e+07 3.0000000e+06 2.6000000e+07
#  5.0000000e+06 6.0000000e+06 2.0000000e+06 1.7500000e+07 7.5000000e+06
#  2.4000000e+06 1.1000000e+07 7.0000000e+06 1.5000000e+08 1.9000000e+07
#  4.4000000e+07 3.7000000e+07 3.2000000e+07 3.4000000e+07 2.4000000e+07
#  4.0500000e+07 1.3000000e+08 1.2000000e+06 2.3000000e+07 3.1000000e+07
#  5.0000000e+08 3.8100000e+07 1.0000000e+06 4.3000000e+07 3.6000000e+07
#  3.9000000e+07 4.1000000e+07 1.5000000e+06 5.3000000e+06 7.5000000e+07
#  0.0000000e+00 8.0000000e+08 3.5250000e+07 2.1000000e+06 1.1000000e+08
#  2.5000000e+06 1.0500000e+08 6.3500000e+07 2.7500000e+07 9.0000000e+07
#  3.5000000e+06 6.3000000e+07 1.6000000e+08 1.1250000e+08 6.5000000e+06
#  5.0800000e+07 8.7500000e+07 3.4500000e+07 4.6000000e+07 4.7000000e+07
#  2.9000000e+07 2.1000000e+07 2.9900000e+07 5.7000000e+06 1.2500000e+08
#  4.5000000e+06 2.9400000e+07 4.5000000e+08 5.8750000e+07 5.0000000e+05]
#
#
# Unique values in First_Working_Day_Of_Week:
# [ 2. nan  3.]
#
#
# Unique values in Last_Working_Day_Of_Week:
# [ 6. nan  4.]
#
#
# Unique values in Work_On_Saturday:
# [ 0.  1. nan]
#
#
# Unique values in Work_On_Sunday:
# [ 0.  1. nan]
#
#
# Unique values in Experience_Years:
# ['2 năm' 'Không yêu cầu' 'Dưới 1 năm' '3 năm' '1 năm' '5 năm' 'Trên 5 năm'
#  '4 năm' 'Null']
#
#
# Unique values in Deadline:
# ['31/01/2026' '02/01/2026' '27/12/2025' '01/01/2026' '04/01/2026'
#  '05/01/2026' '28/12/2025' '31/12/2025' '25/12/2025' '24/12/2025'
#  '31/03/2026' '03/01/2026' '23/12/2025' '15/01/2026' '12/12/2025'
#  '29/01/2026' '26/12/2025' '21/12/2025' '10/12/2025' '30/12/2025'
#  '14/12/2025' '19/12/2025' '10/01/2026' '08/01/2026' '18/12/2025'
#  '09/12/2025' 'Null' '16/12/2025' '11/12/2025' '28/02/2026' '28/01/2026'
#  '15/12/2025' '07/01/2026' '30/01/2026' '06/01/2026' '01/02/2026'
#  '29/12/2025' '03/02/2026' '20/12/2025' '30/04/2026' '17/12/2025'
#  '22/12/2025' '14/01/2026' '01/12/2026' '12/01/2026' '09/01/2026'
#  '17/01/2026' '07/02/2026' '03/12/2026' '02/12/2026' '23/01/2026'
#  '30/06/2026' '27/03/2026' '22/01/2026' '12/03/2026' '15/02/2026'
#  '06/03/2026' '21/01/2026' '31/05/2026' '24/10/2026' '19/01/2026'
#  '20/02/2026' '13/12/2025' '25/01/2026' '20/01/2026' 'Hết hạn nộp đơn'
#  '27/04/2026' '01/03/2026' '27/11/2026' '24/01/2026' '31/07/2026'
#  '11/01/2026' '04/02/2026' '18/03/2026']
#
#
# Unique values in Company_Name:
# ['Công ty Cổ phần Hệ thống Công nghệ ETC'
#  'CÔNG TY TNHH CÔNG NGHỆ PHẦN MỀM NASANI'
#  'CÔNG TY CP THIẾT BỊ CÔNG NGHIỆP HUỲNH LONG' ...
#  'Công ty TNHH Thời Trang Quốc Tế Savani'
#  'CÔNG TY TNHH CÔNG NGHỆ PHẦN MỀM DUDI'
#  'VPĐD Công ty Cổ phần Trực tuyến GOSU']
#
#
# Unique values in Company_Industry:
# ['IT - Phần mềm' 'Internet / Online' 'Cơ khí' 'Tư vấn'
#  'Giáo dục / Đào tạo' 'Tài chính' 'Sản xuất'
#  'Marketing / Truyền thông / Quảng cáo' 'Ngân hàng' 'Null' 'Khác'
#  'Giải trí' 'Thiết kế / kiến trúc' 'In ấn / Xuất bản'
#  'Bán lẻ - Hàng tiêu dùng - FMCG' 'Nhà hàng / Khách sạn' 'Du lịch'
#  'Thương mại điện tử' 'Bảo hiểm' 'Viễn thông' 'Tự động hóa' 'Xây dựng'
#  'Dược phẩm / Y tế / Công nghệ sinh học' 'Điện tử / Điện lạnh'
#  'Bất động sản' 'Năng lượng' 'Bảo trì / Sửa chữa'
#  'Agency (Marketing/Advertising)' 'Kế toán / Kiểm toán' 'IT - Phần cứng'
#  'Chứng khoán' 'Xuất nhập khẩu' 'Nhân sự' 'Thương mại tổng hợp'
#  'Logistics - Vận tải' 'Thời trang' 'Agency (Design/Development)'
#  'Nông Lâm Ngư nghiệp' 'Luật']
#
#
# Unique values in Job_Level:
# ['Nhân viên' 'Quản lý / Giám sát' 'Thực tập sinh' 'Trưởng nhóm'
#  'Trưởng/Phó phòng' 'Giám đốc' 'Null' 'Phó giám đốc']
#
#
# Unique values in Academic_Level:
# ['Cao Đẳng trở lên' 'Trung cấp trở lên' 'Đại Học trở lên'
#  'Trung học phổ thông (Cấp 3) trở lên' 'Trung học cơ sở (Cấp 2) trở lên'
#  'Cao học trở lên' 'Null']
#
#
# Unique values in Job_Type:
# ['Toàn thời gian' 'Thực tập' 'Bán thời gian' 'Làm tại nhà' 'Khác'
#  'Thời vụ' 'Null']
#
#
# Unique values in Company_URL:
# ['https://www.topcv.vn/cong-ty/cong-ty-co-phan-he-thong-cong-nghe-etc/200939.html'
#  'https://www.topcv.vn/cong-ty/cong-ty-tnhh-cong-nghe-phan-mem-nasani/233549.html'
#  'https://www.topcv.vn/cong-ty/cong-ty-cp-thiet-bi-cong-nghiep-huynh-long/105523.html'
#  ...
#  'https://www.topcv.vn/cong-ty/cong-ty-tnhh-thoi-trang-quoc-te-savani/96717.html'
#  'https://www.topcv.vn/cong-ty/cong-ty-tnhh-cong-nghe-phan-mem-dudi/206549.html'
#  'https://www.topcv.vn/cong-ty/vpdd-cong-ty-co-phan-truc-tuyen-gosu/21410.html']
#
#
# Unique values in Job_URL:
# ['https://www.topcv.vn/viec-lam/ky-su-trien-khai-du-an-he-thong-postsale-system-thu-nhap-upto-40tr/1949543.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765095807'
#  'https://www.topcv.vn/viec-lam/nhan-vien-tu-van-phat-trien-phan-mem-hcm-thu-nhap-len-den-25tr-thang/1971777.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765095807'
#  'https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-sale-tu-van-ban-hangmay-inluong-cung-12tr-hoa-hong-nhan-viec-ngay/1971328.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765095807'
#  ...
#  'https://www.topcv.vn/viec-lam/frontend-developer-reactjs-mid-senior-level-khong-yeu-cau-tieng-anh-thu-nhap-tu-20-35-trieu-vnd/1945977.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096431'
#  'https://www.topcv.vn/viec-lam/experienced-business-analyst/1891659.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096431'
#  'https://www.topcv.vn/viec-lam/senior-devops-thu-nhap-hap-dan-lam-viec-tai-tan-binh/1946011.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096431']
#
#
# Unique values in Date_Crawl:
# ['09/12/2025 13:13:17' '09/12/2025 13:13:28' '09/12/2025 13:13:41' ...
#  '10/12/2025 07:02:26' '10/12/2025 07:02:46' '10/12/2025 07:03:05']
#
#
# Unique values in Layout_Type:
# ['standard' 'brand_v1' 'brand_v2']

# %% [markdown]
# ## Xử lí nhất quán thuộc tính ngày tháng

# %% [markdown]
# ### Lọc ra các ngày đi làm đầu tuần không phải thứ 2 để xem có gì bất thường

# %%
#Lọc ra các ngày đi làm đầu tuần không phải thứ 2 để xem có gì bất thường
data_API[(data_API['First_Working_Day_Of_Week'] != 2) & data_API['First_Working_Day_Of_Week'].notnull()]
# Out:
#                Job_Title  \
# 2491  Nhân Viên Thiết Kế
#
#                                                                                                                                                                                    Roles  \
# 2491  [MARKETING/PR/QUẢNG CÁO, CÔNG NGHỆ THÔNG TIN, THIẾT KẾ, QUẢNG CÁO/SÁNG TẠO, SOFTWARE DESIGN, THIẾT KẾ ĐỒ HOẠ/GIAO DIỆN/TRẢI NGHIỆM, THIẾT KẾ ĐỒ HỌA (GRAPHIC DESIGN), VIỆC LÀM IT]
#
#       Recruitment_Count       Province Company_Location  Current_Employee_Min  \
# 2491                  2  [HỒ CHÍ MINH]    [HỒ CHÍ MINH]                  25.0
#
#       Current_Employee_Max      Language  \
# 2491                  99.0  [TIẾNG VIỆT]
#
#                                          Tech_Stack Programming_Language  \
# 2491  [PHOTOSHOP, ADOBE ILLUSTRATOR, VIDEO EDITING]                 None
#
#                                       Skills  Total_Work_Hour  Salary_Min  \
# 2491  [THẨM MỸ TỐT, CHỦ ĐỘNG, ĐÚNG DEADLINE]             45.0         NaN
#
#       Salary_Max  First_Working_Day_Of_Week  Last_Working_Day_Of_Week  \
# 2491         NaN                        3.0                       6.0
#
#       Work_On_Saturday  Work_On_Sunday Experience_Years    Deadline  \
# 2491               1.0             0.0            2 năm  28/12/2025
#
#                                 Company_Name Company_Industry  Job_Level  \
# 2491  CÔNG TY CỔ PHẦN ĐẦU TƯ ĐỊA ỐC MINH PHÚ     Bất động sản  Nhân viên
#
#         Academic_Level        Job_Type  \
# 2491  Cao Đẳng trở lên  Toàn thời gian
#
#                                                                          Company_URL  \
# 2491  https://www.topcv.vn/cong-ty/cong-ty-co-phan-dau-tu-dia-oc-minh-phu/56823.html
#
#                                                                                                                                                            Job_URL  \
# 2491  https://www.topcv.vn/viec-lam/nhan-vien-thiet-ke/1968360.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096366
#
#                Date_Crawl Layout_Type
# 2491  09/12/2025 19:13:23    standard

# %% [markdown]
# ### Lọc ra các ngày đi làm cuối tuần không phải thứ 6 để xem có gì bất thường

# %%
#Lọc ra các ngày đi làm cuối tuần không phải thứ 6 để xem có gì bất thường
data_API[(data_API['Last_Working_Day_Of_Week'] != 6) & data_API['Last_Working_Day_Of_Week'].notnull()]
# Out:
#                                  Job_Title  \
# 3424  Technical Support (Weekend Rotation)
#
#                                                                             Roles  \
# 3424  [CÔNG NGHỆ THÔNG TIN, SOFTWARE ENGINEERING, SOFTWARE ENGINEER, VIỆC LÀM IT]
#
#       Recruitment_Count   Province Company_Location  Current_Employee_Min  \
# 3424                  1  [ĐÀ NẴNG]        [ĐÀ NẴNG]                 100.0
#
#       Current_Employee_Max                 Language  \
# 3424                 499.0  [TIẾNG VIỆT, TIẾNG ANH]
#
#                                                                                                                                       Tech_Stack  \
# 3424  [HTTP, REST, JSON, POSTGRESQL, REDIS, MONGODB, DATADOG, GRAFANA LOKI, LINUX, AWS, GCP, CLOUDWATCH, S3, IAM, XCODE, ANDROID LOGCAT, DEVOPS]
#
#                 Programming_Language  \
# 3424  [SQL, NOSQL, PYTHON, BASH, GO]
#
#                                                                                                                                                                                        Skills  \
# 3424  [TECHNICAL SUPPORT, QUALITY ASSURANCE, CUSTOMER FACING, DEBUGGING, PROBLEM-SOLVING, OWNERSHIP, COMMUNICATION, MOBILE DEBUGGING, SCRIPTING, AUTOMATION, HARDWARE AND SOFTWARE KNOWLEDGE]
#
#       Total_Work_Hour  Salary_Min  Salary_Max  First_Working_Day_Of_Week  \
# 3424             47.5         NaN         NaN                        2.0
#
#       Last_Working_Day_Of_Week  Work_On_Saturday  Work_On_Sunday  \
# 3424                       4.0               1.0             1.0
#
#      Experience_Years    Deadline  \
# 3424            1 năm  28/02/2026
#
#                                                           Company_Name  \
# 3424  Văn phòng đại diện Everfit Technologies Inc tại thành phố ĐàNẵng
#
#      Company_Industry  Job_Level   Academic_Level        Job_Type  \
# 3424    IT - Phần mềm  Nhân viên  Đại Học trở lên  Toàn thời gian
#
#                                                                                                     Company_URL  \
# 3424  https://www.topcv.vn/cong-ty/van-phong-dai-dien-everfit-technologies-inc-tai-thanh-pho-danang/131746.html
#
#                                                                                                                                                                            Job_URL  \
# 3424  https://www.topcv.vn/viec-lam/technical-support-weekend-rotation/1852837.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096578
#
#                Date_Crawl Layout_Type
# 3424  10/12/2025 00:59:27    standard

# %% [markdown]
# #### Chỉnh tất cả ngày đi làm có liên quan đến thứ Bảy thành True ở cột 'Work_On_Saturday'

# %%
#Chỉnh tất cả ngày đi làm có liên quan đến thứ Bảy thành True ở cột 'Work_On_Saturday'
mask = (data_API['First_Working_Day_Of_Week'] == 7) | (data_API['Last_Working_Day_Of_Week'] == 7)
data_API.loc[mask, 'Work_On_Saturday'] = True
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_28752\1658121745.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data_API.loc[mask, 'Work_On_Saturday'] = True

# %% [markdown]
# #### Chỉnh tất cả ngày đi làm có liên quan đến Chủ Nhật thành True ở cột 'Work_On_Sunday'

# %%
#Chỉnh tất cả ngày đi làm có liên quan đến Chủ Nhật thành True ở cột 'Work_On_Sunday'
mask = (data_API['First_Working_Day_Of_Week'] == 1) | (data_API['Last_Working_Day_Of_Week'] == 1)
data_API.loc[mask, 'Work_On_Sunday'] = True
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_28752\220305482.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data_API.loc[mask, 'Work_On_Sunday'] = True

# %% [markdown]
# ### Thay thế giá trị '1' (tức Chủ Nhật)  với '7' (thứ Bảy) thành '2' (thứ Hai) trong thuộc tính 'First_Working_Day_Of_Week' vì đang tính ngày trong tuần trong thuộc tính này

# %%
#Thay thế giá trị '1' (tức Chủ Nhật)  với '7' (thứ Bảy) thành '2' (thứ Hai) trong thuộc tính 'First_Working_Day_Of_Week' vì đang tính ngày trong tuần trong thuộc tính này
data_API['First_Working_Day_Of_Week'] = data_API['First_Working_Day_Of_Week'].replace([1, 7], 2)

# %% [markdown]
# ### Thay thế giá trị '1' (tức Chủ Nhật)  với '7' (thứ Bảy) thành '6' (thứ 6) trong thuộc tính 'Last_Working_Day_Of_Week' vì đang tính ngày trong tuần trong thuộc tính này

# %%
# # Thay thế giá trị '1' (tức Chủ Nhật)  với '7' (thứ Bảy) thành '6' (thứ 6) trong thuộc tính 'Last_Working_Day_Of_Week' vì đang tính ngày trong tuần trong thuộc tính này
data_API['Last_Working_Day_Of_Week'] = data_API['Last_Working_Day_Of_Week'].replace([1, 7], 6)

# %% [markdown]
# ## Kiểm tra lại sự nhất quán

# %%
#Xem giá trị unique của các cột 'First_Working_Day_Of_Week', 'Last_Working_Day_Of_Week'
for col in ['First_Working_Day_Of_Week', 'Last_Working_Day_Of_Week']:
    print(f"Unique values in {col}:")
    print(data_API[col].unique())
    print("\n")
# Out:
# Unique values in First_Working_Day_Of_Week:
# [ 2. nan  3.]
#
#
# Unique values in Last_Working_Day_Of_Week:
# [ 6. nan  4.]

# %%
#Lọc ra các ngày đi làm đầu tuần không phải thứ 2 để xem có gì bất thường
data_API[(data_API['First_Working_Day_Of_Week'] != 2) & data_API['First_Working_Day_Of_Week'].notnull()]
# Out:
#                Job_Title  \
# 2491  Nhân Viên Thiết Kế
#
#                                                                                                                                                                                    Roles  \
# 2491  [MARKETING/PR/QUẢNG CÁO, CÔNG NGHỆ THÔNG TIN, THIẾT KẾ, QUẢNG CÁO/SÁNG TẠO, SOFTWARE DESIGN, THIẾT KẾ ĐỒ HOẠ/GIAO DIỆN/TRẢI NGHIỆM, THIẾT KẾ ĐỒ HỌA (GRAPHIC DESIGN), VIỆC LÀM IT]
#
#       Recruitment_Count       Province Company_Location  Current_Employee_Min  \
# 2491                  2  [HỒ CHÍ MINH]    [HỒ CHÍ MINH]                  25.0
#
#       Current_Employee_Max      Language  \
# 2491                  99.0  [TIẾNG VIỆT]
#
#                                          Tech_Stack Programming_Language  \
# 2491  [PHOTOSHOP, ADOBE ILLUSTRATOR, VIDEO EDITING]                 None
#
#                                       Skills  Total_Work_Hour  Salary_Min  \
# 2491  [THẨM MỸ TỐT, CHỦ ĐỘNG, ĐÚNG DEADLINE]             45.0         NaN
#
#       Salary_Max  First_Working_Day_Of_Week  Last_Working_Day_Of_Week  \
# 2491         NaN                        3.0                       6.0
#
#      Work_On_Saturday Work_On_Sunday Experience_Years    Deadline  \
# 2491              1.0            0.0            2 năm  28/12/2025
#
#                                 Company_Name Company_Industry  Job_Level  \
# 2491  CÔNG TY CỔ PHẦN ĐẦU TƯ ĐỊA ỐC MINH PHÚ     Bất động sản  Nhân viên
#
#         Academic_Level        Job_Type  \
# 2491  Cao Đẳng trở lên  Toàn thời gian
#
#                                                                          Company_URL  \
# 2491  https://www.topcv.vn/cong-ty/cong-ty-co-phan-dau-tu-dia-oc-minh-phu/56823.html
#
#                                                                                                                                                            Job_URL  \
# 2491  https://www.topcv.vn/viec-lam/nhan-vien-thiet-ke/1968360.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096366
#
#                Date_Crawl Layout_Type
# 2491  09/12/2025 19:13:23    standard

# %%
#Lọc ra các ngày đi làm cuối tuần không phải thứ 6 để xem có gì bất thường
data_API[(data_API['Last_Working_Day_Of_Week'] != 6) & data_API['Last_Working_Day_Of_Week'].notnull()]
# Out:
#                                  Job_Title  \
# 3424  Technical Support (Weekend Rotation)
#
#                                                                             Roles  \
# 3424  [CÔNG NGHỆ THÔNG TIN, SOFTWARE ENGINEERING, SOFTWARE ENGINEER, VIỆC LÀM IT]
#
#       Recruitment_Count   Province Company_Location  Current_Employee_Min  \
# 3424                  1  [ĐÀ NẴNG]        [ĐÀ NẴNG]                 100.0
#
#       Current_Employee_Max                 Language  \
# 3424                 499.0  [TIẾNG VIỆT, TIẾNG ANH]
#
#                                                                                                                                       Tech_Stack  \
# 3424  [HTTP, REST, JSON, POSTGRESQL, REDIS, MONGODB, DATADOG, GRAFANA LOKI, LINUX, AWS, GCP, CLOUDWATCH, S3, IAM, XCODE, ANDROID LOGCAT, DEVOPS]
#
#                 Programming_Language  \
# 3424  [SQL, NOSQL, PYTHON, BASH, GO]
#
#                                                                                                                                                                                        Skills  \
# 3424  [TECHNICAL SUPPORT, QUALITY ASSURANCE, CUSTOMER FACING, DEBUGGING, PROBLEM-SOLVING, OWNERSHIP, COMMUNICATION, MOBILE DEBUGGING, SCRIPTING, AUTOMATION, HARDWARE AND SOFTWARE KNOWLEDGE]
#
#       Total_Work_Hour  Salary_Min  Salary_Max  First_Working_Day_Of_Week  \
# 3424             47.5         NaN         NaN                        2.0
#
#       Last_Working_Day_Of_Week Work_On_Saturday Work_On_Sunday  \
# 3424                       4.0              1.0            1.0
#
#      Experience_Years    Deadline  \
# 3424            1 năm  28/02/2026
#
#                                                           Company_Name  \
# 3424  Văn phòng đại diện Everfit Technologies Inc tại thành phố ĐàNẵng
#
#      Company_Industry  Job_Level   Academic_Level        Job_Type  \
# 3424    IT - Phần mềm  Nhân viên  Đại Học trở lên  Toàn thời gian
#
#                                                                                                     Company_URL  \
# 3424  https://www.topcv.vn/cong-ty/van-phong-dai-dien-everfit-technologies-inc-tai-thanh-pho-danang/131746.html
#
#                                                                                                                                                                            Job_URL  \
# 3424  https://www.topcv.vn/viec-lam/technical-support-weekend-rotation/1852837.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096578
#
#                Date_Crawl Layout_Type
# 3424  10/12/2025 00:59:27    standard

# %% [markdown]
# Dữ liệu ngày tháng đã được nhất quán về ngày đi làm

# %% [markdown]
# # Chuẩn hóa giá trị None (missing values)

# %%
list_cols = ['Tech_Stack', 'Programming_Language', 'Province', 'Language', 'Roles', 'Company_Location']

# Chuyển np.ndarray về list trước
for col in list_cols:
    data_API[col] = data_API[col].apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x)

# Thay thế các phần tử có danh sách rỗng bằng None
for col in list_cols:
    data_API[col] = data_API[col].apply(lambda x: None if isinstance(x, list) and len(x) == 0 else x)

# Thay thế các khoảng trắng trong các cột có kiểu dữ liệu list là None
for col in list_cols:
    data_API[col] = data_API[col].apply(lambda x: None if isinstance(x, list) and all(item == '' for item in x) else x)
# Thay thế khoảng trắng bằng None
data_API = data_API.replace(['', 'NULL', 'Null', 'Hết hạn nộp đơn'], None)
data_API = data_API.replace('Khác', 'UNKNOWN')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_28752\556460669.py:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_API = data_API.replace('Khác', 'UNKNOWN')

# %%
#Kiểm tra kiểu dữ liệu và đếm số lượng kiểu dữ liệu trong 1 cột
for col in data_API.columns:
    print(data_API[col].apply(type).value_counts())
# Out:
# Job_Title
# <class 'str'>    3458
# Name: count, dtype: int64
# Roles
# <class 'list'>        3455
# <class 'NoneType'>       3
# Name: count, dtype: int64
# Recruitment_Count
# <class 'int'>    3458
# Name: count, dtype: int64
# Province
# <class 'list'>        3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Company_Location
# <class 'list'>        3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Current_Employee_Min
# <class 'float'>    3458
# Name: count, dtype: int64
# Current_Employee_Max
# <class 'float'>    3458
# Name: count, dtype: int64
# Language
# <class 'list'>        3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Tech_Stack
# <class 'list'>        3274
# <class 'NoneType'>     184
# Name: count, dtype: int64
# Programming_Language
# <class 'NoneType'>    2133
# <class 'list'>        1325
# Name: count, dtype: int64
# Skills
# <class 'list'>        3435
# <class 'NoneType'>      23
# Name: count, dtype: int64
# Total_Work_Hour
# <class 'float'>    3458
# Name: count, dtype: int64
# Salary_Min
# <class 'float'>    3458
# Name: count, dtype: int64
# Salary_Max
# <class 'float'>    3458
# Name: count, dtype: int64
# First_Working_Day_Of_Week
# <class 'float'>    3458
# Name: count, dtype: int64
# Last_Working_Day_Of_Week
# <class 'float'>    3458
# Name: count, dtype: int64
# Work_On_Saturday
# <class 'float'>    3458
# Name: count, dtype: int64
# Work_On_Sunday
# <class 'float'>    3458
# Name: count, dtype: int64
# Experience_Years
# <class 'str'>         3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Deadline
# <class 'str'>         3310
# <class 'NoneType'>     148
# Name: count, dtype: int64
# Company_Name
# <class 'str'>         3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Company_Industry
# <class 'str'>         3299
# <class 'NoneType'>     159
# Name: count, dtype: int64
# Job_Level
# <class 'str'>         3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Academic_Level
# <class 'str'>         3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Job_Type
# <class 'str'>         3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Company_URL
# <class 'str'>         3456
# <class 'NoneType'>       2
# Name: count, dtype: int64
# Job_URL
# <class 'str'>    3458
# Name: count, dtype: int64
# Date_Crawl
# <class 'str'>    3458
# Name: count, dtype: int64
# Layout_Type
# <class 'str'>    3458
# Name: count, dtype: int64

# %%
# Kiểm tra missing values
data_API.isnull().sum().sort_values(ascending=False)
# Out:
# Programming_Language         2133
# Salary_Min                   1629
# Salary_Max                   1366
# Current_Employee_Max          544
# Total_Work_Hour               510
# First_Working_Day_Of_Week     271
# Last_Working_Day_Of_Week      271
# Work_On_Saturday              206
# Work_On_Sunday                205
# Tech_Stack                    184
# Current_Employee_Min          159
# Company_Industry              159
# Deadline                      148
# Skills                         23
# Roles                           3
# Company_Name                    2
# Province                        2
# Company_Location                2
# Job_Level                       2
# Language                        2
# Experience_Years                2
# Company_URL                     2
# Job_Type                        2
# Academic_Level                  2
# Recruitment_Count               0
# Job_Title                       0
# Job_URL                         0
# Date_Crawl                      0
# Layout_Type                     0
# dtype: int64

# %% [markdown]
# # Thống kê dữ liệu số

# %%
# Basic numeric statistics
data_API.describe().T
# Out:
#                             count          mean           std       min  \
# Recruitment_Count          3458.0  2.233950e+00  2.894027e+00       1.0
# Current_Employee_Min       3299.0  5.263086e+02  1.636432e+03       1.0
# Current_Employee_Max       2914.0  3.608308e+02  3.211401e+02       9.0
# Total_Work_Hour            2948.0  4.767152e+01  4.195885e+00       0.0
# Salary_Min                 1829.0  1.427952e+07  1.102058e+07  300000.0
# Salary_Max                 2092.0  2.492721e+07  2.683239e+07       0.0
# First_Working_Day_Of_Week  3187.0  2.000314e+00  1.771369e-02       2.0
# Last_Working_Day_Of_Week   3187.0  5.999372e+00  3.542737e-02       4.0
# Work_On_Saturday           3252.0  4.028290e-01  4.905424e-01       0.0
# Work_On_Sunday             3253.0  1.137412e-02  1.060575e-01       0.0
#
#                                   25%         50%          75%          max
# Recruitment_Count                 1.0         1.0         2.00         50.0
# Current_Employee_Min             25.0       100.0       100.00      10000.0
# Current_Employee_Max             99.0       499.0       499.00       1000.0
# Total_Work_Hour                  45.0        47.5        49.17         93.5
# Salary_Min                  9000000.0  12000000.0  17500000.00  250000000.0
# Salary_Max                 15000000.0  20000000.0  30000000.00  800000000.0
# First_Working_Day_Of_Week         2.0         2.0         2.00          3.0
# Last_Working_Day_Of_Week          6.0         6.0         6.00          6.0
# Work_On_Saturday                  0.0         0.0         1.00          1.0
# Work_On_Sunday                    0.0         0.0         0.00          1.0

# %%
data_API[data_API['Salary_Max']==data_API['Salary_Max'].max()]
# Out:
#          Job_Title  \
# 1532  Nhân Viên SE
#
#                                                                                                   Roles  \
# 1532  [CÔNG NGHỆ THÔNG TIN, CÔNG NGHỆ THÔNG TIN KHÁC, CHUYÊN MÔN CÔNG NGHỆ THÔNG TIN KHÁC, VIỆC LÀM IT]
#
#       Recruitment_Count      Province Company_Location  Current_Employee_Min  \
# 1532                  2  [NƯỚC NGOÀI]         [HÀ NỘI]                 100.0
#
#       Current_Employee_Max                  Language  \
# 1532                 499.0  [TIẾNG NHẬT, TIẾNG VIỆT]
#
#                                      Tech_Stack  \
# 1532  [C#, NODEJS, ANGULARJS, AI, JAVA, PYTHON]
#
#                 Programming_Language  \
# 1532  [C#, JAVASCRIPT, JAVA, PYTHON]
#
#                                                                                                                Skills  \
# 1532  [QUẢN LÝ DỰ ÁN, KỸ NĂNG GIẢI QUYẾT VẤN ĐỀ, KHẢ NĂNG LÀM VIỆC NHÓM, KIẾN THỨC VỀ CẤU TRÚC DỮ LIỆU VÀ GIẢI THUẬT]
#
#       Total_Work_Hour  Salary_Min   Salary_Max  First_Working_Day_Of_Week  \
# 1532              NaN         NaN  800000000.0                        2.0
#
#       Last_Working_Day_Of_Week  Work_On_Saturday  Work_On_Sunday  \
# 1532                       6.0               0.0             0.0
#
#      Experience_Years    Deadline                    Company_Name  \
# 1532            1 năm  31/12/2025  Công ty Cổ phần VNEXT SOFTWARE
#
#      Company_Industry  Job_Level   Academic_Level        Job_Type  \
# 1532    IT - Phần mềm  Nhân viên  Đại Học trở lên  Toàn thời gian
#
#                                                                 Company_URL  \
# 1532  https://www.topcv.vn/cong-ty/cong-ty-co-phan-vnext-software/1469.html
#
#                                                                                                                                                      Job_URL  \
# 1532  https://www.topcv.vn/viec-lam/nhan-vien-se/1800127.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096150
#
#                Date_Crawl Layout_Type
# 1532  09/12/2025 18:27:23    standard

# %% [markdown]
# # Thống kê dữ liệu chuỗi

# %% [markdown]
# ## Chuẩn hóa in hoa các dữ liệu dạng VĂN BẢN

# %%
cols = data_API.columns.difference(['Job_URL', 'Company_URL'])
for col in cols:
    if data_API[col].apply(lambda x: isinstance(x, list)).any():
        # Áp dụng cho từng phần tử trong mảng
        data_API[col] = data_API[col].apply(
            lambda arr: [str(i).strip().upper() for i in arr] if isinstance(arr, list) else arr
        )
    else:
        # Áp dụng cho chuỗi thông thường
        data_API[col] = data_API[col].apply(
            lambda x: x.strip().upper() if isinstance(x, str) else x
        )
data_API.head()
# Out:
#                                             Job_Title  \
# 0   KỸ SƯ TRIỂN KHAI DỰ ÁN HỆ THỐNG (POSTSALE SYSTEM)
# 1                NHÂN VIÊN TƯ VẤN PHÁT TRIỂN PHẦN MỀM
# 2  NHÂN VIÊN KINH DOANH/SALE/TƯ VẤN BÁN HÀNG (MÁY IN)
# 3                                    BUSINESS ANALYST
# 4        NHÂN VIÊN KINH DOANH PHẦN MỀM ERP/ SALES ERP
#
#                                                                                                                                       Roles  \
# 0                                                     [CÔNG NGHỆ THÔNG TIN, IT INFRASTRUCTURE AND OPERATIONS, SYSTEM ENGINEER, VIỆC LÀM IT]
# 1                      [KINH DOANH/BÁN HÀNG, MARKETING/PR/QUẢNG CÁO, SALES DỊCH VỤ QUẢNG CÁO/TRIỂN LÃM/SỰ KIỆN, MARKETING, SALES MARKETING]
# 2  [KINH DOANH/BÁN HÀNG, CÔNG NGHỆ THÔNG TIN, SALES KỸ THUẬT (SALES ENGINEER), CÔNG NGHỆ THÔNG TIN KHÁC, BÁN HÀNG KỸ THUẬT IT, VIỆC LÀM IT]
# 3                                            [CÔNG NGHỆ THÔNG TIN, PRODUCT MANAGEMENT, BUSINESS ANALYST (PHÂN TÍCH NGHIỆP VỤ), VIỆC LÀM IT]
# 4                                           [KINH DOANH/BÁN HÀNG, CÔNG NGHỆ THÔNG TIN, SALES IT PHẦN MỀM, KINH DOANH PHẦN MỀM, VIỆC LÀM IT]
#
#    Recruitment_Count               Province Company_Location  \
# 0                 10  [HÀ NỘI, HỒ CHÍ MINH]         [HÀ NỘI]
# 1                  8          [HỒ CHÍ MINH]    [HỒ CHÍ MINH]
# 2                  2          [HỒ CHÍ MINH]    [HỒ CHÍ MINH]
# 3                  1               [HÀ NỘI]         [HÀ NỘI]
# 4                  1          [HỒ CHÍ MINH]    [HỒ CHÍ MINH]
#
#    Current_Employee_Min  Current_Employee_Max  \
# 0                 500.0                1000.0
# 1                1000.0                   NaN
# 2                  25.0                  99.0
# 3                  25.0                  99.0
# 4                  25.0                  99.0
#
#                                Language  \
# 0               [TIẾNG VIỆT, TIẾNG ANH]
# 1                          [TIẾNG VIỆT]
# 2                          [TIẾNG VIỆT]
# 3               [TIẾNG VIỆT, TIẾNG ANH]
# 4  [TIẾNG VIỆT, TIẾNG TRUNG, TIẾNG ANH]
#
#                                                                                                                                                                                                 Tech_Stack  \
# 0  [VMWARE, CITRIX, HYPER-V, HPE, IBM, DELL EMC, ACTIVE DIRECTORY, DNS, MAIL SERVER, PROXY, SAN, NAS, NETAPP, HP, FUJITSU, EMC, CLOUD, ORACLE, VMWARE CERTIFIED ASSOCIATE (VCA), MCSA, NETWORKING, WIND...
# 1                                                                                  [WEBSITE, PHẦN MỀM BÁN HÀNG, PHẦN MỀM VĂN PHÒNG, PHẦN MỀM QUẢN LÝ TÀI LIỆU, HỆ THỐNG EMAIL, MẠNG LƯỚI, QUẢN LÝ WEBSITE]
# 2                                                                                                                                                                                                  [EXCEL]
# 3                                                                                       [CYBER SECURITY, DATA MODELING, MOCKUPS, PROTOTYPES, AGILE, UX/UI, DESIGN THINKING, TOÁN - TIN, KHOA HỌC MÁY TÍNH]
# 4                                                                                                                                                                                               [ERP, CRM]
#
#   Programming_Language  \
# 0                [SQL]
# 1                 None
# 2                 None
# 3                 None
# 4                 None
#
#                                                                                                                                                                                                     Skills  \
# 0  [GIÁM SÁT THI CÔNG, QUẢN LÝ DỰ ÁN, VIẾT TÀI LIỆU KỸ THUẬT, TƯ VẤN GIẢI PHÁP, XỬ LÝ SỰ CỐ, QUẢN TRỊ HỆ THỐNG, BẢO TRÌ HỆ THỐNG, NGHIÊN CỨU SẢN PHẨM, ĐỌC HIỂU TÀI LIỆU KỸ THUẬT, GIAO TIẾP, GIẢI QUYẾ...
# 1  [TƯ VẤN KHÁCH HÀNG, KÝ KẾT HỢP ĐỒNG, XÂY DỰNG MỐI QUAN HỆ, CHĂM SÓC KHÁCH HÀNG, GIAO TIẾP, KINH DOANH PHẦN MỀM, KIẾN THỨC VỀ CÔNG NGHỆ THÔNG TIN, HIỂU BIẾT VỀ THỊ TRƯỜDNG CÔNG NGHỆ THÔNG TIN, AM H...
# 2                                                                                                                               [KỸ NĂNG GIAO TIẾP, KỸ NĂNG LÀM VIỆC NHÓM, QUẢN TRỊ KINH DOANH, MARKETING]
# 3  [PHÂN TÍCH NGHIỆP VỤ, PHÂN TÍCH DỮ LIỆU, TƯ DUY LOGIC, KỸ NĂNG VIẾT, KỸ NĂNG TRÌNH BÀY, PHÂN TÍCH TRẢI NGHIỆM KHÁCH HÀNG, THIẾT KẾ HỆ THỐNG, GIAO TIẾP, PHỐI HỢP ĐA PHÒNG BAN, LÀM VIỆC NHÓM, CHỊU Đ...
# 4                                                                      [XÂY DỰNG MỐI QUAN HỆ, GIAO TIẾP, PHÂN TÍCH NGHIỆP VỤ, THUYẾT TRÌNH, ĐÀM PHÁN KINH DOANH, CHỊU ĐƯỢC ÁP LỰC, KHẢ NĂNG HỌC HỎI NHANH]
#
#    Total_Work_Hour  Salary_Min  Salary_Max  First_Working_Day_Of_Week  \
# 0             45.0  20000000.0  40000000.0                        2.0
# 1             49.0  10000000.0  25000000.0                        2.0
# 2              NaN   8000000.0  12000000.0                        NaN
# 3             50.0  25000000.0  30000000.0                        2.0
# 4             45.0  30000000.0  60000000.0                        2.0
#
#    Last_Working_Day_Of_Week  Work_On_Saturday  Work_On_Sunday  \
# 0                       6.0               0.0             0.0
# 1                       6.0               1.0             0.0
# 2                       NaN               0.0             0.0
# 3                       6.0               0.0             0.0
# 4                       6.0               0.0             0.0
#
#   Experience_Years    Deadline  \
# 0            2 NĂM  31/01/2026
# 1    KHÔNG YÊU CẦU  02/01/2026
# 2       DƯỚI 1 NĂM  02/01/2026
# 3            3 NĂM  27/12/2025
# 4            3 NĂM  01/01/2026
#
#                                                   Company_Name  \
# 0                       CÔNG TY CỔ PHẦN HỆ THỐNG CÔNG NGHỆ ETC
# 1                       CÔNG TY TNHH CÔNG NGHỆ PHẦN MỀM NASANI
# 2                   CÔNG TY CP THIẾT BỊ CÔNG NGHIỆP HUỲNH LONG
# 3                      CÔNG TY CỔ PHẦN CÔNG NGHỆ THÔNG MINH GX
# 4  CÔNG TY TNHH KINGDEE INTERNATIONAL SOFTWARE GROUP (VIETNAM)
#
#     Company_Industry  Job_Level     Academic_Level        Job_Type  \
# 0      IT - PHẦN MỀM  NHÂN VIÊN   CAO ĐẲNG TRỞ LÊN  TOÀN THỜI GIAN
# 1  INTERNET / ONLINE  NHÂN VIÊN  TRUNG CẤP TRỞ LÊN  TOÀN THỜI GIAN
# 2             CƠ KHÍ  NHÂN VIÊN  TRUNG CẤP TRỞ LÊN  TOÀN THỜI GIAN
# 3      IT - PHẦN MỀM  NHÂN VIÊN    ĐẠI HỌC TRỞ LÊN  TOÀN THỜI GIAN
# 4      IT - PHẦN MỀM  NHÂN VIÊN   CAO ĐẲNG TRỞ LÊN  TOÀN THỜI GIAN
#
#                                                                                           Company_URL  \
# 0                     https://www.topcv.vn/cong-ty/cong-ty-co-phan-he-thong-cong-nghe-etc/200939.html
# 1                     https://www.topcv.vn/cong-ty/cong-ty-tnhh-cong-nghe-phan-mem-nasani/233549.html
# 2                 https://www.topcv.vn/cong-ty/cong-ty-cp-thiet-bi-cong-nghiep-huynh-long/105523.html
# 3                    https://www.topcv.vn/cong-ty/cong-ty-co-phan-cong-nghe-thong-minh-gx/243568.html
# 4  https://www.topcv.vn/cong-ty/cong-ty-tnhh-kingdee-international-software-group-vietnam/237459.html
#
#                                                                                                                                                                                                    Job_URL  \
# 0  https://www.topcv.vn/viec-lam/ky-su-trien-khai-du-an-he-thong-postsale-system-thu-nhap-upto-40tr/1949543.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_17...
# 1  https://www.topcv.vn/viec-lam/nhan-vien-tu-van-phat-trien-phan-mem-hcm-thu-nhap-len-den-25tr-thang/1971777.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_...
# 2  https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-sale-tu-van-ban-hangmay-inluong-cung-12tr-hoa-hong-nhan-viec-ngay/1971328.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4V...
# 3  https://www.topcv.vn/viec-lam/business-analyst-tu-3-nam-kinh-nghiem-thu-nhap-upto-30m-tai-ha-noi/1966948.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_17...
# 4  https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-phan-mem-erp-sales-erp-thu-nhap-cao-upto-30-60-trieu-nhan-viec-ngay-tai-quan-7/1891406.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4Gqa...
#
#             Date_Crawl Layout_Type
# 0  09/12/2025 13:13:17    STANDARD
# 1  09/12/2025 13:13:28    STANDARD
# 2  09/12/2025 13:13:41    STANDARD
# 3  09/12/2025 13:13:50    STANDARD
# 4  09/12/2025 13:14:03    STANDARD

# %% [markdown]
# ### Thống kê dữ liệu string

# %%
# Thống kê cơ bản cho các cột không phải là list
data_API.drop(columns=list_cols).describe(include='object').T.sort_values(by='unique', ascending=False)
# Out:
#                  count unique  \
# Job_URL           3458   3458
# Skills            3435   3427
# Date_Crawl        3458   3395
# Job_Title         3458   2529
# Company_URL       3456   1825
# Company_Name      3456   1756
# Deadline          3310     72
# Company_Industry  3299     38
# Experience_Years  3456      8
# Job_Level         3456      7
# Academic_Level    3456      6
# Job_Type          3456      6
# Layout_Type       3458      3
#
#                                                                                                                                                                                                              top  \
# Job_URL           https://www.topcv.vn/viec-lam/senior-devops-thu-nhap-hap-dan-lam-viec-tai-tan-binh/1946011.html?ta_source=JobSearchList_LinkDetail&u_sr_id=vhbFIo4GqaZLKyp8jn9Cn4VEepc9rh4hVUZWiqL6_1765096431
# Skills                                                                                            [CHỦ ĐỘNG, TRÁCH NHIỆM CAO TRONG CÔNG VIỆC, LÀM VIỆC NHÓM, GIAO TIẾP TỐT, TƯ DUY PHÂN TÍCH, GIẢI QUYẾT VẤN ĐỀ]
# Date_Crawl                                                                                                                                                                                   09/12/2025 16:37:18
# Job_Title                                                                                                                                                                                       GRAPHIC DESIGNER
# Company_URL                                                                                                                          https://www.topcv.vn/cong-ty/cong-ty-co-phan-cong-nghe-alphaway/201267.html
# Company_Name                                                                                                                                                                  CÔNG TY CỔ PHẦN CÔNG NGHỆ ALPHAWAY
# Deadline                                                                                                                                                                                              31/12/2025
# Company_Industry                                                                                                                                                                                   IT - PHẦN MỀM
# Experience_Years                                                                                                                                                                                           1 NĂM
# Job_Level                                                                                                                                                                                              NHÂN VIÊN
# Academic_Level                                                                                                                                                                                   ĐẠI HỌC TRỞ LÊN
# Job_Type                                                                                                                                                                                          TOÀN THỜI GIAN
# Layout_Type                                                                                                                                                                                             STANDARD
#
#                   freq
# Job_URL              1
# Skills               2
# Date_Crawl           2
# Job_Title           55
# Company_URL         64
# Company_Name        70
# Deadline           705
# Company_Industry  1715
# Experience_Years   851
# Job_Level         2363
# Academic_Level    2094
# Job_Type          3323
# Layout_Type       3300

# %% [markdown]
# ### Thống kê dữ liệu list 'Tech_Stack', 'Programming_Language', 'Province', 'Language'

# %%
# Giả sử cột Tech_Stack, Programming_Language, Province, Language chứa các list
flattened_Tech = list(itertools.chain.from_iterable(data_API['Tech_Stack'].dropna()))
flattened_Programming = list(itertools.chain.from_iterable(data_API['Programming_Language'].dropna()))
flattened_Province = list(itertools.chain.from_iterable(data_API['Province'].dropna()))
flattened_Language = list(itertools.chain.from_iterable(data_API['Language'].dropna()))

# Đếm số lượng unique cho từng giá trị
tech_counts = pd.Series(flattened_Tech).value_counts().reset_index()
tech_counts.columns = ['Tech_Stack', 'Count']

programming_counts = pd.Series(flattened_Programming).value_counts().reset_index()
programming_counts.columns = ['Programming_Language', 'Count']

province_counts = pd.Series(flattened_Province).value_counts().reset_index()
province_counts.columns = ['Province', 'Count']

language_counts = pd.Series(flattened_Language).value_counts().reset_index()
language_counts.columns = ['Language', 'Count']

# Hiển thị từng DataFrame với tiêu đề rõ ràng
print("\nUnique Programming Languages và số lượng:")
display(programming_counts)
print("Unique Tech Stack và số lượng:")
display(tech_counts)
print("\nUnique Provinces và số lượng:")
display(province_counts)
print("\nUnique Languages và số lượng:")
display(language_counts)
# Out:
# Unique Programming Languages và số lượng:
#     Programming_Language  Count
# 0                    SQL    798
# 1                 PYTHON    436
# 2             JAVASCRIPT    362
# 3                   JAVA    328
# 4                  NOSQL    289
# ..                   ...    ...
# 100            ANGULARJS      1
# 101              EXPRESS      1
# 102          SPRING BOOT      1
# 103     SPRING FRAMEWORK      1
# 104           BASH SHELL      1
#
# [105 rows x 2 columns]
# Unique Tech Stack và số lượng:
#                    Tech_Stack  Count
# 0                   PHOTOSHOP    475
# 1                          AI    436
# 2                 ILLUSTRATOR    376
# 3                         GIT    367
# 4                       CI/CD    317
# ...                       ...    ...
# 6055    TCP/IP PROTOCOL SUITE      1
# 6056  NETWORK TROUBLESHOOTING      1
# 6057             QUEUE SYSTEM      1
# 6058          API WEBSERVICES      1
# 6059         NHẬT KÝ HỆ THỐNG      1
#
# [6060 rows x 2 columns]
# Unique Provinces và số lượng:
#                  Province  Count
# 0                  HÀ NỘI   2179
# 1             HỒ CHÍ MINH   1089
# 2                 ĐÀ NẴNG    120
# 3                 CẦN THƠ     33
# 4               HẢI PHÒNG     30
# 5                BẮC NINH     30
# 6                ĐỒNG NAI     29
# 7                HƯNG YÊN     21
# 8                     HUẾ     18
# 9             THÁI NGUYÊN     18
# 10               TÂY NINH     17
# 11              THANH HÓA     17
# 12                NGHỆ AN     16
# 13              KHÁNH HÒA     14
# 14             NƯỚC NGOÀI     14
# 15              NINH BÌNH     12
# 16               LÂM ĐỒNG     11
# 17                PHÚ THỌ      9
# 18               NHẬT BẢN      7
# 19               AN GIANG      7
# 20             QUẢNG NINH      7
# 21             QUẢNG NGÃI      6
# 22              ĐỒNG THÁP      6
# 23        BÀ RỊA-VŨNG TÀU      6
# 24  THÀNH PHỐ HỒ CHÍ MINH      5
# 25                ĐẮK LẮK      5
# 26              HẢI DƯƠNG      4
# 27               CAO BẰNG      3
# 28                HÀ TĨNH      3
# 29                GIA LAI      3
# 30                LÀO CAI      3
# 31              VĨNH LONG      3
# 32                 SƠN LA      3
# 33             BÌNH THUẬN      3
# 34                 CÀ MAU      2
# 35        QUẬN 3 - TP HCM      2
# 36               LẠNG SƠN      2
# 37              ĐIỆN BIÊN      2
# 38              QUẢNG TRỊ      2
# 39    THẠCH THẤT - HÀ NỘI      2
# 40            TUYÊN QUANG      2
# 41             BÌNH DƯƠNG      2
# 42    BÌNH THẠNH - TP HCM      2
# 43               LAI CHÂU      1
# 44              BẮC GIANG      1
# 45              QUẢNG NAM      1
# 46              VĨNH PHÚC      1
# 47                BẮC KẠN      1
# 48     PHÚ NHUẬN - TP HCM      1
# 49      CẦU GIẤY - HÀ NỘI      1
# 50              NHA TRANG      1
# 51              BÌNH ĐỊNH      1
# 52       ĐỐNG ĐA - HÀ NỘI      1
# 53       THỦ ĐỨC - TP HCM      1
# 54               NAM ĐỊNH      1
# Unique Languages và số lượng:
#              Language  Count
# 0          TIẾNG VIỆT   3450
# 1           TIẾNG ANH   1229
# 2          TIẾNG NHẬT    154
# 3         TIẾNG TRUNG     65
# 4           TIẾNG HÀN     22
# 5           TIẾNG ĐỨC      4
# 6           TIẾNG LÀO      1
# 7          TIẾNG PHÁP      1
# 8   TIẾNG TÂY BAN NHA      1
# 9    TIẾNG TRUNG QUỐC      1
# 10         TIẾNG THÁI      1

# %% [markdown]
# ## Chuẩn hóa lại một số kết quả ở các thuộc tính dạng danh sách (list) mà API trả về chưa được nhất quán (Language và Province)

# %% [markdown]
# ### Language

# %%
# Thống nhất giá trị trong biến Language, thay 'TIẾNG HOA' thành 'TIẾNG TRUNG' 
data_API['Language'] = data_API['Language'].apply(
    lambda x: [lang if lang != 'TIẾNG HOA' else 'TIẾNG TRUNG' for lang in x] if isinstance(x, list) else x
)

# %% [markdown]
# ### Province

# %%
# Thống nhất giá trị trong biến Province, thống nhất 'BÀ RỊA-VŨNG TÀU' thành 'BÀ RỊA - VŨNG TÀU', 'HUẾ' thành 'THỪA THIÊN HUẾ'
province_standardization = {
    'BÀ RỊA-VŨNG TÀU': 'BÀ RỊA - VŨNG TÀU',
    'HUẾ': 'THỪA THIÊN HUẾ'
}

def standardize_province(province_list):
    if isinstance(province_list, list):
        return [province_standardization.get(prov, prov) for prov in province_list]
    return province_list

data_API['Province'] = data_API['Province'].apply(standardize_province)

# %% [markdown]
# ### Programming_Language

# %%
# Ciá trị giống nhau nhưng khác format trong Programming_Language
programming_language_alias_mapping = {
    # Ngôn ngữ lập trình chính thức
    "PYTHON": ["PYTHON"],
    "PHP": ["PHP"],
    "RUST": ["RUST"],
    "COBOL": ["COBOL"],
    "PERL": ["PERL"],
    "SCALA": ["SCALA"],
    "ABAP": ["ABAP"],
    "R": ["R"],
    "LUA": ["LUA"],
    "GROOVY": ["GROOVY"],
    "HASKELL": ["HASKELL"],
    "D": ["D"],
    "F#": ["F#"],
    "TCL": ["TCL"],
    "JULIA": ["JULIA"],
    "AWK": ["AWK"],
    "QML": ["QML"],
    "APEX": ["APEX"],
    "SOQL": ["SOQL"],
    "MAXSCRIPT": ["MAXSCRIPT"],
    "X++": ["X++"],
    "VB.NET": ["VB.NET", "VB6", "VB", "VBA", "VISUAL BASIC"],
    "GO": ["GO", "GOLANG"],
    "DART": ["DART"],
    "KOTLIN": ["KOTLIN", "KOLINT"],
    "JAVA": ["JAVA", "JAVA EE"],
    "SWIFT": ["SWIFT", "RXSWIFT"],
    "OBJECTIVE-C": ["OBJECTIVE-C", "OBJECTIVE C"],
    "C": ["C", "C/C++"],
    "C++": ["C++", "VC++"],
    "C#": ["C#", "CSHARP"],
    "MATLAB": ["MATLAB"],
    "ASSEMBLY": ["ASSEMBLY", "ASM"],
    "VERILOG": ["VERILOG", "SYSTEM VERILOG"],
    "ERLANG": ["ERLANG"],
    "JAVASCRIPT": ["JAVASCRIPT", "JS", "ES5", "ES6", "ES6+"],
    "TYPESCRIPT": ["TYPESCRIPT", "TS"],
    "SQL": ["SQL", "PL/SQL", "PLSQL", "T-SQL", "MS SQL", "MSSQL", "MICROSOFT SQL SERVER", "POSTGRES", "POSTGRESQL", "ORACLE", "MYSQL", "MARIADB"],
    "POWERSHELL": ["POWERSHELL"],
    "BASH": ["BASH", "BASH SCRIPT", "BASH SHELL", "BASH SHELL SCRIPT"],
    "SHELL": ["SHELL SCRIPT", "SHELL SCRIPTING", "SHELL-SCRIPT", "SHELL"],

    # Không phải ngôn ngữ lập trình chính thức
    "HTML": ["HTML", "HTML5"],
    "CSS": ["CSS", "CSS3", "SCSS", "SASS/SCSS"],
    "JSON": ["JSON"],
    "XML": ["XML"],
    "YAML": ["YAML"],
    "IOS": ["IOS"],
    "ANDROID": ["ANDROID"],
    "SAS": ["SAS"],
    "JQUERY": ["JQUERY"],
    "JSP": ["JSP"],
    "DJANGO": ["DJANGO"],
    "FLASK": ["FLASK"],
    "LESS": ["LESS"],
    "LIQUID": ["LIQUID"],
    "WINDOWS": ["WINDOWS"],
    "GIT": ["GIT"],
    "MONGODB": ["MONGODB"],
    "CASSANDRA": ["CASSANDRA"],
    "DAX": ["DAX"],
    "POWER QUERY": ["POWER QUERY"],
    "REALM": ["REALM"],
    "UNREAL": ["UNREAL"],
    "UNITY": ["UNITY"],
    "RPA": ["RPA"],
    "DBT": ["DBT"],
    "SPRING BOOT": ["SPRING BOOT"],
    "LINUX": ["LINUX", "UBUNTU", "UNIX"],
    "JSX/TSX": ["JSX", "TSX"],
    "ANGULAR": ["ANGULAR", "ANGULARJS"],
    "NEXT.JS": ["NEXTJS"],
    "NUXT.JS": ["NUXTJS"],
    "NODE.JS": ["NODEJS", "NODE.JS", "NODE"],
    "EXPRESS.JS": ["EXPRESSJS"],
    "GRAPHQL": ["GRAPHQL"],
    "HTTP": ["HTTP"],
    "TCP, IP": ["TCP/IP"],
    "IPV4": ["IPV4"],
    "IPV6": ["IPV6"],
    "APP SCRIPT": ["APP SCRIPT", "APPSCRIPT", "GOOGLE APPS SCRIPT"],
    "ROBOT FRAMEWORK": ["ROBOT FRAMEWORK"],
    "REACT": ["REACT", "REACTJS", "REACT.JS", "REACTNATIVE", "REACT NATIVE", "REACT-NATIVE"],
    "VUE.JS": ["VUE", "VUEJS", "VUE.JS"],
    "REST API": ["REST API", "RESTFUL API", "REST APIS"],
    ".NET": [".NET", "NET", ".NETCORE", "NETCORE", ".NET CORE", "ASP.NET", "ASP.NET CORE", "ASP .NET"],
    "SPARK": ["SPARK", "PYSPARK"],
    "LINQ": ["LINQ"]
}

# Danh sách các ngôn ngữ lập trình chính thức official programming languages
OffProLang = ['PYTHON', 'PHP', 'RUST', 'COBOL', 'PERL', 'SCALA', 'ABAP', 'R', 'LUA', 'GROOVY', 'HASKELL', 'D', 'F#', 'TCL', 'JULIA', 'AWK', 'QML', 'APEX', 'SOQL', 'MAXSCRIPT', 'X++', 'VB.NET', 'GO', 'DART', 'KOTLIN', 'JAVA', 'SWIFT', 'OBJECTIVE-C', 'C', 'C++', 'C#', 'MATLAB', 'ASSEMBLY', 'VERILOG', 'ERLANG', 'JAVASCRIPT', 'TYPESCRIPT', 'SQL', 'POWERSHELL', 'BASH', 'SHELL', 'NOSQL']

# Chuẩn hóa giá trị trong Programming_Language
def normalize_programming_language(lang):
    for key, aliases in programming_language_alias_mapping.items():
        if lang in aliases:
            return key
    return lang
data_API['Programming_Language'] = data_API['Programming_Language'].apply(
    lambda x: [normalize_programming_language(lang) for lang in x] if isinstance(x, list) else x
)

# %% [markdown]
# ### Tech_Stack

# %%
tech_alias_mapping = {
    # Cloud Providers & Services
    "AWS": ["AWS", "AMAZON WEB SERVICES", "AWS CLOUD", "AMAZON CLOUD"],
    "AZURE": ["AZURE", "MICROSOFT AZURE", "MS AZURE", "AZURE CLOUD"],
    "GCP": ["GCP", "GOOGLE CLOUD", "GOOGLE CLOUD PLATFORM", "GOOGLE CLOUD SERVICES", "GOOGLE CLOUD SERVICE"],
    "AWS S3": ["S3", "AWS S3"],
    "AWS EC2": ["EC2", "AWS EC2"],
    "AWS RDS": ["RDS", "AWS RDS"],
    "AWS LAMBDA": ["LAMBDA", "AWS LAMBDA"],
    "AWS EKS": ["EKS", "AWS EKS"],
    "AWS ELASTICACHE": ["ELASTICACHE", "AWS REDIS"],
    "AWS CLOUDFORMATION": ["CLOUDFORMATION", "AWS CLOUDFORMATION"],
    "AWS CLOUDWATCH": ["CLOUDWATCH", "AWS CLOUDWATCH"],
    "AWS CODEPIPELINE": ["AWS CODEPIPELINE", "AWSCODEPIPELINE"],
    "AWS SNS/SQS": ["SQS", "AWS SNS/SQS", "SNS"],
    "AZURE DEVOPS": ["AZURE DEVOPS", "AZURE DEVOPS CI/CD", "AZURE DEVOPS SERVICES"],
    "AZURE FUNCTIONS": ["AZURE FUNCTIONS", "CLOUD FUNCTIONS"],
    "AZURE ACTIVE DIRECTORY": ["AZURE AD", "AZURE ACTIVE DIRECTORY", "AZUREAD", "MS ENTRA ID"],
    "AZURE SQL DATABASE": ["AZURE SQL", "AZURE SQL DATABASE"],
    "GOOGLE BIGQUERY": ["BIGQUERY", "GOOGLE BIGQUERY"],
    "GOOGLE KUBERNETES ENGINE": ["GKE", "GOOGLE KUBERNETES ENGINE"],
    "DIGITAL OCEAN": ["DIGITALOCEAN", "DIGITAL OCEAN"],

    # Databases
    "SQL SERVER": ["SQL SERVER", "MSSQL", "MS SQL", "MICROSOFT SQL SERVER", "SQLSERVER", "SQL SEVER", "MS SQL SERVER", "MSSQLSERVER", "MS-SQL SERVER", "MS SQL DATABASE"],
    "POSTGRESQL": ["POSTGRESQL", "POSTGRES", "POSTGRE", "POSTGRESDB"],
    "MONGODB": ["MONGODB", "MONGO DB", "MONGO"],
    "ORACLE DATABASE": ["ORACLE", "ORACLEDB", "ORACLE DB", "ORACLE DATABASE", "ORALCE"],
    "SQLITE": ["SQLITE", "SQLITE3"],
    "REDIS": ["REDIS", "REDIS CACHE", "REDIS CLUSTER", "REDISMQ", "REDIT"],
    "ELASTICSEARCH": ["ELASTICSEARCH", "ELASTIC SEARCH", "ELASTIC STACK", "ELK", "ELK STACK", "ELATICSEARCH", "ELASTIC"],
    "DYNAMODB": ["DYNAMODB", "AMAZON DYNAMODB"],
    "NOSQL DATABASES": ["NOSQL", "NOSQL DBMS", "NO-SQL DATABASES", "NO-SQL", "NON SQL DATABASE", "NON-SQL"],
    "RDBMS": ["RDBMS", "RELATIONAL DATABASES", "SQL DATABASES", "SQL VÀ CƠ SỞ DỮ LIỆU QUAN HỆ", "SQL VÀ CƠ SỞ DỮ LIỆU QUAN HỆ (MYSQL, POSTGRESQL, ORACLE)"],
    "DATABASE CONCEPTS": ["DATABASE", "DATABASES", "DATABASE DESIGN", "DATABASE MANAGEMENT SYSTEM", "DBMS", "CSDL", "CƠ SỞ DỮ LIỆU", "DATABASES (SQL, NOSQL)", "DB", "DATABASE ADMINISTRATION", "THIẾT KẾ CƠ SỞ DỮ LIỆU", "QUẢN LÝ CƠ SỞ DỮ LIỆU", "DATABASE SYSTEM", "DATABASE SYSTEMS", "HỆ QTCSDL", "SQL/NOSQL"],
    # CI/CD & DevOps
    "CI/CD": ["CI/CD", "CICD", "CI CD", "CONTINUOUS INTEGRATION", "CONTINUOUS DELIVERY", "CONTINUOUS DEPLOYMENT", "CI", "CI-CD", "CI CD PIPELINES", "CI CD PIPELINE", "CI/CT", "DEVOPS CI/CD"],
    "JENKINS": ["JENKINS", "JENKIN"],
    "GITLAB CI/CD": ["GITLAB CI", "GITLAB CI/CD", "GITLABCI", "GITLAB-CI", "GITLAB CI RUNNER"],
    "GITHUB ACTIONS": ["GITHUB ACTIONS", "GITHUB ACTION", "GITHUB ACTIONS CI/CD"],
    "TERRAFORM": ["TERRAFORM", "TERAFORM"],
    "DEVOPS": ["DEVOPS", "AZURE DEVOPS", "AWS DEVOPS", "DEVSECOPS", "DEV OPS", "DEPOPS"],

    # Version Control
    "GIT": ["GIT", "VERSION CONTROL (GIT)", "GIT FLOW", "GIT-FLOW", "GITFLOW", "VERSION CONTROL GIT", "KIỂM SOÁT PHIÊN BẢN (GIT)", "KIỂM SOÁT PHIÊN BẢN (VERSION CONTROL GIT)", "QUẢN LÝ PHIÊN BẢN (VERSION CONTROL GIT)"],
    "GITHUB": ["GITHUB", "GIT HUB"],
    "GITLAB": ["GITLAB", "GIT LAB"],
    "BITBUCKET": ["BITBUCKET", "BITBUCKET PIPELINES"],
    "SVN": ["SVN", "SUBVERSION"],
    "VERSION CONTROL": ["VERSION CONTROL", "VCS", "SCM", "SCM TOOLS", "QUẢN LÝ PHIÊN BẢN"],

    # Frameworks & Libraries
    ".NET CORE": [".NET CORE", ".NETCORE"],
    "ASP.NET": ["ASP.NET", "ASPNET"],
    "ASP.NET MVC": ["ASP.NET MVC", "ASPNET MVC", "MVC4", "MVC5"],
    "ASP.NET CORE": ["ASP.NET CORE", "ASP.NET CORE MVC"],
    "ENTITY FRAMEWORK": ["ENTITY FRAMEWORK", "EF CORE", "ENTITY FRAMEWORK CORE"],
    "SPRING FRAMEWORK": ["SPRING", "SPRING FRAMEWORK", "SPRING CORE", "SPRING JDBC", "SPRING JDBC/ DATA", "SPRING DATA", "SPRING DATA JPA", "SPRING CLOUD", "SPRING CLOUD FRAMEWORK", "SPRING TEST", "SPRINGFRAMEWORK", "SPRING-CORE", "SPRINGMVC", "SPRINGMVC", "SPRING JPA", "SPRING FRAMEWORK (SPRING BOOT, SPRING MVC, SPRING DATA)"],
    "SPRING BOOT": ["SPRING BOOT", "SPRINGBOOT", "JAVA SPRING BOOT", "SPRING-BOOT"],
    "HIBERNATE": ["HIBERNATE", "JPA", "JPA2", "JAVA PERSISTENCE API (JPA)"],
    "REACT": ["REACTJS", "REACT JS", "REACT.JS", "REACT", "REACT COMPONENT"],
    "REACT HOOK": ["REACT HOOK", "REACT HOOKS", "REACT HOOK FORM","HOOKS"],
    "REACT CONTEXT": ["REACT CONTEXT", "REACT CONTEXT API"],

    "REACT NATIVE": ["REACT NATIVE", "REACTNATIVE"],
    "ANGULAR": ["ANGULAR", "ANGULARJS", "ANGULAR JS", "ANGULAR FRAMEWORK", "ANGULAR CLI", "ANGULAR MATERIAL"],
    "VUEJS": ["VUEJS", "VUE.JS", "VUE JS", "VUE", "VUEX", "VUEX/PINIA", "VUE3"],
    "NUXT.JS": ["NUXTJS", "NUXT.JS", "NUXT JS", "NUXT"],
    "VITE.JS": ["VITEJS", "VITE.JS", "VITE JS", "VITE"],

    "NEXT.JS": ["NEXTJS", "NEXT.JS", "NEXT JS", "NEXT"],
    "NODE.JS": ["NODE.JS", "NODEJS", "NODE JS", "NODESJS"],
    "EXPRESS.JS": ["EXPRESSJS", "EXPRESS.JS", "EXPRESS"],
    "DJANGO": ["DJANGO", "DJANGO FRAMEWORK", "DJANGO REST FRAMEWORK"],
    "FLASK": ["FLASK", "FLASK API"],
    "LARAVEL": ["LARAVEL", "LARAVEL FRAMEWORK"],
    "RUBY ON RAILS": ["RUBY ON RAILS", "RAILS"],
    "BOOTSTRAP": ["BOOTSTRAP", "BOOTSTRAP CSS", "BOOTSTRAP 5"],
    "TAILWIND CSS": ["TAILWIND CSS", "TAILWINDCSS", "TAILWIND"],
    "MATERIAL UI": ["MATERIAL UI", "MATERIALUI", "MUI", "MATERIAL DESIGN", "MATERIAL"],
    "ANT DESIGN": ["ANT DESIGN", "ANTD", "ANT-DESIGN", "ANT-DESINE", "ANTD DESIGN"],
    "SASS/SCSS": ["SASS", "SCSS", "SASS/SCSS"],

    # Operating Systems
    "LINUX": ["LINUX", "LINUX SERVER", "LINUX KERNEL", "EMBEDDED LINUX", "LINUX/UNIX", "HỆ ĐIỀU HÀNH LINUX", "LINUX SYSTEM ADMINISTRATION", "ENTERPRISE LINUX", "KALI LINUX", "ALMALINUX", "LINUX OS"],
    "REDHAT": ["REDHAT", "REDHAT/CENTOS", "RED HAT"],
    "WINDOWS": ["WINDOWS", "WINDOWS SERVER", "HỆ ĐIỀU HÀNH WINDOWS", "WIN SERVER", "MS WINDOWS", "WINDOWS FORMS", "WINFORM", "WINFORMS", "WINDOWS 10", "WINDOWS 7", "WINDOWS 8", "WINDOWS XP", "WINDOW"],
    "MACOS": ["MACOS", "MAC OS", "HỆ ĐIỀU HÀNH MACOS"],
    "UNIX": ["UNIX", "UNIX/LINUX", "HỆ ĐIỀU HÀNH UNIX"],
    "ANDROID": ["ANDROID", "ANDROID SDK", "ANDROID STUDIO", "ANDROID JETPACK", "ANDROID ARCHITECTURE COMPONENTS", "ANDROIDX"],
    "IOS": ["IOS", "IOS SDK"],
    "OPERATING SYSTEM": ["OS", "HỆ ĐIỀU HÀNH", "OPERATING SYSTEMS", "SYSTEM OS"],

    # Virtualization & Containerization
    "DOCKER": ["DOCKER", "DOCKER HUB"],
    "DOCKER COMPOSE": ["DOCKER COMPOSE", "DOCKER-COMPOSE"],
    "KUBERNETES": ["KUBERNETES", "K8S", "KUBEADM", "KUBENATES", "KUBERNETE"],
    "HELM": ["HELM", "HELM CHART"],
    "CONTAINERIZATION": ["CONTAINERIZATION", "CONTAINER", "CONTAINERS", "CONTAINER ORCHESTRATION", "CONTAINER ENGINE", "CONTAINERD", "DOCKER/KUBERNETES", "CONTAINERIZATION (DOCKER, KUBERNETES)"],
    "VMWARE": ["VMWARE", "VIRTUALIZATION", "ẢO HÓA", "VIRTUAL MACHINE", "VM", "VIRTUALIZATION (VMWARE, HYPER V, KVM)", "SERVER ẢO HÓA", "HỆ THỐNG ẢO HÓA"],
    "VSPHERE": ["VSPHERE", "VMWARE VSPHERE"],
    "HYPER-V": ["HYPER-V", "HYPERV", "HYPER V"],
    "VMWARE, HYPER V, KVM": ["VIRTUALIZATION (VMWARE, HYPER V, KVM)"],

    # Messaging & Queues
    "KAFKA": ["KAFKA", "APACHE KAFKA", "CONFLUENT KAFKA"],
    "RABBITMQ": ["RABBITMQ", "RABBIT MQ"],
    "ACTIVEMQ": ["ACTIVEMQ", "ACTIVE MQ"],
    "MESSAGE QUEUE": ["MESSAGE QUEUE", "MESSAGE QUEUES", "MESSAGE BROKER", "MQ"],

    # API & Web Services
    "REST API": ["RESTFUL API", "REST API", "RESTFUL APIS", "REST APIS", "API RESTFUL", "REST", "RESTFUL", "RESTFUL SERVICES", "RESTFUL SERVICE", "RESTFUL WEB SERVICES", "RESTAPI", "RESTFULL API", "RESTFULAPIS"],

    "API TESTING": ["API TESTING", "API TESTING (REST, SOAP)"],
    "REST ASSURED": ["REST ASSURED", "RESTASSURED", "REST ASSURED API"],
    "API": ["API", "APIS"],
    "SOAP, REST": ["WEB SERVICE (SOAP, REST)"],

    "GRAPHQL": ["GRAPHQL", "GRAPHQL API"],
    "SOAP": ["SOAP", "SOAP API", "SOAP SERVICE", "WEBSERVICE", "WEB SERVICES", "WEBSERVICES"],
    "API GATEWAY": ["API GATEWAY", "KONG", "KONG API GATEWAY"],
    "MICROSERVICES": ["MICROSERVICES", "MICROSERVICE", "MICRO-SERVICE", "MICRO SERVICES", "MICROSERVICES ARCHITECTURE", "MICROSERVICE ARCHITECTURE", "KIẾN TRÚC MICROSERVICES", "MICRO FRONTEND", "MICRO-FRONTEND"],
    "WEBSOCKET": ["WEBSOCKET", "WEB SOCKET", "WEBSOCKETS", "SOCKET.IO", "SOCKETIO", "SOCKET"],

    # AI/ML
    "MACHINE LEARNING": ["MACHINE LEARNING", "ML", "MACHINE LEARNING ALGORITHMS", "HỌC MÁY"],
    "DEEP LEARNING": ["DEEP LEARNING", "DL"],
    "GAN": ["GANS", "GAN"],
    "TRANSFORMER": ["TRANSFORMER", "TRANSFORMERS"],
    "NLP": ["NLP", "NATURAL LANGUAGE PROCESSING", "NATURAL LANGUAGE UNDERSTANDING (NLU)", "NATURAL LANGUAGE GENERATION (NLG)", "NLP LIBRARIES (SPACY, NLTK, TRANSFORMERS)"],
    "SPACY, NLTK, TRANSFORMERS": ["NLP LIBRARIES (SPACY, NLTK, TRANSFORMERS)"],
    "COMPUTER VISION": ["COMPUTER VISION", "OPENCV", "IMAGE PROCESSING", "OBJECT DETECTION", "IMAGE CLASSIFICATION", "OCR", "COMPUTER VISION ALGORITHMS", "IMAGE PROCESSING TECHNIQUES"],
    "TENSORFLOW": ["TENSORFLOW", "TF", "TENSORFLOW LITE", "TENSORFLOW SERVING"],
    "PYTORCH": ["PYTORCH", "TORCHSERVE"],
    "SCIKIT-LEARN": ["SCIKIT-LEARN", "SKLEARN", "SCIKIT LEARN"],
    "LARGE LANGUAGE MODELS": ["LLM", "LARGE LANGUAGE MODELS (LLMS)", "GPT", "CHATGPT", "GEMINI", "CLAUDE", "LLAMA", "GENERATIVE AI", "GENAI", "LLMS", "OPENAI", "OPENAI API", "FINE-TUNING LLM","LARGE LANGUAGE MODELS (LLM)"],
    "RAG": ["RAG", "RETRIEVAL-AUGMENTED GENERATION", "RAG (RETRIEVAL-AUGMENTED GENERATION)"],
    "AI": ["AI", "AI/ML", "ARTIFICIAL INTELLIGENCE", "AI TOOLS", "AI AGENTS", "AI AGENT"],
    "HUGGING FACE": ["HUGGING FACE", "HUGGINGFACE"],

    # Data & Analytics
    "BIG DATA": ["BIG DATA", "BIGDATA"],
    "APACHE SPARK": ["SPARK", "APACHE SPARK"],
    "APACHE FLINK": ["FLINK", "APACHE FLINK"],
    "DATA WAREHOUSE": ["DATA WAREHOUSE", "DWH", "DATA WAREHOUSING", "ETL", "ELT", "DATA LAKE", "DATALAKE", "DATA MART", "DATA LAKEHOUSE"],
    "DATA VISUALIZATION": ["BUSINESS INTELLIGENCE", "DATA VISUALIZATION", "DASHBOARD", "REPORTING", "GOOGLE DATA STUDIO"],
    "DATA ANALYSIS": ["DATA ANALYTICS", "DATA ANALYSIS", "DATA ANALYST", "ANALYTICS", "PHÂN TÍCH DỮ LIỆU"],
    "LOOKER": ["LOOKER",  "LOOKER STUDIO"],
    "POWER BI": ["POWER BI", "POWERBI", "BI"],
    "DATA MODELING": ["DATA MODELING", "ERD", "MÔ HÌNH HÓA DỮ LIỆU", "DATA MODEL", "THIẾT KẾ MÔ HÌNH DỮ LIỆU"],
    "DATA ENGINEERING": ["DATA ENGINEER", "DATA PIPELINE", "AIRFLOW", "DATA ENGINEERING"],
    "APACHE NIFI": ["APACHE NIFI", "NIFI"],

    # UI/UX Design
    "UI/UX DESIGN": ["UI/UX", "UI", "UX", "UI/UX DESIGN", "UX/UI", "USER INTERFACE DESIGN", "DESIGN SYSTEM", "USER RESEARCH", "UIUX", "UI UX DESIGN FOR GAMES", "UI/UX DESIGN PRINCIPLES", "UI FLOW", "UX ANALYTICS"],
    "ADOBE XD": ["ADOBE XD", "XD"],
    "ADOBE ILLUSTRATOR": ["ILLUSTRATOR", "ADOBE ILLUSTRATOR"],
    "PHOTOSHOP": ["PHOTOSHOP", "ADOBE PHOTOSHOP"],
    "BALSAMIQ": ["BALSAMIQ", "BALASAMIQ"],
    "AXURE": ["AXURE", "AXURE RP"],
    "RESPONSIVE DESIGN": ["RESPONSIVE DESIGN", "RESPONSIVE WEB DESIGN", "RESPONSIVE"],

    # Testing
    # "TESTING": ["TESTING", "QA", "SOFTWARE QA", "QUALITY ASSURANCE", "QC", "QA/QC", "KIỂM THỬ PHẦN MỀM", "KIỂM THỬ", "TESTER", "MANUAL TESTING", "MANUAL TEST", "AUTOMATION TESTING", "AUTOMATION TEST", "AUTO TEST", "TEST AUTOMATION", "FUNCTIONAL TESTING", "INTEGRATION TESTING", "UNIT TESTING", "SYSTEM TESTING", "PERFORMANCE TESTING", "SECURITY TESTING", "API TESTING", "UI TESTING", "E2E TESTING", "GREY BOX TESTING", "REGRESSION TESTING", "USABILITY TESTING", "DATABASE TESTING", "LOAD TESTING", "STRESS TESTING", "TEST EXECUTION", "DEFECT REPORTING", "BUG TRACKING", "TEST CASES", "TEST CASE", "TEST PLAN", "TEST SCENARIO", "TEST SCRIPT", "SOFTWARE TESTING LIFE CYCLE", "STLC", "KIỂM THỬ PHẦN MỀM (TESTING)", "KIỂM THỬ HỆ THỐNG", "TEST AUTOMATION FRAMEWORKS", "TEST AUTOMATION FRAMEWORKS (SELENIUM, CYPRESS, APPIUM, ETC.)"],
     "TESTING CONCEPTS": [
    "TESTING", "QA", "SOFTWARE QA", "QUALITY ASSURANCE", "QC", "QA/QC",
    "KIỂM THỬ PHẦN MỀM", "KIỂM THỬ", "TESTER",
    "SOFTWARE TESTING LIFE CYCLE", "STLC",
    "KIỂM THỬ PHẦN MỀM (TESTING)", "KIỂM THỬ HỆ THỐNG"],
    
    #Testing methods
    "GREY BOX TESTING": ["KIỂM THỬ HỘP XÁM (GREY BOX TESTING)", "GREY BOX TESTING"],
    "BLACK BOX TESTING": ["KIỂM THỬ HỘP ĐEN (BLACK BOX TESTING)", "BLACK BOX TESTING"],
    "WHITE BOX TESTING": ["KIỂM THỬ HỘP TRẮNG (WHITE BOX TESTING)", "WHITE BOX TESTING"],
    "PENETRATION TESTING": ["KIỂM THỬ XÂM NHẬP (PENETRATION TESTING)", "PENETRATION TESTING"],

    "MANUAL TESTING": [
        "MANUAL TESTING", "MANUAL TEST"
    ],
    "AUTOMATION TESTING": [
        "AUTOMATION TESTING", "AUTOMATION TEST", "AUTO TEST", "TEST AUTOMATION"
    ],
    "TEST AUTOMATION FRAMEWORKS": [
        "TEST AUTOMATION FRAMEWORKS",
        "TEST AUTOMATION FRAMEWORKS (SELENIUM, CYPRESS, APPIUM, ETC.)"
    ],
    "FUNCTIONAL TESTING": [
        "FUNCTIONAL TESTING", "USABILITY TESTING"
    ],
    "UNIT TESTING": [
        "UNIT TESTING"
    ],
    "INTEGRATION TESTING": [
        "INTEGRATION TESTING"
    ],
    "SYSTEM TESTING": [
        "SYSTEM TESTING", "E2E TESTING"
    ],
  
    "PERFORMANCE TESTING": [
        "PERFORMANCE TESTING", "LOAD TESTING", "STRESS TESTING"
    ],

    "API TESTING": [
        "API TESTING", "API TESTING (REST, SOAP)"
    ],
  
    "TEST MANAGEMENT & ARTIFACTS": [
        "TEST PLAN", "TEST CASE", "TEST CASES", "TEST SCENARIO", "TEST SCRIPT",
        "TEST EXECUTION", "DEFECT REPORTING", "BUG TRACKING"
    ],

    "SELENIUM": ["SELENIUM", "SELENIUM WEBDRIVER", "SELENIUM GRID", "SELENIUM FRAMEWORK"],
    "POSTMAN": ["POSTMAN", "API POSTMAN"],
    "TDD": ["TDD", "TEST-DRIVEN DEVELOPMENT", "TEST DRIVEN DEVELOPMENT"],
    "CUCUMBER BDD": ["BDD", "BEHAVIOR DRIVEN DEVELOPMENT", "CUCUMBER", "CUCUMBER BDD", "GHERKIN"],

    # Methodologies & Concepts
    "AGILE": ["AGILE", "SCRUM", "AGILE/SCRUM", "AGILE SCRUM", "AGILE METHODOLOGIES", "AGILE TESTING", "AGILE SOFTWARE DEVELOPMENT", "SCRUM (AGILE)", "AGILE-SCRUM", "AGILE PROCESS"],

    "WATERFALL": ["WATERFALL", "WATER-FALL"],

    "OOP": ["OOP", "OBJECT ORIENTED PROGRAMMING", "OBJECT-ORIENTED PROGRAMMING", "OBJECT ORIENTED PROGRAMMING (OOP)", "LẬP TRÌNH HƯỚNG ĐỐI TƯỢNG (OOP)", "SOLID", "SOLID PRINCIPLES", "OOAD", "OBJECT-ORIENTED DESIGN", "OOPS"],

    "DESIGN PATTERNS": ["DESIGN PATTERN", "DESIGN PATTERNS", "SOFTWARE DESIGN PATTERNS", "FACTORY METHOD", "SINGLETON", "DESIGNPATTERNS"],

    "SOFTWARE ARCHITECTURE": ["SOFTWARE ARCHITECTURE", "KIẾN TRÚC PHẦN MỀM", "SYSTEM ARCHITECTURE", "KIẾN TRÚC HỆ THỐNG", "CLEAN ARCHITECTURE"],

    "MVC, MVVM, MVP": ["KIẾN TRÚC PHẦN MỀM (MVC, MVVM, MVP)"],

    "SOFTWARE DESIGN PRINCIPLES": [
        "CLEAN CODE",
        "SOFTWARE DESIGN PRINCIPLES",
        "DOMAIN DRIVEN DESIGN",
        "DOMAIN-DRIVEN DESIGN",
        "DDD"
    ],

    "ENTERPRISE ARCHITECTURE": [
        "ENTERPRISE ARCHITECT",
        "ENTERPRISE ARCHITECTURE"
    ],

    "SOFTWARE_DEVELOPMENT_LIFECYCLE": [
        "SOFTWARE DEVELOPMENT LIFE CYCLE",
        "SDLC"
    ],

    #General Networking Concepts
    "NETWORKING CONCEPTS": [
    "NETWORKING", "NETWORK", "MẠNG MÁY TÍNH", "MẠNG", "HỆ THỐNG MẠNG", "MẠNG MÁY TÍNH (NETWORKING)", "KIẾN THỨC VỀ MẠNG MÁY TÍNH",
    "NETWORK ADMINISTRATION", "QUẢN TRỊ MẠNG",
    "THIẾT BỊ MẠNG"
],
    "LAN" : ["LAN", "LOCAL AREA NETWORK", "MẠNG LAN"],
    "WAN" : ["WAN", "WIDE AREA NETWORK", "MẠNG WAN"],
    "ROUTING": ["ROUTING", "ROUTER"],
    "SWITCHING": ["SWITCHING", "SWITCH"],
    "FIREWALLS": ["FIREWALLS", "FIREWALL", "TƯỜNG LỬA"],
    "DNS": ["DNS", "DOMAIN NAME SYSTEM", "HỆ THỐNG TÊN MIỀN"],
    "DHCP": ["DHCP", "DYNAMIC HOST CONFIGURATION PROTOCOL", "GIAO THỨC CẤU HÌNH ĐỘNG HOST"],
    "VPN": ["VPN", "VIRTUAL PRIVATE NETWORK", "MẠNG RIÊNG ẢO"],
    "LOAD BALANCE" : ["LOAD BALANCE", "LOAD BALANCING", "LOAD BALANCER", "LOADBALANCE", "LOAD BALANCERS", "BALANCER", "CÂN BẰNG TẢI"],
    "TCP, IP": ["TCP/IP", "TCP IP", "TCP", "IP", "NETWORKING (TCP IP)"],
    "TCP, IP, ROUTING, SWITCHING, FIREWALLS": ["NETWORKING (TCP IP, ROUTING, SWITCHING, FIREWALLS)"],
    "TCP, IP, DNS, HTTP": ["NETWORKING FUNDAMENTALS (TCP IP, DNS, HTTP)"],
    "TCP, IP, DNS,  DHCP": ["NETWORKING FUNDAMENTALS (TCP IP, DNS, DHCP)"],
    "TCP, IP, DNS, ROUTING": ["NETWORKING (TCP IP, DNS, ROUTING)"],

    # Cybersecurity & Security Concepts
    "CYBERSECURITY": ["SECURITY", "CYBERSECURITY", "AN NINH MẠNG", "INFORMATION SECURITY", "WAF", "SIEM", "VULNERABILITY SCANNING", "ENCRYPTION", "AUTHENTICATION", "AUTHORIZATION", "CYBER SECURITY", "SECURITY TEST","AN TOÀN THÔNG TIN", "BẢO MẬT THÔNG TIN", "ENDPOINT SECURITY", "NETWORK SECURITY", "SECURITY ARCHITECTURE","NETWORK SECURITY", "AN NINH MẠNG (CYBERSECURITY)"],

    "OWASP": ["OWASP", "OWASP TOP 10"],

    "IDS/IPS": ["IPS", "IDS", "INTRUSION DETECTION SYSTEM", "INTRUSION PREVENTION SYSTEM", "HỆ THỐNG PHÁT HIỆN XÂM NHẬP (IDS)", "HỆ THỐNG NGĂN CHẶN XÂM NHẬP (IPS)"],

    "OAUTH": ["OAUTH", "OAUTH2", "OAUTH 2.0", "OAUTH 2"],

    "ISO": ["ISO", "ISO 27001", "ISO/IEC 27001", "ISO 9001", "ISO 20000", "ISO 22301", "ISO 31000", "ISO/IEC 27001", "ISO/IEC 20000", "ISO 27001:2013"],

    "PROJECT MANAGEMENT": ["PROJECT MANAGEMENT", "QUẢN LÝ DỰ ÁN", "PMP", "PRINCE2", "GANTT CHART", "BACKLOG", "PRODUCT BACKLOG", "IT PROJECT MANAGEMENT", "QUẢN LÝ DỰ ÁN IT", "QUẢN LÝ DỰ ÁN PHẦN MỀM"],

    "DATA STRUCTURES AND ALGORITHMS": ["DATA STRUCTURES", "ALGORITHM", "ALGORITHMS", "CẤU TRÚC DỮ LIỆU", "GIẢI THUẬT", "DATA STRUCTURES AND ALGORITHMS", "CẤU TRÚC DỮ LIỆU VÀ GIẢI THUẬT", "DATA STRUCTURE", "DATA STUCTURE", "THUẬT TOÁN", "THUẬT TOÁN VÀ CẤU TRÚC DỮ LIỆU", "CẤU TRÚC DỮ LIỆU GIẢI THUẬT"],

    "CLOUD COMPUTING": ["CLOUD", "CLOUD COMPUTING", "SERVERLESS", "CLOUD SERVICES", "CLOUD PLATFORMS", "CLOUD SERVICE", "CLOUD INFRASTRUCTURE", "CLOUD NATIVE", "CLOUD ARCHITECTURE", "KIẾN TRÚC HỆ THỐNG ĐÁM MÂY"],
    "AWS, AZURE, GCP": ["CLOUD COMPUTING (AWS, AZURE, GCP)"],

    "ERP": ["ERP", "SAP", "SAP ERP"],
    "MICROSOFT DYNAMICS 365": ["MICROSOFT DYNAMICS 365", "DYNAMICS 365"],

    "SAP": ["SAP", "SAP ERP"],

    "ODOO": ["ODOO", "ODOO ERP", "ODOO FRAMEWORK"],

    "CRM": ["CRM", "SALESFORCE", "HUBSPOT", "MICROSOFT DYNAMICS CRM", "DYNAMICS CRM"],


    # Vietnamese Specific Skills/Concepts
    "GIÁM SÁT VÀ KHẮC PHỤC SỰ CỐ HỆ THỐNG": ["GIÁM SÁT VÀ KHẮC PHỤC SỰ CỐ HỆ THỐNG", "KHẮC PHỤC SỰ CỐ", "DEBUGGING", "TROUBLESHOOTING", "DEBUGGING AND TROUBLESHOOTING", "GIẢI QUYẾT SỰ CỐ HỆ THỐNG", "KHẮC PHỤC SỰ CỐ (DEBUGGING)", "XỬ LÝ LỖI (DEBUGGING)"],

    "PHẦN CỨNG MÁY TÍNH": ["PHẦN CỨNG MÁY TÍNH", "PHẦN CỨNG", "HARDWARE", "MÁY TÍNH", "PC", "LAPTOP", "SERVER", "PHẦN CỨNG PC/ LAPTOP", "MÁY CHỦ"],

    "QUẢN TRỊ HỆ THỐNG": ["QUẢN TRỊ HỆ THỐNG", "SYSTEM ADMINISTRATION", "SERVER ADMINISTRATION", "QUẢN TRỊ HỆ THỐNG LINUX", "QUẢN TRỊ HỆ THỐNG MÁY CHỦ (SERVER ADMINISTRATION)"],

    "THIẾT KẾ HỆ THỐNG": ["THIẾT KẾ HỆ THỐNG", "SYSTEM DESIGN", "THIẾT KẾ HỆ THỐNG PHÂN TÁN"],

    "BUSINESS ANALYSIS": ["BUSINESS ANALYSIS", "BUSINESS ANALYST", "BA", "PHÂN TÍCH NGHIỆP VỤ", "BABOK", "REQUIREMENTS ANALYSIS", "USER STORIES", "USE CASES", "PHÂN TÍCH YÊU CẦU"],

    # Other tools and technologies
    "JIRA": ["JIRA", "JIRA SOFTWARE"],
    "MICROSOFT OFFICE": ["MS OFFICE", "OFFICE 365", "MICROSOFT 365", "MS.OFFICE"],
    "MICROSOFT WORD": ["MS WORD", "MS.WORD"],
    "VSCODE": ["VISUAL STUDIO CODE", "VSCODE"],
    "UNITY": ["UNITY", "UNITY ENGINE", "UNITY GAME ENGINE", "UNITY 3D", "UNITY3D"],
    "UNREAL ENGINE": ["UNREAL ENGINE", "UNREAL"],
    "FLUTTER": ["FLUTTER", "FLUTTER FRAMEWORK"],
}

# Chuẩn hóa giá trị trong tech_alias_mapping
def normalize_technology(tech):
    for key, aliases in tech_alias_mapping.items():
        if tech in aliases:
            return key
    return tech
data_API['Tech_Stack'] = data_API['Tech_Stack'].apply(
    lambda x: [normalize_technology(tech) for tech in x] if isinstance(x, list) else x
 )

# %%
print(f"Tổng số lượng Tech_Stack gốc: {len(tech_counts)}")
# Lấy ra số lượng TechStack và Skill chính thức, không bao gồm các ngôn ngữ lập trình
OffTech = list(set(data_API['Tech_Stack'].explode().dropna().unique()) - set(OffProLang))
print(f"Số lượng Tech_Stack chính thức (không bao gồm ngôn ngữ lập trình): {len(OffTech)}")
# Out:
# Tổng số lượng Tech_Stack gốc: 6060
# Số lượng Tech_Stack chính thức (không bao gồm ngôn ngữ lập trình): 5674

# %%
# In ra 1 giá trị ngẫu nhiên trong cột Tech_Stack
data_API['Tech_Stack'].loc[20]
# Out:
# ['AI',
#  'WEB',
#  'ANDROID',
#  'IOS',
#  'UI/UX DESIGN',
#  'SMOKE TEST',
#  'REGRESSION TEST',
#  'FREE TEST',
#  'EXPLORATORY TEST',
#  'LARGE LANGUAGE MODELS',
#  'COPILOT CHAT',
#  'BUGZILLA',
#  'KATALON STUDIO',
#  'TEST GAME',
#  'TESTCASE']

# %% [markdown]
# ## Loại bỏ Tech_Stack trong Programming_Language và ngược lại (Nếu có Programming_Language trong tech_stack, ta xóa Programming_Language trong ô của thuộc tính  tech_stack đó và bổ sung ngôn ngữ lập trình bị lẫn lộn đó cho ô của thuộc tính Programming_Language(nếu chưa có) trên cùng 1 mẫu dữ liệu)

# %% [markdown]
# Programming_Language trong Tech_Stack

# %%
# Đếm số lượng Programming_Language lẫn lộn trong Tech_Stack
cntPL = 0
for tech in data_API['Tech_Stack'].explode().unique():
    if tech in OffProLang:
        print(f"Ngôn ngữ lập trình lẫn lộn: {tech}")
        cntPL += 1
print(f"Số lượng ngôn ngữ lập trình lẫn lộn trong Tech_Stack trước khi chuẩn hóa: {cntPL}")
# Out:
# Ngôn ngữ lập trình lẫn lộn: MATLAB
# Ngôn ngữ lập trình lẫn lộn: QML
# Ngôn ngữ lập trình lẫn lộn: JAVA
# Ngôn ngữ lập trình lẫn lộn: PHP
# Ngôn ngữ lập trình lẫn lộn: TYPESCRIPT
# Ngôn ngữ lập trình lẫn lộn: SWIFT
# Ngôn ngữ lập trình lẫn lộn: VB.NET
# Ngôn ngữ lập trình lẫn lộn: JAVASCRIPT
# Ngôn ngữ lập trình lẫn lộn: KOTLIN
# Ngôn ngữ lập trình lẫn lộn: PYTHON
# Ngôn ngữ lập trình lẫn lộn: SHELL
# Ngôn ngữ lập trình lẫn lộn: POWERSHELL
# Ngôn ngữ lập trình lẫn lộn: BASH
# Ngôn ngữ lập trình lẫn lộn: SQL
# Ngôn ngữ lập trình lẫn lộn: GO
# Ngôn ngữ lập trình lẫn lộn: VERILOG
# Ngôn ngữ lập trình lẫn lộn: ABAP
# Ngôn ngữ lập trình lẫn lộn: C#
# Ngôn ngữ lập trình lẫn lộn: OBJECTIVE-C
# Ngôn ngữ lập trình lẫn lộn: DART
# Ngôn ngữ lập trình lẫn lộn: C++
# Ngôn ngữ lập trình lẫn lộn: R
# Ngôn ngữ lập trình lẫn lộn: RUST
# Ngôn ngữ lập trình lẫn lộn: APEX
# Số lượng ngôn ngữ lập trình lẫn lộn trong Tech_Stack trước khi chuẩn hóa: 24

# %%
# Xử lí các ngôn ngữ lập trình lẫn lộn trong Tech_Stack
for idx, row in data_API.iterrows():
    tech_stack = row['Tech_Stack']
    prog_lang = row['Programming_Language']

    # Bỏ qua nếu tech_stack và prog_lang là null
    if tech_stack is None and prog_lang is None:
        continue

    # Chuyển về list để thao tác
    tech_stack_list = tech_stack if isinstance(tech_stack, list) else []
    prog_lang_list = prog_lang if isinstance(prog_lang, list) else []

    # Tìm các ngôn ngữ lập trình trong tech_stack
    langs_in_tech = [lang for lang in tech_stack_list if lang in OffProLang]

    # Xóa tất cả ngôn ngữ lập trình khỏi tech_stack
    tech_stack_list = [tech for tech in tech_stack_list if tech not in OffProLang]

    # Bổ sung vào prog_lang nếu chưa có
    for lang in langs_in_tech:
        if lang not in prog_lang_list:
            prog_lang_list.append(lang)

    # Gán lại giá trị cho DataFrame
    #Kiểm tra nếu tech_stack_list rỗng thì gán giá trị None
    if not tech_stack_list:
        tech_stack_list = None
    # Đảm bảo giá trị không trùng bằng set, nếu không phải rỗng
    data_API.at[idx, 'Tech_Stack'] = list(set(tech_stack_list)) if tech_stack_list else None
    data_API.at[idx, 'Programming_Language'] = list(set(prog_lang_list)) if prog_lang_list else None

# %% [markdown]
# Tech_Stack trong Programming_Language

# %%
# Đếm số lượng Tech_Stack lẫn lộn trong Programming_Language
cntTech = 0
for Pro_Lang in data_API['Programming_Language'].explode().unique():
    if Pro_Lang in OffTech:
        print(f"Ngôn ngữ lập trình lẫn lộn: {Pro_Lang}")
        cntTech += 1
print(f"Số lượng ngôn ngữ lập trình lẫn lộn trong Programming_Language trước khi chuẩn hóa: {cntTech}")
# Out:
# Ngôn ngữ lập trình lẫn lộn: .NET
# Ngôn ngữ lập trình lẫn lộn: REST API
# Ngôn ngữ lập trình lẫn lộn: NODE.JS
# Ngôn ngữ lập trình lẫn lộn: GRAPHQL
# Ngôn ngữ lập trình lẫn lộn: HTML
# Ngôn ngữ lập trình lẫn lộn: UNITY
# Ngôn ngữ lập trình lẫn lộn: CSS
# Ngôn ngữ lập trình lẫn lộn: REACT
# Ngôn ngữ lập trình lẫn lộn: FLUTTER
# Ngôn ngữ lập trình lẫn lộn: NEXT.JS
# Ngôn ngữ lập trình lẫn lộn: ANGULAR
# Ngôn ngữ lập trình lẫn lộn: NUXT.JS
# Ngôn ngữ lập trình lẫn lộn: XML
# Ngôn ngữ lập trình lẫn lộn: SOLIDITY
# Ngôn ngữ lập trình lẫn lộn: G-CODE
# Ngôn ngữ lập trình lẫn lộn: M-CODE
# Ngôn ngữ lập trình lẫn lộn: CAPL
# Ngôn ngữ lập trình lẫn lộn: VHDL
# Ngôn ngữ lập trình lẫn lộn: LIQUID
# Ngôn ngữ lập trình lẫn lộn: VYPER
# Ngôn ngữ lập trình lẫn lộn: API
# Ngôn ngữ lập trình lẫn lộn: BATCH
# Ngôn ngữ lập trình lẫn lộn: SCRATCH
# Ngôn ngữ lập trình lẫn lộn: JSON
# Ngôn ngữ lập trình lẫn lộn: HTML/CSS
# Ngôn ngữ lập trình lẫn lộn: SPRING BOOT
# Ngôn ngữ lập trình lẫn lộn: SPRING FRAMEWORK
# Số lượng ngôn ngữ lập trình lẫn lộn trong Programming_Language trước khi chuẩn hóa: 27

# %%
# Xử lí các tech stack lẫn lộn trong Programming_Language
for idx, row in data_API.iterrows():
    tech_stack = row['Tech_Stack']
    prog_lang = row['Programming_Language']

    # Bỏ qua nếu tech_stack hoặc prog_lang là null
    if tech_stack is None and prog_lang is None:
        continue

    # Chuyển về list để thao tác
    tech_stack_list = tech_stack if isinstance(tech_stack, list) else []
    prog_lang_list = prog_lang if isinstance(prog_lang, list) else []

    # Tìm các tech stack lẫn lộn trong prog_lang
    techs_in_prog = [tech for tech in prog_lang_list if tech in OffTech]

    # Xóa tất cả tech stack khỏi prog_lang
    prog_lang_list = [pl for pl in prog_lang_list if pl not in OffTech]
    
    # Bổ sung vào tech_stack nếu chưa có
    for tech in techs_in_prog:
        if tech not in tech_stack_list:
            tech_stack_list.append(tech)
    # Kiểm tra nếu prog_lang_list rỗng thì gán giá trị None
    if not prog_lang_list:
        prog_lang_list = None
    data_API.at[idx, 'Programming_Language'] = list(set(prog_lang_list)) if prog_lang_list else None
    data_API.at[idx, 'Tech_Stack'] = list(set(tech_stack_list)) if tech_stack_list else None

# %%
# Thống kê số lượng Tech_Stack và Programming_Language sau khi chuẩn hóa
#Tổng số lượng Tech_Stack chính thức
print(f"Tổng số lượng Tech_Stack unique gốc: {len(tech_counts)}")
# print(f"Tổng số lượng ngôn ngữ lập trình bị lẫn lộn trong Tech_Stack: {cntPL}")
print(f"Tổng số lượng Tech_Stack unique sau khi được chuẩn hóa và loại bỏ ngôn ngữ lập trình lẫn lộn: {len(data_API['Tech_Stack'].explode().unique())}")
# Tổng số lượng Programming_Language chính thức
print(f"Tổng số lượng Programming_Language unique gốc: {len(programming_counts)}")
# print(f"Tổng số lượng Tech_Stack bị lẫn lộn trong Programming_Language: {cntTech}")
print(f"Tổng số lượng Programming_Language unique sau khi được chuẩn hóa và loại bỏ Tech_Stack lẫn lộn: {len(data_API['Programming_Language'].explode().unique())}")
# Out:
# Tổng số lượng Tech_Stack unique gốc: 6060
# Tổng số lượng Tech_Stack unique sau khi được chuẩn hóa và loại bỏ ngôn ngữ lập trình lẫn lộn: 5675
# Tổng số lượng Programming_Language unique gốc: 105
# Tổng số lượng Programming_Language unique sau khi được chuẩn hóa và loại bỏ Tech_Stack lẫn lộn: 53

# %%
len(data_API[data_API['Programming_Language'].notnull()])
# Out:
# 1304

# %%
data_API_before.isnull().sum()
# Out:
# Job_Title                       0
# Roles                           3
# Recruitment_Count               0
# Province                        2
# Company_Location                2
# Current_Employee_Min          159
# Current_Employee_Max          544
# Language                        2
# Tech_Stack                    184
# Programming_Language         2132
# Skills                         23
# Total_Work_Hour               510
# Salary_Min                   1629
# Salary_Max                   1366
# First_Working_Day_Of_Week     271
# Last_Working_Day_Of_Week      271
# Work_On_Saturday              206
# Work_On_Sunday                205
# Experience_Years                0
# Deadline                        0
# Company_Name                    0
# Company_Industry                0
# Job_Level                       0
# Academic_Level                  0
# Job_Type                        0
# Company_URL                     0
# Job_URL                         0
# Date_Crawl                      0
# Layout_Type                     0
# dtype: int64

# %%
data_API.isnull().sum()
# Out:
# Job_Title                       0
# Roles                           3
# Recruitment_Count               0
# Province                        2
# Company_Location                2
# Current_Employee_Min          159
# Current_Employee_Max          544
# Language                        2
# Tech_Stack                    183
# Programming_Language         2154
# Skills                         23
# Total_Work_Hour               510
# Salary_Min                   1629
# Salary_Max                   1366
# First_Working_Day_Of_Week     271
# Last_Working_Day_Of_Week      271
# Work_On_Saturday              206
# Work_On_Sunday                205
# Experience_Years                2
# Deadline                      148
# Company_Name                    2
# Company_Industry              159
# Job_Level                       2
# Academic_Level                  2
# Job_Type                        2
# Company_URL                     2
# Job_URL                         0
# Date_Crawl                      0
# Layout_Type                     0
# dtype: int64

# %%
data_API_before[['Job_Title', 'Tech_Stack','Programming_Language']].head(5)
# Out:
#                                             Job_Title  \
# 0   Kỹ Sư Triển Khai Dự Án Hệ Thống (Postsale System)
# 1                Nhân Viên Tư Vấn Phát Triển Phần Mềm
# 2  Nhân Viên Kinh Doanh/Sale/Tư Vấn Bán Hàng (Máy In)
# 3                                    Business Analyst
# 4        Nhân Viên Kinh Doanh Phần Mềm Erp/ Sales Erp
#
#                                                                                                                                                                                                 Tech_Stack  \
# 0  [VMWARE, CITRIX, HYPER-V, HPE, IBM, DELL EMC, ACTIVE DIRECTORY, DNS, MAIL SERVER, PROXY, SAN, NAS, NETAPP, HP, FUJITSU, EMC, CLOUD, ORACLE, VMWARE CERTIFIED ASSOCIATE (VCA), MCSA, NETWORKING, WIND...
# 1                                                                                  [WEBSITE, PHẦN MỀM BÁN HÀNG, PHẦN MỀM VĂN PHÒNG, PHẦN MỀM QUẢN LÝ TÀI LIỆU, HỆ THỐNG EMAIL, MẠNG LƯỚI, QUẢN LÝ WEBSITE]
# 2                                                                                                                                                                                                  [EXCEL]
# 3                                                                                       [CYBER SECURITY, DATA MODELING, MOCKUPS, PROTOTYPES, AGILE, UX/UI, DESIGN THINKING, TOÁN - TIN, KHOA HỌC MÁY TÍNH]
# 4                                                                                                                                                                                               [ERP, CRM]
#
#   Programming_Language
# 0                [SQL]
# 1                 None
# 2                 None
# 3                 None
# 4                 None

# %%
data_API[['Job_Title', 'Tech_Stack','Programming_Language']].head(5)
# Out:
#                                             Job_Title  \
# 0   KỸ SƯ TRIỂN KHAI DỰ ÁN HỆ THỐNG (POSTSALE SYSTEM)
# 1                NHÂN VIÊN TƯ VẤN PHÁT TRIỂN PHẦN MỀM
# 2  NHÂN VIÊN KINH DOANH/SALE/TƯ VẤN BÁN HÀNG (MÁY IN)
# 3                                    BUSINESS ANALYST
# 4        NHÂN VIÊN KINH DOANH PHẦN MỀM ERP/ SALES ERP
#
#                                                                                                                                                                                                 Tech_Stack  \
# 0  [LINUX, PROXY, NAS, EMC, VMWARE CERTIFIED ASSOCIATE (VCA), MICROSOFT EXCEL, FUJITSU, CLOUD COMPUTING, CITRIX, MICROSOFT WORD, ORACLE DATABASE, DNS, DATABASE CONCEPTS, MAIL SERVER, DHCP, SAN, HPE, ...
# 1                                                                                  [WEBSITE, PHẦN MỀM VĂN PHÒNG, MẠNG LƯỚI, HỆ THỐNG EMAIL, PHẦN MỀM BÁN HÀNG, PHẦN MỀM QUẢN LÝ TÀI LIỆU, QUẢN LÝ WEBSITE]
# 2                                                                                                                                                                                                  [EXCEL]
# 3                                                                                 [CYBERSECURITY, TOÁN - TIN, MOCKUPS, DESIGN THINKING, DATA MODELING, UI/UX DESIGN, KHOA HỌC MÁY TÍNH, AGILE, PROTOTYPES]
# 4                                                                                                                                                                                               [ERP, CRM]
#
#   Programming_Language
# 0                [SQL]
# 1                 None
# 2                 None
# 3                 None
# 4                 None

# %% [markdown]
# ## Thống kê lại số phần tử unique trong Tech_Stack và Programming_Language

# %%
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
flattened_Tech = list(itertools.chain.from_iterable(data_API['Tech_Stack'].dropna()))
flattened_Programming = list(itertools.chain.from_iterable(data_API['Programming_Language'].dropna()))
flattened_Province = list(itertools.chain.from_iterable(data_API['Province'].dropna()))
flattened_Language = list(itertools.chain.from_iterable(data_API['Language'].dropna()))

tech_counts = pd.Series(flattened_Tech).value_counts().reset_index()
tech_counts.columns = ['Tech_Stack', 'Count']

programming_counts = pd.Series(flattened_Programming).value_counts().reset_index()
programming_counts.columns = ['Programming_Language', 'Count']

province_counts = pd.Series(flattened_Province).value_counts().reset_index()
province_counts.columns = ['Province', 'Count']

language_counts = pd.Series(flattened_Language).value_counts().reset_index()
language_counts.columns = ['Language', 'Count']

print("\nUnique Programming Languages và số lượng:")
display(programming_counts)
print("Unique Tech Stack và số lượng:")
display(tech_counts)
print("\nUnique Provinces và số lượng:")
display(province_counts)
print("\nUnique Languages và số lượng:")
display(language_counts)
# Out:
# Unique Programming Languages và số lượng:
#    Programming_Language  Count
# 0                   SQL    798
# 1                PYTHON    436
# 2            JAVASCRIPT    363
# 3                  JAVA    330
# 4                 NOSQL    289
# 5                    C#    168
# 6            TYPESCRIPT    131
# 7                   C++    122
# 8                   PHP     97
# 9                    GO     79
# 10                 BASH     74
# 11                    C     74
# 12               KOTLIN     49
# 13                SWIFT     48
# 14                 DART     38
# 15           POWERSHELL     26
# 16          OBJECTIVE-C     21
# 17                SHELL     20
# 18                    R     20
# 19                 RUBY     14
# 20               VUE.JS     13
# 21                 PERL     10
# 22                 RUST     10
# 23                SCALA     10
# 24               VB.NET      9
# 25                 ABAP      5
# 26               MATLAB      5
# 27                  QML      3
# 28             ASSEMBLY      3
# 29                SPARK      2
# 30              VERILOG      2
# 31             POWER FX      2
# 32                  X++      2
# 33                 APEX      2
# 34              RESTFUL      1
# 35                 YAML      1
# 36                COBOL      1
# 37           APP SCRIPT      1
# 38               GROOVY      1
# 39                  LUA      1
# 40         RESTFUL APIS      1
# 41            ASSEMBLER      1
# 42                  TCL      1
# 43                   AL      1
# 44           EMBEDDED C      1
# 45                 ESQL      1
# 46       BASH SCRIPTING      1
# 47                 SASS      1
# 48   UNIX SHELL SCRIPTS      1
# 49                 SOQL      1
# 50             SOAP API      1
# 51              EXPRESS      1
# Unique Tech Stack và số lượng:
#              Tech_Stack  Count
# 0             PHOTOSHOP    717
# 1     ADOBE ILLUSTRATOR    642
# 2                    AI    469
# 3                 AGILE    391
# 4                   GIT    367
# ...                 ...    ...
# 5669          GIẢI TÍCH      1
# 5670         PYSPARK ML      1
# 5671         SPATIALITE      1
# 5672   LÝ THUYẾT ĐỒ THỊ      1
# 5673        ERP SYSTEMS      1
#
# [5674 rows x 2 columns]
# Unique Provinces và số lượng:
#                  Province  Count
# 0                  HÀ NỘI   2179
# 1             HỒ CHÍ MINH   1089
# 2                 ĐÀ NẴNG    120
# 3                 CẦN THƠ     33
# 4               HẢI PHÒNG     30
# 5                BẮC NINH     30
# 6                ĐỒNG NAI     29
# 7                HƯNG YÊN     21
# 8          THỪA THIÊN HUẾ     18
# 9             THÁI NGUYÊN     18
# 10               TÂY NINH     17
# 11              THANH HÓA     17
# 12                NGHỆ AN     16
# 13              KHÁNH HÒA     14
# 14             NƯỚC NGOÀI     14
# 15              NINH BÌNH     12
# 16               LÂM ĐỒNG     11
# 17                PHÚ THỌ      9
# 18               NHẬT BẢN      7
# 19               AN GIANG      7
# 20             QUẢNG NINH      7
# 21             QUẢNG NGÃI      6
# 22              ĐỒNG THÁP      6
# 23      BÀ RỊA - VŨNG TÀU      6
# 24  THÀNH PHỐ HỒ CHÍ MINH      5
# 25                ĐẮK LẮK      5
# 26              HẢI DƯƠNG      4
# 27               CAO BẰNG      3
# 28                HÀ TĨNH      3
# 29                GIA LAI      3
# 30                LÀO CAI      3
# 31              VĨNH LONG      3
# 32                 SƠN LA      3
# 33             BÌNH THUẬN      3
# 34                 CÀ MAU      2
# 35        QUẬN 3 - TP HCM      2
# 36               LẠNG SƠN      2
# 37              ĐIỆN BIÊN      2
# 38              QUẢNG TRỊ      2
# 39    THẠCH THẤT - HÀ NỘI      2
# 40            TUYÊN QUANG      2
# 41             BÌNH DƯƠNG      2
# 42    BÌNH THẠNH - TP HCM      2
# 43               LAI CHÂU      1
# 44              BẮC GIANG      1
# 45              QUẢNG NAM      1
# 46              VĨNH PHÚC      1
# 47                BẮC KẠN      1
# 48     PHÚ NHUẬN - TP HCM      1
# 49      CẦU GIẤY - HÀ NỘI      1
# 50              NHA TRANG      1
# 51              BÌNH ĐỊNH      1
# 52       ĐỐNG ĐA - HÀ NỘI      1
# 53       THỦ ĐỨC - TP HCM      1
# 54               NAM ĐỊNH      1
# Unique Languages và số lượng:
#              Language  Count
# 0          TIẾNG VIỆT   3450
# 1           TIẾNG ANH   1229
# 2          TIẾNG NHẬT    154
# 3         TIẾNG TRUNG     65
# 4           TIẾNG HÀN     22
# 5           TIẾNG ĐỨC      4
# 6           TIẾNG LÀO      1
# 7          TIẾNG PHÁP      1
# 8   TIẾNG TÂY BAN NHA      1
# 9    TIẾNG TRUNG QUỐC      1
# 10         TIẾNG THÁI      1

# %% [markdown]
# # Preprocessing + Basic EDA

# %% [markdown]
# ## Kiểm tra tin đăng spam

# %% [markdown]
# Thử nghiệm loại bỏ tin đăng trên biến tạm trước

# %%
# Sử dụng lại tiêu đề gốc của tên tuyển dụng để lọc bỏ trùng vì tiêu đề gốc thể hiện rõ ràng hơn sự khác nhau giữa các tin tuyển dụng
old_job_titles = data_original['job_title']
# Chuẩn hóa bằng cách viết hoa toàn bộ, loại bỏ khoảng trắng thừa
old_job_titles = old_job_titles.str.upper().str.strip()
# Thêm cột 'Old_Job_Title' vào data_API
data_API['Old_Job_Title'] = old_job_titles

# %%
#Quan sát một số cột cần thiết
check_unique_before_drop_dup = data_API[['Job_Title', 'Company_Name','Job_Type', 'Roles', 'Experience_Years', 'Job_Level', 'Academic_Level', 'Tech_Stack', 'Programming_Language', 'Province','Language', 'Job_URL', 'Deadline']].copy()
# Ghép cột tiêu đề cũ với data mới
check_unique_before_drop_dup['Old_Job_Title'] = old_job_titles
print(f"Số tin đăng trước khi kiểm tra duplicate: {check_unique_before_drop_dup.shape[0]}")
# Out:
# Số tin đăng trước khi kiểm tra duplicate: 3458

# %%
def normalize_list_field(x):
    if isinstance(x, list):
        items = sorted(set([str(i).strip().upper() for i in x if i and str(i).strip() != '']))
        return ', '.join(items)
    else:
        return ''

cols_dup = ['Old_Job_Title', 'Company_Name','Experience_Years', 'Job_Level', 'Academic_Level', 
            'Tech_Stack', 'Programming_Language', 'Province', 'Language']

# Chuẩn hóa các cột dạng list sang string
for col in list_cols:
    check_unique_before_drop_dup[col] = check_unique_before_drop_dup[col].apply(normalize_list_field)

# Loại bỏ trùng lặp, chỉ giữ lại dòng đầu tiên
check_unique_after_drop_dup = check_unique_before_drop_dup.drop_duplicates(subset=cols_dup, keep='first').reset_index(drop=True)

print(f"Số tin đăng sau khi loại trùng: {check_unique_after_drop_dup.shape[0]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ASUS\anaconda3\envs\DS111_env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Company_Location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[317], line 13
#      11 # Chuẩn hóa các cột dạng list sang string
#      12 for col in list_cols:
# ---> 13     check_unique_before_drop_dup[col] = check_unique_before_drop_dup[col].apply(normalize_list_field)
#      15 # Loại bỏ trùng lặp, chỉ giữ lại dòng đầu tiên
#      16 check_unique_after_drop_dup = check_unique_before_drop_dup.drop_duplicates(subset=cols_dup, keep='first').reset_index(drop=True)
#
# File c:\Users\ASUS\anaconda3\envs\DS111_env\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\ASUS\anaconda3\envs\DS111_env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Company_Location'

# %%
#Xem những mẫu trùng lặp (tin spam)
duplicates = check_unique_before_drop_dup[check_unique_before_drop_dup.duplicated(keep=False, subset= cols_dup)].sort_values(by=['Company_Name','Job_Title'])
print(f"Số tin đăng bị trùng kèm với tin gốc: {len(duplicates)}")
print(f"Số tin đăng bị trùng: {duplicates.shape[0]//2}")
duplicates.head(30)
# Out:
# Số tin đăng bị trùng kèm với tin gốc: 16
# Số tin đăng bị trùng: 8
#                                     Job_Title  \
# 1740             E-LEARNING CONTENT DEVELOPER
# 1746             E-LEARNING CONTENT DEVELOPER
# 558                                IT SUPPORT
# 2194                               IT SUPPORT
# 588                    THỰC TẬP SINH THIẾT KẾ
# 590                    THỰC TẬP SINH THIẾT KẾ
# 1708                         GRAPHIC DESIGNER
# 1739                         GRAPHIC DESIGNER
# 570   THỰC TẬP SINH KINH DOANH MẢNG CÔNG NGHỆ
# 1283  THỰC TẬP SINH KINH DOANH MẢNG CÔNG NGHỆ
# 92       NHÂN VIÊN TƯ VẤN PHÁT TRIỂN PHẦN MỀM
# 930      NHÂN VIÊN TƯ VẤN PHÁT TRIỂN PHẦN MỀM
# 457            CHUYÊN VIÊN GIẢI PHÁP PHẦN MỀM
# 1991           CHUYÊN VIÊN GIẢI PHÁP PHẦN MỀM
# 2508                        VIỆC LÀM TỐT NHẤT
# 2539                        VIỆC LÀM TỐT NHẤT
#
#                                        Company_Name        Job_Type  \
# 1740                 CÔNG TY CỔ PHẦN CÔNG NGHỆ PREP  TOÀN THỜI GIAN
# 1746                 CÔNG TY CỔ PHẦN CÔNG NGHỆ PREP  TOÀN THỜI GIAN
# 558   CÔNG TY CỔ PHẦN DỊCH VỤ CÔNG NGHỆ TIN HỌC HPT  TOÀN THỜI GIAN
# 2194  CÔNG TY CỔ PHẦN DỊCH VỤ CÔNG NGHỆ TIN HỌC HPT  TOÀN THỜI GIAN
# 588                   CÔNG TY CỔ PHẦN GOVI VIỆT NAM  TOÀN THỜI GIAN
# 590                   CÔNG TY CỔ PHẦN GOVI VIỆT NAM  TOÀN THỜI GIAN
# 1708            CÔNG TY CỔ PHẦN ĐẦU TƯ K&G VIỆT NAM  TOÀN THỜI GIAN
# 1739            CÔNG TY CỔ PHẦN ĐẦU TƯ K&G VIỆT NAM  TOÀN THỜI GIAN
# 570                         CÔNG TY TNHH AN ĐỨC TÂM  TOÀN THỜI GIAN
# 1283                        CÔNG TY TNHH AN ĐỨC TÂM  TOÀN THỜI GIAN
# 92           CÔNG TY TNHH CÔNG NGHỆ PHẦN MỀM NASANI  TOÀN THỜI GIAN
# 930          CÔNG TY TNHH CÔNG NGHỆ PHẦN MỀM NASANI  TOÀN THỜI GIAN
# 457                   CÔNG TY TNHH PHÁT TRIỂN AROMA  TOÀN THỜI GIAN
# 1991                  CÔNG TY TNHH PHÁT TRIỂN AROMA  TOÀN THỜI GIAN
# 2508                                           None            None
# 2539                                           None            None
#
#                                                                                                                                                                                  Roles  \
# 1740                                                                                                    GIÁO DỤC/ĐÀO TẠO, GIÁO DỤC/ĐÀO TẠO KHÁC, PHÁT TRIỂN HỌC LIỆU/THIẾT KẾ KHÓA HỌC
# 1746                                                                                                    GIÁO DỤC/ĐÀO TẠO, GIÁO DỤC/ĐÀO TẠO KHÁC, PHÁT TRIỂN HỌC LIỆU/THIẾT KẾ KHÓA HỌC
# 558                                                                                           CÔNG NGHỆ THÔNG TIN, IT INFRASTRUCTURE AND OPERATIONS, SYSTEM ADMINISTRATOR, VIỆC LÀM IT
# 2194                                                                                          CÔNG NGHỆ THÔNG TIN, IT INFRASTRUCTURE AND OPERATIONS, SYSTEM ADMINISTRATOR, VIỆC LÀM IT
# 588   CÔNG NGHỆ THÔNG TIN, MARKETING/PR/QUẢNG CÁO, QUẢNG CÁO/SÁNG TẠO, SOFTWARE DESIGN, THIẾT KẾ, THIẾT KẾ ĐỒ HOẠ/GIAO DIỆN/TRẢI NGHIỆM, THIẾT KẾ ĐỒ HỌA (GRAPHIC DESIGN), VIỆC LÀM IT
# 590   CÔNG NGHỆ THÔNG TIN, MARKETING/PR/QUẢNG CÁO, QUẢNG CÁO/SÁNG TẠO, SOFTWARE DESIGN, THIẾT KẾ, THIẾT KẾ ĐỒ HOẠ/GIAO DIỆN/TRẢI NGHIỆM, THIẾT KẾ ĐỒ HỌA (GRAPHIC DESIGN), VIỆC LÀM IT
# 1708  CÔNG NGHỆ THÔNG TIN, MARKETING/PR/QUẢNG CÁO, QUẢNG CÁO/SÁNG TẠO, SOFTWARE DESIGN, THIẾT KẾ, THIẾT KẾ ĐỒ HOẠ/GIAO DIỆN/TRẢI NGHIỆM, THIẾT KẾ ĐỒ HỌA (GRAPHIC DESIGN), VIỆC LÀM IT
# 1739  CÔNG NGHỆ THÔNG TIN, MARKETING/PR/QUẢNG CÁO, QUẢNG CÁO/SÁNG TẠO, SOFTWARE DESIGN, THIẾT KẾ, THIẾT KẾ ĐỒ HOẠ/GIAO DIỆN/TRẢI NGHIỆM, THIẾT KẾ ĐỒ HỌA (GRAPHIC DESIGN), VIỆC LÀM IT
# 570                                                                                      CÔNG NGHỆ THÔNG TIN, KINH DOANH PHẦN MỀM, KINH DOANH/BÁN HÀNG, SALES IT PHẦN MỀM, VIỆC LÀM IT
# 1283                                                                                     CÔNG NGHỆ THÔNG TIN, KINH DOANH PHẦN MỀM, KINH DOANH/BÁN HÀNG, SALES IT PHẦN MỀM, VIỆC LÀM IT
# 92                                                                                                         CÔNG NGHỆ THÔNG TIN, IT PROJECT MANAGEMENT, IT PROJECT MANAGER, VIỆC LÀM IT
# 930                                                                                                        CÔNG NGHỆ THÔNG TIN, IT PROJECT MANAGEMENT, IT PROJECT MANAGER, VIỆC LÀM IT
# 457                                                                                    CHUYÊN MÔN CÔNG NGHỆ THÔNG TIN KHÁC, CÔNG NGHỆ THÔNG TIN, CÔNG NGHỆ THÔNG TIN KHÁC, VIỆC LÀM IT
# 1991                                                                                     CÔNG NGHỆ THÔNG TIN, KINH DOANH PHẦN MỀM, KINH DOANH/BÁN HÀNG, SALES IT PHẦN MỀM, VIỆC LÀM IT
# 2508
# 2539
#
#      Experience_Years      Job_Level     Academic_Level  \
# 1740            2 NĂM      NHÂN VIÊN    ĐẠI HỌC TRỞ LÊN
# 1746            2 NĂM      NHÂN VIÊN    ĐẠI HỌC TRỞ LÊN
# 558             2 NĂM      NHÂN VIÊN  TRUNG CẤP TRỞ LÊN
# 2194            2 NĂM      NHÂN VIÊN  TRUNG CẤP TRỞ LÊN
# 588     KHÔNG YÊU CẦU  THỰC TẬP SINH   CAO ĐẲNG TRỞ LÊN
# 590     KHÔNG YÊU CẦU  THỰC TẬP SINH   CAO ĐẲNG TRỞ LÊN
# 1708            3 NĂM      NHÂN VIÊN   CAO ĐẲNG TRỞ LÊN
# 1739            3 NĂM      NHÂN VIÊN   CAO ĐẲNG TRỞ LÊN
# 570     KHÔNG YÊU CẦU  THỰC TẬP SINH    ĐẠI HỌC TRỞ LÊN
# 1283    KHÔNG YÊU CẦU  THỰC TẬP SINH    ĐẠI HỌC TRỞ LÊN
# 92      KHÔNG YÊU CẦU      NHÂN VIÊN  TRUNG CẤP TRỞ LÊN
# 930     KHÔNG YÊU CẦU      NHÂN VIÊN  TRUNG CẤP TRỞ LÊN
# 457             3 NĂM      NHÂN VIÊN    ĐẠI HỌC TRỞ LÊN
# 1991            3 NĂM      NHÂN VIÊN    ĐẠI HỌC TRỞ LÊN
# 2508             None           None               None
# 2539             None           None               None
#
#                                                                                                                                                                                Tech_Stack  \
# 1740  ADOBE CAPTIVATE, ANIMATION, ARTICULATE STORYLINE, E-LEARNING, EDUCATIONAL TECHNOLOGY, EDUCATIONAL VIDEO PRODUCTION, ELT MATERIALS DEVELOPMENT, GRAPHIC DESIGN, INSTRUCTIONAL DESIGN
# 1746  ADOBE CAPTIVATE, ANIMATION, ARTICULATE STORYLINE, E-LEARNING, EDUCATIONAL TECHNOLOGY, EDUCATIONAL VIDEO PRODUCTION, ELT MATERIALS DEVELOPMENT, GRAPHIC DESIGN, INSTRUCTIONAL DESIGN
# 558                                                                                                           AUTOPILOT, INTUNE, ITIL, LAN/VLAN, MICROSOFT OFFICE, TICKET SYSTEM, WINDOWS
# 2194                                                                                                          AUTOPILOT, INTUNE, ITIL, LAN/VLAN, MICROSOFT OFFICE, TICKET SYSTEM, WINDOWS
# 588                                                                                                                                                          ADOBE ILLUSTRATOR, PHOTOSHOP
# 590                                                                                                                                                          ADOBE ILLUSTRATOR, PHOTOSHOP
# 1708                                                                                            ADOBE AFTER EFFECTS, ADOBE ILLUSTRATOR, ADOBE INDESIGN, ADOBE PREMIERE, CAPCUT, PHOTOSHOP
# 1739                                                                                            ADOBE AFTER EFFECTS, ADOBE ILLUSTRATOR, ADOBE INDESIGN, ADOBE PREMIERE, CAPCUT, PHOTOSHOP
# 570                                                                                                                                                               MARKETING, SEO, WEBSITE
# 1283                                                                                                                                                              MARKETING, SEO, WEBSITE
# 92                                                                                                                                                                      CRM, ERP, WEBSITE
# 930                                                                                                                                                                     CRM, ERP, WEBSITE
# 457                                                                                                                                                         BPM, CRM, HRM, NOCODE/LOWCODE
# 1991                                                                                                                                                        BPM, CRM, HRM, NOCODE/LOWCODE
# 2508
# 2539
#
#      Programming_Language             Province               Language  \
# 1740                                    HÀ NỘI  TIẾNG ANH, TIẾNG VIỆT
# 1746                                    HÀ NỘI  TIẾNG ANH, TIẾNG VIỆT
# 558                                   ĐỒNG NAI  TIẾNG ANH, TIẾNG VIỆT
# 2194                                  ĐỒNG NAI  TIẾNG ANH, TIẾNG VIỆT
# 588                                     HÀ NỘI             TIẾNG VIỆT
# 590                                     HÀ NỘI             TIẾNG VIỆT
# 1708                                    HÀ NỘI             TIẾNG VIỆT
# 1739                                    HÀ NỘI             TIẾNG VIỆT
# 570                                     HÀ NỘI             TIẾNG VIỆT
# 1283                                    HÀ NỘI             TIẾNG VIỆT
# 92                                     CẦN THƠ  TIẾNG ANH, TIẾNG VIỆT
# 930                                    CẦN THƠ  TIẾNG ANH, TIẾNG VIỆT
# 457                        HÀ NỘI, HỒ CHÍ MINH             TIẾNG VIỆT
# 1991                       HÀ NỘI, HỒ CHÍ MINH             TIẾNG VIỆT
# 2508
# 2539
#
#                                                                                                                                                                                                       Job_URL  \
# 1740                                   HTTPS://WWW.TOPCV.VN/VIEC-LAM/E-LEARNING-CONTENT-DEVELOPER/1911489.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765096196
# 1746                                   HTTPS://WWW.TOPCV.VN/VIEC-LAM/E-LEARNING-CONTENT-DEVELOPER/1911483.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765096196
# 558                                                      HTTPS://WWW.TOPCV.VN/VIEC-LAM/IT-SUPPORT/1974505.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765095930
# 2194                                                     HTTPS://WWW.TOPCV.VN/VIEC-LAM/IT-SUPPORT/1974514.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765096298
# 588                                          HTTPS://WWW.TOPCV.VN/VIEC-LAM/THUC-TAP-SINH-THIET-KE/1974248.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765095930
# 590                                          HTTPS://WWW.TOPCV.VN/VIEC-LAM/THUC-TAP-SINH-THIET-KE/1974184.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765095930
# 1708                                               HTTPS://WWW.TOPCV.VN/VIEC-LAM/GRAPHIC-DESIGNER/1952528.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765096184
# 1739                                               HTTPS://WWW.TOPCV.VN/VIEC-LAM/GRAPHIC-DESIGNER/1952526.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765096196
# 570                         HTTPS://WWW.TOPCV.VN/VIEC-LAM/THUC-TAP-SINH-KINH-DOANH-MANG-CONG-NGHE/1974430.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765095930
# 1283                        HTTPS://WWW.TOPCV.VN/VIEC-LAM/THUC-TAP-SINH-KINH-DOANH-MANG-CONG-NGHE/1961847.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765096094
# 92    HTTPS://WWW.TOPCV.VN/VIEC-LAM/NHAN-VIEN-TU-VAN-PHAT-TRIEN-PHAN-MEM-CAN-THO-THU-NHAP-LEN-DEN-25TR-THANG/1975529.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWI...
# 930   HTTPS://WWW.TOPCV.VN/VIEC-LAM/NHAN-VIEN-TU-VAN-PHAT-TRIEN-PHAN-MEM-CAN-THO-THU-NHAP-LEN-DEN-25TR-THANG/1952479.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWI...
# 457                                  HTTPS://WWW.TOPCV.VN/VIEC-LAM/CHUYEN-VIEN-GIAI-PHAP-PHAN-MEM/1887527.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765095908
# 1991                                 HTTPS://WWW.TOPCV.VN/VIEC-LAM/CHUYEN-VIEN-GIAI-PHAP-PHAN-MEM/1708669.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765096252
# 2508    HTTPS://WWW.TOPCV.VN/BRAND/MATBAO/TUYEN-DUNG/NHAN-VIEN-THIET-KE-KIEM-TRUYEN-THONG-NOI-BO-J1967886.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765096377
# 2539                          HTTPS://WWW.TOPCV.VN/BRAND/BPOMATBAO/TUYEN-DUNG/NHAN-VIEN-THIET-KE-J1967238.HTML?TA_SOURCE=JOBSEARCHLIST_LINKDETAIL&U_SR_ID=VHBFIO4GQAZLKYP8JN9CN4VEEPC9RH4HVUZWIQL6_1765096377
#
#         Deadline  \
# 1740  31/12/2025
# 1746  31/12/2025
# 558   03/01/2026
# 2194  03/01/2026
# 588   03/01/2026
# 590   03/01/2026
# 1708  15/12/2025
# 1739  14/12/2025
# 570   03/01/2026
# 1283  24/12/2025
# 92    04/01/2026
# 930   14/12/2025
# 457   04/01/2026
# 1991  20/12/2025
# 2508        None
# 2539        None
#
#                                                                      Old_Job_Title
# 1740                                                  E-LEARNING CONTENT DEVELOPER
# 1746                                                  E-LEARNING CONTENT DEVELOPER
# 558                                                                     IT SUPPORT
# 2194                                                                    IT SUPPORT
# 588                                                         THỰC TẬP SINH THIẾT KẾ
# 590                                                         THỰC TẬP SINH THIẾT KẾ
# 1708                                                              GRAPHIC DESIGNER
# 1739                                                              GRAPHIC DESIGNER
# 570                                        THỰC TẬP SINH KINH DOANH MẢNG CÔNG NGHỆ
# 1283                                       THỰC TẬP SINH KINH DOANH MẢNG CÔNG NGHỆ
# 92    NHÂN VIÊN TƯ VẤN PHÁT TRIỂN PHẦN MỀM (CẦN THƠ - THU NHẬP LÊN ĐẾN 25TR/THÁNG)
# 930   NHÂN VIÊN TƯ VẤN PHÁT TRIỂN PHẦN MỀM (CẦN THƠ - THU NHẬP LÊN ĐẾN 25TR/THÁNG)
# 457                                                 CHUYÊN VIÊN GIẢI PHÁP PHẦN MỀM
# 1991                                                CHUYÊN VIÊN GIẢI PHÁP PHẦN MỀM
# 2508                                                             VIỆC LÀM TỐT NHẤT
# 2539                                                             VIỆC LÀM TỐT NHẤT

# %% [markdown]
# Nhận thấy loại bỏ trùng lặp bằng các trường nói trên là phù hợp. Trong đó 'Tech_Stack', 'Programming_Language' thay đổi nếu yêu cầu công việc thay đổi -> Có thể xem là 1 tin đăng unique. Ta sẽ tiến hành loại bỏ trên bộ data đã được xử lí bằng API.

# %%
# Chuẩn hóa các cột dạng list sang string
for col in list_cols:
    data_API[col] = data_API[col].apply(normalize_list_field)

# Loại bỏ trùng lặp, chỉ giữ lại dòng đầu tiên
data_API = data_API.drop_duplicates(subset=cols_dup, keep='first').reset_index(drop=True)

# Thay các giá trị rỗng trong các cột dạng list về UNKNOWN
data_API[list_cols] = data_API[list_cols].map(lambda x: 'UNKNOWN' if isinstance(x, str) and x.strip() == '' else x)

# Chuyển đổi lại kiểu dữ liệu của các cột Tech_Stack, Programming_Language, Province, Language về lại dạng list, ngăn cách bởi dấu phẩy
for col in list_cols:
    data_API[col] = data_API[col].apply(lambda x: list(x.split(',')) if isinstance(x, str) else x)

print(f"Số tin đăng sau khi loại trùng: {data_API.shape[0]}")
# Out:
# Số tin đăng sau khi loại trùng: 3450

# %%
#Check lại kiểu dữ liệu, chọn các thuộc tính không null để kiểm tra dữ liệu
type(data_API['Tech_Stack'].iloc[7]), type(data_API['Programming_Language'].iloc[10]), type(data_API['Province'].iloc[0]), type(data_API['Language'].iloc[0])
# Out:
# (list, list, list, list)

# %% [markdown]
# ## Kiểm tra missing value

# %%
#Check for missing values
data_API.isnull().sum().sort_values(ascending=False)
# Out:
# Salary_Min                   1628
# Salary_Max                   1365
# Current_Employee_Max          542
# Total_Work_Hour               509
# Last_Working_Day_Of_Week      270
# First_Working_Day_Of_Week     270
# Work_On_Saturday              205
# Work_On_Sunday                204
# Current_Employee_Min          158
# Company_Industry              158
# Deadline                      147
# Skills                         22
# Company_Location                1
# Experience_Years                1
# Job_Level                       1
# Academic_Level                  1
# Job_Type                        1
# Company_URL                     1
# Company_Name                    1
# Roles                           0
# Province                        0
# Job_Title                       0
# Tech_Stack                      0
# Language                        0
# Programming_Language            0
# Recruitment_Count               0
# Job_URL                         0
# Date_Crawl                      0
# Layout_Type                     0
# Old_Job_Title                   0
# dtype: int64

# %%
#Hiển thị số lượng thiếu dưới dạng phần trăm
missing_percentage = round(data_API.isnull().mean() * 100,0)
missing_percentage.sort_values(ascending=False)
# Out:
# Salary_Min                   47.0
# Salary_Max                   40.0
# Current_Employee_Max         16.0
# Total_Work_Hour              15.0
# Last_Working_Day_Of_Week      8.0
# First_Working_Day_Of_Week     8.0
# Work_On_Sunday                6.0
# Work_On_Saturday              6.0
# Current_Employee_Min          5.0
# Company_Industry              5.0
# Deadline                      4.0
# Skills                        1.0
# Company_Location              0.0
# Province                      0.0
# Tech_Stack                    0.0
# Language                      0.0
# Programming_Language          0.0
# Job_Title                     0.0
# Roles                         0.0
# Recruitment_Count             0.0
# Experience_Years              0.0
# Company_Name                  0.0
# Job_Level                     0.0
# Academic_Level                0.0
# Job_Type                      0.0
# Company_URL                   0.0
# Job_URL                       0.0
# Date_Crawl                    0.0
# Layout_Type                   0.0
# Old_Job_Title                 0.0
# dtype: float64

# %% [markdown]
# ### Xử lí Salary_Min, Salary_Max

# %%
#Vẽ biểu đồ histogram Salary_Min, Salary_Max
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(data_API['Salary_Min'].dropna(), bins=50, color='blue', alpha=0.7)
plt.title('Histogram of Salary_Min')
plt.xlabel('Salary_Min')
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
plt.hist(data_API['Salary_Max'].dropna(), bins=50, color='green', alpha=0.7)
plt.title('Histogram of Salary_Max')
plt.xlabel('Salary_Max')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# Biểu đồ cho thấy phân phối về mức lương cả tối thiểu và tối đa đều lệch phải nặng, ta sẽ ưu tiên tiến hành xử lí giá trị rỗng bằng cách lấy theo giá trị trung vị cục bộ (lấy cho từng 'Role') nhằm tạo ra mức lương ở mức tham khảo khi thống kê đồng thời tránh hiện tượng outlier. Nếu toàn bộ nhóm 'Role' nào đó không có mức lương cụ thể thì điền giá trị -1:

# %%
# Dữ liệu trước khi điền missing values
data_API[data_API['Salary_Min'].isnull() | data_API['Salary_Max'].isnull()][['Job_Title', 'Salary_Min', 'Salary_Max']].head(20)
# Out:
#                                                                  Job_Title  \
# 5                                                     AI/ROBOTICS ENGINEER
# 6                                            NETWORK ENGINEER (TRIỂN KHAI)
# 9                                                NHÂN VIÊN KINH DOANH CNTT
# 12                            SENIOR FRONTEND DEVELOPER (REACT.JS/NEXT.JS)
# 14                                                          JAVA DEVELOPER
# 15                                                   PRODUCT DESIGN LEADER
# 18                                                             AI ENGINEER
# 19                                                     LẬP TRÌNH VIÊN .NET
# 22                                                          MANUAL TESTERS
# 23                                                            DATA ANALYST
# 24  CHUYÊN VIÊN PHÂN TÍCH NGHIỆP VỤ (BUSINESS ANALYST) - KVH - MSB - 4M009
# 25                       THỰC TẬP SINH NETWORK SECURITY (SECURITY/ INTERN)
# 26                                   SOFTWARE TESTER (MANUAL & AUTOMATION)
# 30                                             THỰC TẬP SINH GAME DESIGNER
# 31                               PRODUCTION LEAD (VISUAL SUPERVISOR) - VVE
# 32                      VISUAL PRODUCER (PROJECT MANAGER, KOREAN SPEAKING)
# 33                                                          .NET DEVELOPER
# 37                              BACKEND DEVELOPER - SENIOR LEVEL (PYTHONL)
# 39                                                 GRAPHIC DESIGNER LEADER
# 40                                                          JAVA DEVELOPER
#
#     Salary_Min  Salary_Max
# 5          NaN         NaN
# 6          NaN  25000000.0
# 9          NaN         NaN
# 12         NaN  30000000.0
# 14         NaN         NaN
# 15         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 22         NaN  20000000.0
# 23         NaN  30000000.0
# 24         NaN         NaN
# 25         NaN         NaN
# 26         NaN  22000000.0
# 30   6000000.0         NaN
# 31         NaN         NaN
# 32         NaN         NaN
# 33         NaN         NaN
# 37         NaN  40000000.0
# 39         NaN         NaN
# 40         NaN         NaN

# %%
# Xử lí giá trị thiếu trong cột Salary_Min và Salary_Max bằng cách điền giá trị trung vị cục bộ theo 'Role', n
data_API['Salary_Min'] = data_API.groupby('Role')['Salary_Min'].transform(
    lambda x: x.fillna(x.median() if not x.dropna().empty else -1)  
)
data_API['Salary_Max'] = data_API.groupby('Role')['Salary_Max'].transform(
    lambda x: x.fillna(x.median() if not x.dropna().empty else -1)  
)
# Kiểm tra lại dữ liệu sau khi điền giá trị trung vị
data_API[data_API['Salary_Min'].isnull() | data_API['Salary_Max'].isnull()][['Job_Title','Role' ,'Salary_Min', 'Salary_Max', 'Job_URL']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[114], line 2
#       1 # Xử lí giá trị thiếu trong cột Salary_Min và Salary_Max bằng cách điền giá trị trung vị cục bộ theo 'Role', n
# ----> 2 data_API['Salary_Min'] = data_API.groupby('Role')['Salary_Min'].transform(
#       3     lambda x: x.fillna(x.median() if not x.dropna().empty else -1)
#       4 )
#       5 data_API['Salary_Max'] = data_API.groupby('Role')['Salary_Max'].transform(
#       6     lambda x: x.fillna(x.median() if not x.dropna().empty else -1)
#       7 )
#       8 # Kiểm tra lại dữ liệu sau khi điền giá trị trung vị
#
# File c:\Users\ASUS\anaconda3\envs\DS111_env\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File c:\Users\ASUS\anaconda3\envs\DS111_env\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\ASUS\anaconda3\envs\DS111_env\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Role'

# %%
data_API.describe().T

# %%
data_API.isnull().sum().sort_values(ascending=False)

# %%
#Hiển thị số tự nhiên không phải số khoa học
pd.options.display.float_format = '{:,.0f}'.format

# %%
data_API[data_API['Salary_Max'] > data_API['Salary_Max'].mean()][['Job_Title', 'Salary_Min', 'Salary_Max', 'Job_URL']].nlargest(20, 'Salary_Max')

# %% [markdown]
# Một số mức lương cao bất thường, đó là do đang tính tổng thu nhập trong 1 năm thay vì 1 tháng như các ngành khác

# %% [markdown]
# ### Kiểm tra bất thường, có mẫu dữ liệu nào có mức lương tối thiểu cao hơn lương tối đa không?

# %%
abnormal_salary = data_API[(data_API['Salary_Min'] > data_API['Salary_Max'])][['Job_Title', 'Salary_Min', 'Salary_Max', 'Job_URL']]
abnormal_salary

# %%
old_index = abnormal_salary.index
abnormal_salary = pd.merge(abnormal_salary, data_original[['Salary', 'Job_URL']], on='Job_URL', how='left')
abnormal_salary.index = old_index
abnormal_salary

# %%
# Chạy vòng lặp xử lí các giá trị bất thường trong cột Salary_Min và Salary_Max va cap nhat lai index trong bộ data_API
for idx, row in abnormal_salary.iterrows():
    original_salary = row['Salary']
    if 'Từ' in original_salary and 'Tới' not in original_salary:
        data_API.at[idx, 'Salary_Max'] = -1
    elif 'Tới' in original_salary and 'Từ' not in original_salary:
        data_API.at[idx, 'Salary_Min'] = -1
    else:
        data_API.at[idx, 'Salary_Min'] = -1
        data_API.at[idx, 'Salary_Max'] = -1

# %% [markdown]
# Kiểm tra lại sau quá trình xử lý bất thường trong dữ liệu lương

# %%
# Kiểm tra lại bất thường sau khi xử lí
data_API[(data_API['Salary_Min'] > data_API['Salary_Max'])][['Job_Title', 'Salary_Min', 'Salary_Max', 'Job_URL']]

# %%
data_API.describe().T

# %% [markdown]
# Nhận thấy sau khi xử lí các trường hợp chưa nhất quán, dữ liệu ở các trường liên quan đến lương đã ổn

# %% [markdown]
# ### Xử lí Programming_Language và Tech_Stack

# %%
data_API[data_API['Programming_Language'].isnull() & data_API['Tech_Stack'].isnull()][['Role', 'Job_Title', 'Programming_Language', 'Tech_Stack', 'Job_URL']].sort_values(by='Role')

# %%
data_original.info()

# %% [markdown]
# Do việc đáp ứng nhu cầu tuyển dụng chủ yếu dựa vào Tech_Stack và Programming_Language, thế nên ta sẽ xem chi tiết các mẫu dữ liệu bị thiếu ở cả 2 trường này không và tiến hành xử lí null

# %%
#Check các mẫu dữ liệu không có giá trị ở mục 'Tech_Stack'
tech_pro = data_API[data_API['Tech_Stack'].isnull() | data_API['Programming_Language'].isnull()][['Job_Title','Tech_Stack', 'Programming_Language', 'Job_URL', 'Recruitment_Count', 'Roles']]
print(f"Số mẫu dữ liệu bị null ở mục 'Tech_Stack' (không null ở 'Programming_Language') là: {tech_pro[tech_pro['Programming_Language'].notnull() & tech_pro['Tech_Stack'].isnull()].shape[0]}")
print(f"Số mẫu dữ liệu bị null ở mục 'Programming_Language' (không null ở 'Tech_Stack') là: {tech_pro[tech_pro['Programming_Language'].isnull() & tech_pro['Tech_Stack'].notnull()].shape[0]}")
print(f"Số mẫu dữ liệu bị null ở cả 2 mục 'Tech_Stack' và 'Programming_Language' là: {tech_pro[tech_pro['Programming_Language'].isnull() & tech_pro['Tech_Stack'].isnull()].shape[0]}")

# %%
# Số mẫu dữ liệu có giá trị ở mục 'Tech_Stack' và 'Programming_Language'
tech_pro[tech_pro['Programming_Language'].isnull() & tech_pro['Tech_Stack'].isnull()]['Role'].value_counts()

# %%
data_bronze = pd.read_csv(r'D:\Python_code\DS108_Đồ_án\Table_Decomposition\297_records_data_bronze.csv')

# %% [markdown]
# #### Kiểm tra các mấu tin tuyển dụng trống cả 2 trường Tech_Stack và Programming_Language

# %%
data_bronze[data_bronze['Role'] == 'Business Analyst (Phân tích nghiệp vụ)'][['Role','Skills', 'Job_URL']]

# %%
data_bronze[data_bronze['Role'] == 'Product Owner/Product Manager'][['Role','Skills', 'Job_URL']]

# %%
data_bronze[data_bronze['Role'] == 'Công nghệ thông tin khác'][['Role','Skills', 'Job_URL']]

# %%
data_API[data_API['Programming_Language'].isnull() & data_API['Tech_Stack'].isnull() & (data_API['Role'] == 'Business Analyst (Phân tích nghiệp vụ)')][['Role', 'Job_Title', 'Programming_Language', 'Tech_Stack', 'Job_URL']].sort_values(by='Role').head(20)

# %% [markdown]
# Vì trường Skills  có dữ liệu không nhất quán đối với các công việc không yêu cầu về vấn đề kĩ thuật, ta xử lí trường hợp NULL ở cả 2 trường tech stack và programming language bằng cách điền -1 vào nhằm bảo toàn số lượng tin đăng tuyển dụng mà không phải loại bỏ

# %% [markdown]
# Nhận thấy phần lớn các role không đặt nặng yêu cầu tuyển dụng về công nghệ sử dụng và ngôn ngữ lập trình hầu hết là quản lí dự án, phân tích nghiệp vụ, tester và nhân viên IT kĩ thuật nói chung. Ta sẽ điền giá trị 'UNKNOWN'

# %%
data_API['Programming_Language'] = data_API['Programming_Language'].fillna('UNKNOWN') # Điền giá trị 'UNKNOWN' vào các ô đã được chuyển kiểu thành string
data_API['Programming_Language'] = data_API['Programming_Language'].apply(lambda x: [x] if isinstance(x, str) else x) # Chuyển đổi giá trị ở dạng string thành list để đảm bảo tính nhất quán
data_API['Tech_Stack'] = data_API['Tech_Stack'].fillna('UNKNOWN')# Điền giá trị 'UNKNOWN' vào các ô đã được chuyển kiểu thành string
data_API['Tech_Stack'] = data_API['Tech_Stack'].apply(lambda x: [x] if isinstance(x, str) else x) # Chuyển đổi giá trị ở dạng string thành list để đảm bảo tính nhất quán
# Kiểm tra lại dữ liệu sau khi điền giá trị 'UNKNOWN'
data_API[data_API['Programming_Language'].isnull() | data_API['Tech_Stack'].isnull()][['Job_Title', 'Programming_Language', 'Tech_Stack', 'Job_URL']] 
data_API.isnull().sum().sort_values(ascending=False)

# %%
data_API['Programming_Language'].apply(type).value_counts()

# %% [markdown]
# - Có khoảng 341 thông tin tuyển dụng yêu cầu kĩ năng khác, không yêu cầu kĩ năng liên quan nhiều tới technical.
# - Cần xử lý trường hợp cả hai trường đều bị thiếu giá trị trong một mẫu dữ liệu. Lúc này dòng dữ liệu sẽ không còn mang ý nghĩa nhiều vì thiếu 2 trường quan trọng thể hiện nhiều nhất nhu cầu tuyển dụng

# %% [markdown]
# ### Xử lí dữ liệu thời gian làm việc trong tuần lần lượt theo thứ tự 1 -> 2 -> 3:
# 1. ['Work_On_Saturday', 'Work_On_Sunday']
# 2. ['First_Working_Day_Of_Week', 'Last_Working_Day_Of_Week']
# 3. ['Total_Work_Hour']

# %%
data_API.isnull().sum().sort_values(ascending=False)

# %%
data_API[['First_Working_Day_Of_Week', 'Last_Working_Day_Of_Week', 'Work_On_Saturday', 'Work_On_Sunday']].isnull().sum()

# %% [markdown]
# #### Xử lí 'Work_On_Saturday', 'Work_On_Sunday'

# %%
# Xem các tin tuyển dụng được xác định trong bộ dữ liệu có nghỉ Thứ 7/CN
data_API[(data_API['Work_On_Saturday'].notnull()) | (data_API['Work_On_Sunday'].notnull())][['Job_Title', 'Company_Name', 'Work_On_Saturday','Work_On_Sunday', 'Job_URL']].head(20)

# %%
# Xem các tin tuyển dụng không được xác định trong bộ dữ liệu có nghỉ Thứ 7/CN
data_API[data_API['Work_On_Saturday'].isnull() | data_API['Work_On_Sunday'].isnull()][['Job_Title', 'First_Working_Day_Of_Week','Last_Working_Day_Of_Week','Work_On_Saturday', 'Work_On_Sunday','Total_Work_Hour', 'Job_URL']].head(20)

# %% [markdown]
# #### Xử lí 'First_Working_Day_Of_Week', 'Last_Working_Day_Of_Week'

# %%
data_API[data_API['First_Working_Day_Of_Week'].isnull() | data_API['Last_Working_Day_Of_Week'].isnull()][['Job_Title', 'First_Working_Day_Of_Week', 'Last_Working_Day_Of_Week','Work_On_Saturday', 'Work_On_Sunday','Total_Work_Hour', 'Job_URL']]

# %% [markdown]
# Các mẫu dữ liệu trên không được cung cấp ngày làm việc cụ thể trong link tuyển dụng gốc, đồng thời 2 thuộc tính Work_On_Saturday và Work_On_Sunday đưa ra giá trị mặc định chưa chuẩn (Vì nếu không có thông tin thì phải trả về None) --> Đang điều chỉnh cách prompt

# %% [markdown]
# #### Xử lí Total_Work_Hour

# %%
col_display = ['Job_Title', 'Total_Work_Hour', 'Job_URL']
data_API[col_display].head(200)

# %%
#Kiểm tra các mẫu dữ liệu không có giá trị ở mục 'Total_Work_Hour'
data_API[data_API['Total_Work_Hour'].isnull()][['Job_Title', 'First_Working_Day_Of_Week','Last_Working_Day_Of_Week','Work_On_Saturday', 'Work_On_Sunday','Total_Work_Hour', 'Job_URL']]

# %%
#Kiểm tra các mẫu dữ liệu không có giá trị ở mục 'Total_Work_Hour' và không có giá trị ở mục 'First_Working_Day_Of_Week' và 'Last_Working_Day_Of_Week'
data_API[data_API['Total_Work_Hour'].isnull() & data_API['First_Working_Day_Of_Week'].isnull() & data_API['Last_Working_Day_Of_Week'].isnull()][['Job_Title', 'First_Working_Day_Of_Week','Last_Working_Day_Of_Week','Work_On_Saturday', 'Work_On_Sunday','Total_Work_Hour', 'Job_URL']]

# %%
#Kiểm tra các mẫu dữ liệu không có giá trị ở mục 'Total_Work_Hour' và có giá trị ở mục 'First_Working_Day_Of_Week' và 'Last_Working_Day_Of_Week'
data_API[data_API['Total_Work_Hour'].isnull() & data_API['First_Working_Day_Of_Week'].notnull() & data_API['Last_Working_Day_Of_Week'].notnull()][['Job_Title', 'Role','First_Working_Day_Of_Week','Last_Working_Day_Of_Week','Work_On_Saturday', 'Work_On_Sunday','Total_Work_Hour', 'Job_URL']]

# %% [markdown]
# Nhìn chung, Total_Work_Hour	còn thiếu nhiều giá trị dữ liệu có phần lớn liên quan tới ngày đi làm trong tuần (First_Working_Day_Of_Week và Last_Working_Day_Of_Week). Nếu giá trị ngày đi làm bị thiếu thì khả năng cao không tồn tại giá trị tương ứng cho mẫu dữ liệu đó ở trường Total_Work_Hour -> Missing at random

# %% [markdown]
# Chuyển đổi 'First_Working_Day_Of_Week', 'Last_Working_Day_Of_Week' thành biến categorical và xem ngày đi làm phổ biến nhất

# %%
data_working_day = data_API[['First_Working_Day_Of_Week', 'Last_Working_Day_Of_Week', 'Work_On_Saturday', 'Work_On_Sunday']].copy()
# Chuyển đổi các giá trị 'First_Working_Day_Of_Week' và 'Last_Working_Day_Of_Week' thành dạng categorical
data_working_day['First_Working_Day_Of_Week'] = data_working_day['First_Working_Day_Of_Week'].astype('str')
data_working_day['Last_Working_Day_Of_Week'] = data_working_day['Last_Working_Day_Of_Week'].astype('str')
data_working_day.describe(include='object').T

# %% [markdown]
# Xem số giờ đi làm phổ biến nhất

# %%
data_API['Total_Work_Hour'].describe()

# %% [markdown]
# Điền giá trị phổ biến nhất để xử lí giá trị thiếu cho các thuộc tính 'First_Working_Day_Of_Week', 'Last_Working_Day_Of_Week', 'Work_On_Saturday', 'Work_On_Sunday'. Hầu hết đều đi làm từ thứ 2 đến thứ 6 và nghỉ 2 ngày cuối tuần là thứ 7 và Chủ Nhật. Còn Total_Work_Hour, chúng ta sẽ điền bằng giá trị trung vị, vì giá trị này bằng tổng số giờ đi làm tiêu chuẩn là 8 tiếng/ 1 ngày, từ thứ 2 đến thứ 6 là 45 tiếng trong 1 tuần.

# %%
data_API.fillna({
    'First_Working_Day_Of_Week': 2,
    'Last_Working_Day_Of_Week': 6,
    'Work_On_Saturday': False,
    'Work_On_Sunday': False,
    'Total_Work_Hour': data_API['Total_Work_Hour'].median()
}, inplace=True)
# Chuyển kiểu dữ liệu của các cột 'First_Working_Day_Of_Week' và 'Last_Working_Day_Of_Week' về kiểu int
data_API['First_Working_Day_Of_Week'] = data_API['First_Working_Day_Of_Week'].astype(int)
data_API['Last_Working_Day_Of_Week'] = data_API['Last_Working_Day_Of_Week'].astype(int)

# %%
data_API.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# ### Xử lí Province

# %%
#Kiểm tra các mẫu dữ liệu bị thiếu địa điểm tuyển dụng Province
data_API[data_API['Province'].isnull()][['Job_Title', 'Company_Name', 'Province','Language', 'Job_URL']]

# %% [markdown]
# Nhận thấy hầu hết các mẫu dữ liệu bị thiếu địa điểm tuyển dụng Province đều có điểm chung là ở nước ngoài, ta có thể tiến hành điền thủ công các mẫu dữ liệu ở chỉ mục 1615, 3853, 3949 theo yêu cầu trong link tuyển dụng là 'NHẬT BẢN', còn mẫu dữ liệu ở mục 4048 là tin đăng tuyển dụng ở Indonesia.

# %%
index_Japan = [1615, 3853, 3949]
index_Indonesia = [4048]
# Thay các list rỗng [] bằng giá trị None
data_API.loc[data_API['Province'].apply(lambda x: isinstance(x, list) and len(x) == 0), 'Province'] = None
data_API.loc[index_Japan, 'Province'] = data_API.loc[index_Japan, 'Province'].fillna('NHẬT BẢN')  
data_API.loc[index_Indonesia, 'Province'] = data_API.loc[index_Indonesia, 'Province'].fillna('INDONESIA')
data_API['Province'] = data_API['Province'].apply(lambda x: list(x.split(',')) if isinstance(x, str) else x)  # Chuyển đổi giá trị ở dạng string thành list để đảm bảo tính nhất quán

# %% [markdown]
# ### Xử lý Language

# %%
#Kiểm tra các mẫu dữ liệu bị thiếu ngôn ngữ làm việc
check_missing_language = data_API[data_API['Language'].isnull()][['Job_Title', 'Province','Language', 'Work_On_Saturday', 'Work_On_Sunday','Job_URL']]
check_missing_language

# %% [markdown]
# Nhận thấy phần lớn các tin đăng bị thiếu ngôn ngữ làm việc phần lớn đều được đăng tuyển tại các tỉnh thành ở Việt Nam. Ta sẽ điền ngôn ngữ bị thiếu là "TIẾNG VIỆT" cho các mẫu dữ liệu bị thiếu này. Ngoài ra có 1 tin đăng được đăng tuyển ở nước ngoài, cụ thể là Indonesia. Ta tiến hành điền giá trị Indonesia cho mẫu dữ liệu tại chỉ mục 4048.

# %%
#Lấy index ngoại trừ 4048
index_Viet_Language =  check_missing_language.index.difference([4048])
# Thay các list rỗng [] bằng giá trị None
data_API.loc[data_API['Language'].apply(lambda x: isinstance(x, list) and len(x) == 0), 'Language'] = None
data_API.loc[index_Viet_Language, 'Language'] = data_API.loc[index_Viet_Language, 'Language'].fillna('TIẾNG VIỆT')
data_API.loc[[4048], 'Language'] = data_API.loc[[4048], 'Language'].fillna('UNKNOWN')  # Indonesia không yêu cầu ngôn ngữ cụ thể  
# Chuyển đổi giá trị ở dạng string thành list để đảm bảo tính nhất quán
data_API['Language'] = data_API['Language'].apply(lambda x: list(x.split(',')) if isinstance(x, str) else x)

# %% [markdown]
# ### Xử lí Company_Field

# %% [markdown]
# Hiện tượng missing xảy ra do có 1 số tin đăng đặc biệt của một công ty, có 1 số tin thì có ghi lĩnh vực còn 1 số tin khác thì không

# %%
# Tiến hành map các công ty theo key-value hiện có, với key là lĩnh vực còn values là danh sách các công ty thuộc lĩnh vực đó
company_field_map = data_API.groupby('Company_Field')['Company_Name'].unique().to_dict()

# Nếu muốn chuyển các giá trị từ numpy array sang list:
company_field_map = {k: list(v) for k, v in company_field_map.items()}

# Xem kết quả
for field, companies in list(company_field_map.items())[:]:
    print(f"Lĩnh vực: {field}\nDanh sách công ty: {companies}\n")

# %%
# Tiến hành điền missing values trong cột 'Company_Field' dựa trên giá trị hiện có của chính 'Company_Name' đó, nếu rỗng thì điền 'UNKNOWN'
def fill_company_field(group):
    # Lấy giá trị lĩnh vực đầu tiên KHÁC NaN và KHÁC 'UNKNOWN'
    first_field = group[(group != 'UNKNOWN') & (pd.notnull(group))]
    if not first_field.empty:
        # Nếu tìm thấy lĩnh vực thực sự, điền cho tất cả các dòng bị thiếu hoặc 'UNKNOWN'
        return group.apply(lambda x: first_field.iloc[0] if pd.isnull(x) or x == 'UNKNOWN' else x)
    else:
        # Nếu toàn bộ group đều NaN hoặc 'UNKNOWN', điền 'UNKNOWN'
        return group.apply(lambda x: 'UNKNOWN')

data_API['Company_Field'] = data_API.groupby('Company_Name')['Company_Field'].transform(fill_company_field)

# %% [markdown]
# ### Xử lí Date_Crawl_Module_1 và Deadline

# %%
data_API.isnull().sum().sort_values(ascending=False)

# %%
data_API[data_API['Date_Crawl_Module_1'].isnull()]

# %% [markdown]
# Tiến hành điền 'UNKNOWN' cho 2 thuộc tính thời gian này

# %%
data_API.fillna({
    'Date_Crawl_Module_1': 'UNKNOWN',
    'Deadline': 'UNKNOWN'
},inplace=True)  # Điền giá trị 'UNKNOWN' vào các ô đã được chuyển kiểu thành string

# %% [markdown]
# ### Xử lí trường hợp missing ở các thuộc tính còn lại

# %%
# Kiểm tra lại missing values
data_API.isnull().sum().sort_values(ascending=False)

# %%
data_API[data_API['Company_Name'].isnull() | data_API['Company_URL'].isnull() | data_API['Level'].isnull() | data_API['Academic_Level'].isnull() | data_API['Job_Type'].isnull()]

# %% [markdown]
# Các trường hợp thiếu còn lại đều nằm chung ở 1 mẫu dữ liệu, ta sẽ điền thủ công dựa trên link gốc

# %%
# Các trường hợp thiếu còn lại đều năm chung ở 1 mẫu dữ liệu, ta sẽ điền thủ công dựa trên link gốc
data_API.at[2531, 'Job_Type'] = 'TOÀN THỜI GIAN'
data_API.at[2531, 'Academic_Level'] = 'CAO ĐẲNG TRỞ LÊN'
data_API.at[2531, 'Level'] = 'NHÂN VIÊN'
data_API.at[2531, 'Company_Name'] = 'CELLPHONES'
data_API.at[2531, 'Company_URL'] = 'https://www.topcv.vn/cong-ty/cellphones/9490.html'
data_API.at[2531, 'Company_Field'] = 'THƯƠNG MẠI ĐIỆN TỬ'

# %% [markdown]
# # CHECKING CLEANED DATA

# %%
data_API.info()

# %%
# Kiểm tra lại missing values
data_API.isnull().sum().sort_values(ascending=False)

# %%
# Đếm lại số kiểu dữ liệu của các cột để đảm bảo tính nhất quán
#Kiểm tra kiểu dữ liệu và đếm số lượng kiểu dữ liệu trong 1 cột
for col in data_API.columns:
    print(data_API[col].apply(type).value_counts())

# %%
data_API.describe().T

# %%
data_API.describe(include='object').T.sort_values(by='unique', ascending=False)

# %%
#Danh sách các role và số lượng tuyển dụng tương ứng
role_recruitment_count = data_API['Recruitment_Count'].groupby(data_API['Role']).sum().reset_index().copy()
role_recruitment_count.sort_values(by='Recruitment_Count', ascending=False, inplace=True)
role_recruitment_count.reset_index(drop=True, inplace=True)
role_recruitment_count

# %%
#Drop cột 'old_job_titles'
data_API.drop(columns=['Old_Job_Title'], inplace=True)

# %% [markdown]
# # DATA NORMALIZATION

# %% [markdown]
# ## Đổi tên lại 1 số thuộc tính để phù hợp với ngữ cảnh và nội dung giá trị của thuộc tính đó

# %%
final_data_API = data_API.copy()

# %%
# 'Job_URL' thành 'Job_Url' -> Cần thể hiện rõ là Job_URL của công việc
final_data_API.rename(columns={'Job_URL': 'Job_Url'}, inplace=True)
# 'Province' thành 'Location' -> Để thể hiện rõ hơn về vị trí địa lý, vì một số công việc tuyển ở nước ngoài
final_data_API.rename(columns={'Province': 'Locations_Name'}, inplace=True)
# 'Thêm s cho một số thuộc tính' -> Để thể hiện rõ hơn về số lượng
final_data_API.rename(columns={
    'Tech_Stack': 'Tech_Stacks',
    'Programming_Language': 'Programming_Languages',
    'Language': 'Languages',
    'Total_Work_Hour': 'Total_Work_Hours',
}, inplace=True)
# 'Đổi tên 'Languages' thành 'Language_Name' 
final_data_API.rename(columns={'Languages': 'Languages_Name'}, inplace=True)
# 'Role' thành 'Role_Name' -> Để thể hiện rõ hơn về vai trò công việc
final_data_API.rename(columns={'Role': 'Role_Name'}, inplace=True)

# %%
#In hoa toàn bộ tên thuộc tính của dữ liệu để đảm bảo tính nhất quán
final_data_API.columns = [col.upper() for col in final_data_API.columns]

# %%
final_data_API.info()

# %%
final_data_API.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# ## Chuẩn hóa 1NF

# %% [markdown]
# Tách các thuộc tính có giá trị là list ra

# %%
data_1nf = final_data_API.copy()

# %% [markdown]
# ### Tạo JOB_ID cho mỗi tin đăng trước khi phân rã để đạt chuẩn 1

# %%
data_1nf['JOB_ID'] = data_1nf.index + 1  # Tạo JOB_ID từ chỉ số của DataFrame, bắt đầu từ 1
# Đưa JOB_ID lên đầu tiên

# %%
def clean_list_column(x):
    if isinstance(x, list):
        # Loại bỏ khoảng trắng, chuyển về in hoa (nếu muốn), loại trùng, loại phần tử rỗng
        cleaned = set(item.strip() for item in x if isinstance(item, str) and item.strip() != '')
        return list(cleaned)
    return x

cols_to_explode = ['TECH_STACKS', 'PROGRAMMING_LANGUAGES', 'LOCATIONS_NAME', 'LANGUAGES_NAME', 'JOB_ROLES']
for col in cols_to_explode:
    data_1nf[col] = data_1nf[col].apply(clean_list_column)

data_1nf.info()

# %%
# Explode các thuộc tính có dạng list để đạt chuẩn 1NF
for col in cols_to_explode:
    data_1nf = data_1nf.explode(col).reset_index(drop=True)
data_1nf.info()

# %%
#Loại bỏ khoảng trắng dư thừa ở đầu và cuối chuỗi
data_1nf = data_1nf.map(lambda x: x.strip() if isinstance(x, str) else x)

# %%
#Kiểm tra kiểu dữ liệu và đếm số lượng kiểu dữ liệu trong 1 cột
for col in data_1nf.columns:
    print(data_1nf[col].apply(type).value_counts())

# %%
data_1nf.head(5)

# %% [markdown]
# ### Thêm ID cho JOB_DETAIL_ID để đánh dấu các yêu cầu khác nhau của các tin đăng

# %%
data_1nf['JOB_DETAIL_ID'] = data_1nf.index + 1  # Tạo ID bắt đầu từ 1

# %% [markdown]
# ### Thêm ID cho thuộc tính LOCATIONS_NAME

# %%
# Tạo 1 DataFrame với cột đầu tiên là 'LOCATIONS_ID' và cột thứ hai là 'LOCATIONS_NAME'
locations_df = data_1nf[['LOCATIONS_NAME']].drop_duplicates().reset_index(drop=True)
locations_df['LOCATIONS_ID'] = locations_df.index + 1  # Tạo ID bắt đầu từ 1
locations_df = locations_df[['LOCATIONS_ID', 'LOCATIONS_NAME']]  # Đổi vị trí cột
#Không hiển thị index của máy của DataFrame
locations_df

# %%
# Left join locations_df vào data_1nf để gán ID cho các địa điểm
data_1nf = data_1nf.merge(locations_df, on='LOCATIONS_NAME', how='left')
data_1nf.head(5)

# %% [markdown]
# ### Thêm ID cho thuộc tính TECH_SKILLS

# %%
# Tạo 1 DataFrame với cột đầu tiên là 'TECH_ID' và cột thứ hai là 'TECH_STACKS'
tech_stacks_df = data_1nf[['TECH_STACKS']].drop_duplicates().reset_index(drop=True)
tech_stacks_df['TECH_ID'] = tech_stacks_df.index + 1  # Tạo ID bắt đầu từ 1
tech_stacks_df = tech_stacks_df[['TECH_ID', 'TECH_STACKS']]  # Đổi vị trí cột
tech_stacks_df.head(50)

# %%
# Left join tech_stacks_df vào data_1nf để gán ID cho các công nghệ
data_1nf = data_1nf.merge(tech_stacks_df, on = 'TECH_STACKS', how = 'left')
data_1nf.head(5)

# %% [markdown]
# ### Thêm ID cho thuộc tính PROGRAMMING_LANGUAGES (Ngôn ngữ lập trình)

# %%
# Tạo 1 DataFrame với cột đầu tiên là 'PRO_ID' và cột thứ hai là 'PROGRAMMING_LANGUAGES'
programming_languages_df = data_1nf[['PROGRAMMING_LANGUAGES']].drop_duplicates().reset_index(drop=True)
programming_languages_df['PRO_ID'] = programming_languages_df.index + 1  # Tạo ID bắt đầu từ 1
programming_languages_df = programming_languages_df[['PRO_ID', 'PROGRAMMING_LANGUAGES']]  # Đổi vị trí cột
programming_languages_df

# %%
# Left join programming_languages_df vào data_1nf để gán ID cho các ngôn ngữ lập trình
data_1nf = data_1nf.merge(programming_languages_df, on='PROGRAMMING_LANGUAGES', how='left')
data_1nf.head(5)

# %% [markdown]
# ### Thêm ID cho thuộc tính LANGUAGES (Ngôn ngữ giao tiếp khi làm việc)

# %%
# Tạo 1 DataFrame với cột đầu tiên là 'LANGUAGES_ID' và cột thứ hai là 'LANGUAGES_NAME'
languages_df = data_1nf[['LANGUAGES_NAME']].drop_duplicates().reset_index(drop=True)
languages_df['LANGUAGES_ID'] = languages_df.index + 1  # Tạo ID bắt đầu từ 1
languages_df = languages_df[['LANGUAGES_ID', 'LANGUAGES_NAME']]  # Đổi vị trí cột
languages_df

# %%
# Left join languages_df vào data_1nf để gán ID cho các ngôn ngữ
data_1nf = data_1nf.merge(languages_df, on='LANGUAGES_NAME', how='left')
data_1nf.head(5)

# %% [markdown]
# ### Thêm ID cho thuộc tính COMPANY

# %%
#hiện max  độ rộng cột
pd.set_option('display.max_colwidth', None)

# %%
# Tạo 1 DataFrame với cột đầu tiên là 'COMPANY_ID' và các cột là 'COMPANY_NAME','COMPANY_FIELD', 'COMPANY_URL'
company_df = data_1nf[['COMPANY_NAME']].drop_duplicates().reset_index(drop=True)
company_df['COMPANY_ID'] = company_df.index + 1  # Đánh ID theo COMPANY_NAME, bắt đầu từ 1
company_df = company_df[['COMPANY_ID', 'COMPANY_NAME']]

# %%
print(company_df['COMPANY_ID'].nunique())

# %%
company_df

# %%
# Kiểm tra công ty trùng nhau
company_df.describe(include='all').T

# %%
#Hiển thị công ty xuất hiện nhiều hơn 1 lần
company_df[company_df.duplicated(subset=['COMPANY_NAME'], keep=False)].sort_values(by='COMPANY_NAME')

# %%
# Left join languages_df vào data_1nf để gán ID cho các ngôn ngữ
data_1nf = data_1nf.merge(company_df, on = ['COMPANY_NAME'], how='left')
data_1nf.head(5)

# %% [markdown]
# ### Thêm ID cho thuộc tính ROLE

# %%
# Tạo 1 DataFrame với cột đầu tiên là 'Role_ID' và các cột là 'ROLE_NAME'
role_df = data_1nf[['ROLE_NAME']].drop_duplicates().reset_index(drop=True)
role_df['ROLE_ID'] = role_df.index + 1  # Tạo ID bắt đầu từ 1
role_df = role_df[['ROLE_ID', 'ROLE_NAME']]  # Đổi vị trí cột
role_df

# %%
# Left join role_df vào data_1nf để gán ID cho các vai trò
data_1nf = data_1nf.merge(role_df, on='ROLE_NAME', how='left')

# %% [markdown]
# ### Thêm ID cho thuộc tính COMPANY_FIELD

# %%
# Tạo 1 DataFrame với cột đầu tiên là 'Role_ID' và các cột là 'ROLE_NAME'
company_field_df = data_1nf[['COMPANY_FIELD']].drop_duplicates().reset_index(drop=True)
company_field_df['COMPANY_FIELD_ID'] = company_field_df.index + 1  # Tạo ID bắt đầu từ 1
company_field_df = company_field_df[['COMPANY_FIELD_ID', 'COMPANY_FIELD']]  # Đổi vị trí cột
company_field_df

# %%
# Left join company_field_df vào data_1nf để gán ID cho các lĩnh vực công ty
data_1nf = data_1nf.merge(company_field_df, on='COMPANY_FIELD', how='left')
data_1nf.head(5)

# %% [markdown]
# # EXPORT FINAL 1NF-DATA

# %%
data_1nf.info()

# %%
data_1nf.isnull().sum()

# %%
# Xuất file data_1nf ra định dạng CSV và parquet
data_1nf.to_csv(r'D:\Python_code\DS108\it-job-trend-analyzer\data\standardized_data\1NF_data\API_data_cleaned_1NF.csv', index=False, encoding='utf-8-sig')
data_1nf.to_parquet(r'D:\Python_code\DS108\it-job-trend-analyzer\data\standardized_data\1NF_data\API_data_cleaned_1NF.parquet', index=False)
